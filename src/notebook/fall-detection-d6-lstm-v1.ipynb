# %%
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn for better confusion matrix plots

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, fbeta_score # Added metrics

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-05-20 16:51:06.061500: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747759866.511951      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747759866.636552      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----- 0. GLOBAL CONSTANTS AND KEYPOINT DEFINITIONS -----

# !!! --- ACTION REQUIRED: REPLACE WITH YOUR ACTUAL 17 KEYPOINT NAMES --- !!!
# รายชื่อ keypoint ทั้ง 17 ชื่อจากไฟล์ CSV
# ลำดับใน list นี้ไม่สำคัญ เพราะจะถูก sort เพื่อสร้าง KEYPOINT_DICT
KEYPOINT_NAMES = [
    'Nose', 'Left Eye', 'Right Eye', 'Left Ear', 'Right Ear',
    'Left Shoulder', 'Right Shoulder', 'Left Elbow', 'Right Elbow',
    'Left Wrist', 'Right Wrist', 'Left Hip', 'Right Hip',
    'Left Knee', 'Right Knee', 'Left Ankle', 'Right Ankle'
] 

# Sort ชื่อ keypoint ตามตัวอักษร (นี่คือลำดับที่ pivot_table ใน generate_fall_sequences.py จะใช้)
SORTED_KEYPOINT_NAMES = sorted(KEYPOINT_NAMES)

# สร้าง KEYPOINT_DICT ที่ถูกต้องตามลำดับการ sort นี้
KEYPOINT_DICT = {name: i for i, name in enumerate(SORTED_KEYPOINT_NAMES)}

# ตั้งค่า NUM_KEYPOINTS จาก KEYPOINT_DICT ที่สร้างขึ้น
NUM_KEYPOINTS = len(KEYPOINT_DICT)

# พิมพ์ออกมาตรวจสอบ
print("--- Initializing Keypoint Definitions ---")
print(f"KEYPOINT_NAMES (before sort): {KEYPOINT_NAMES}")
print(f"SORTED_KEYPOINT_NAMES (used for ordering): {SORTED_KEYPOINT_NAMES}")
print(f"Generated KEYPOINT_DICT: {KEYPOINT_DICT}")
print(f"NUM_KEYPOINTS: {NUM_KEYPOINTS}")

if NUM_KEYPOINTS != 17:
    print(f"WARNING: NUM_KEYPOINTS is {NUM_KEYPOINTS}, but typically expected to be 17 for your case.")
    print("Please double-check the 'KEYPOINT_NAMES' list.")
print("----------------------------------------")
# Out:
# --- Initializing Keypoint Definitions ---
# KEYPOINT_NAMES (before sort): ['Nose', 'Left Eye', 'Right Eye', 'Left Ear', 'Right Ear', 'Left Shoulder', 'Right Shoulder', 'Left Elbow', 'Right Elbow', 'Left Wrist', 'Right Wrist', 'Left Hip', 'Right Hip', 'Left Knee', 'Right Knee', 'Left Ankle', 'Right Ankle']
# SORTED_KEYPOINT_NAMES (used for ordering): ['Left Ankle', 'Left Ear', 'Left Elbow', 'Left Eye', 'Left Hip', 'Left Knee', 'Left Shoulder', 'Left Wrist', 'Nose', 'Right Ankle', 'Right Ear', 'Right Elbow', 'Right Eye', 'Right Hip', 'Right Knee', 'Right Shoulder', 'Right Wrist']
# Generated KEYPOINT_DICT: {'Left Ankle': 0, 'Left Ear': 1, 'Left Elbow': 2, 'Left Eye': 3, 'Left Hip': 4, 'Left Knee': 5, 'Left Shoulder': 6, 'Left Wrist': 7, 'Nose': 8, 'Right Ankle': 9, 'Right Ear': 10, 'Right Elbow': 11, 'Right Eye': 12, 'Right Hip': 13, 'Right Knee': 14, 'Right Shoulder': 15, 'Right Wrist': 16}
# NUM_KEYPOINTS: 17
# ----------------------------------------

# %%
# ----- 1. HELPER FUNCTION FOR KEYPOINT INDICES -----
def get_kpt_indices(keypoint_name):
    if keypoint_name not in KEYPOINT_DICT:
        available_keys = list(KEYPOINT_DICT.keys())
        similar_keys = [k for k in available_keys if keypoint_name.lower() in k.lower() or k.lower() in keypoint_name.lower()]
        error_msg = f"Keypoint name '{keypoint_name}' not found in KEYPOINT_DICT. "
        error_msg += f"Available keys are: {available_keys}. "
        if similar_keys: error_msg += f"Did you mean one of these: {similar_keys}? "
        raise ValueError(error_msg)
    kp_idx = KEYPOINT_DICT[keypoint_name]
    return kp_idx * 3, kp_idx * 3 + 1, kp_idx * 3 + 2

# %%
# ----- 2. SKELETON NORMALIZATION FUNCTION -----
def normalize_skeleton(sequence_data, min_confidence=0.3):
    normalized_sequence = np.copy(sequence_data)
    ref_kp_names = {
        'ls': 'Left Shoulder', 'rs': 'Right Shoulder',
        'lh': 'Left Hip', 'rh': 'Right Hip'
    }
    for ref_kp_key, ref_kp_name_val in ref_kp_names.items():
        if ref_kp_name_val not in KEYPOINT_DICT:
            print(f"FATAL WARNING in normalize_skeleton: Reference keypoint '{ref_kp_name_val}' (for {ref_kp_key}) "
                  f"is not defined in your KEYPOINT_NAMES / KEYPOINT_DICT. Normalization will likely fail.")

    for t in range(sequence_data.shape[0]):
        frame_data = sequence_data[t, :]
        current_frame_normalized = np.copy(frame_data)
        try:
            ls_x_idx, ls_y_idx, ls_c_idx = get_kpt_indices(ref_kp_names['ls'])
            rs_x_idx, rs_y_idx, rs_c_idx = get_kpt_indices(ref_kp_names['rs'])
            lh_x_idx, lh_y_idx, lh_c_idx = get_kpt_indices(ref_kp_names['lh'])
            rh_x_idx, rh_y_idx, rh_c_idx = get_kpt_indices(ref_kp_names['rh'])
        except ValueError:
            normalized_sequence[t, :] = frame_data; continue

        ls_x, ls_y, ls_c = frame_data[ls_x_idx], frame_data[ls_y_idx], frame_data[ls_c_idx]
        rs_x, rs_y, rs_c = frame_data[rs_x_idx], frame_data[rs_y_idx], frame_data[rs_c_idx]
        lh_x, lh_y, lh_c = frame_data[lh_x_idx], frame_data[lh_y_idx], frame_data[lh_c_idx]
        rh_x, rh_y, rh_c = frame_data[rh_x_idx], frame_data[rh_y_idx], frame_data[rh_c_idx]

        mid_shoulder_x, mid_shoulder_y = np.nan, np.nan
        valid_ls, valid_rs = ls_c > min_confidence, rs_c > min_confidence
        if valid_ls and valid_rs: mid_shoulder_x, mid_shoulder_y = (ls_x + rs_x) / 2, (ls_y + rs_y) / 2
        elif valid_ls: mid_shoulder_x, mid_shoulder_y = ls_x, ls_y
        elif valid_rs: mid_shoulder_x, mid_shoulder_y = rs_x, rs_y

        mid_hip_x, mid_hip_y = np.nan, np.nan
        valid_lh, valid_rh = lh_c > min_confidence, rh_c > min_confidence
        if valid_lh and valid_rh: mid_hip_x, mid_hip_y = (lh_x + rh_x) / 2, (lh_y + rh_y) / 2
        elif valid_lh: mid_hip_x, mid_hip_y = lh_x, lh_y
        elif valid_rh: mid_hip_x, mid_hip_y = rh_x, rh_y

        if np.isnan(mid_hip_x) or np.isnan(mid_hip_y):
            normalized_sequence[t, :] = frame_data; continue

        reference_height = np.nan
        if not np.isnan(mid_shoulder_y) and not np.isnan(mid_hip_y):
            reference_height = np.abs(mid_shoulder_y - mid_hip_y)

        perform_scaling = not (np.isnan(reference_height) or reference_height < 1e-5)

        for kp_i in range(NUM_KEYPOINTS):
            x_i_col, y_i_col = kp_i * 3, kp_i * 3 + 1
            current_frame_normalized[x_i_col] -= mid_hip_x
            current_frame_normalized[y_i_col] -= mid_hip_y
            if perform_scaling:
                current_frame_normalized[x_i_col] /= reference_height
                current_frame_normalized[y_i_col] /= reference_height
        normalized_sequence[t, :] = current_frame_normalized
    return normalized_sequence

# %%
# ----- 3. DATA LOADING FUNCTION -----
def load_dataset(data_path, expected_shape_template=(30, None), normalize=True, min_confidence_norm=0.3):
    if NUM_KEYPOINTS is None or NUM_KEYPOINTS == 0:
        raise ValueError("NUM_KEYPOINTS is not set or is zero. Cannot determine expected shape.")
    expected_shape = (expected_shape_template[0], NUM_KEYPOINTS * 3)
    X, y = [], []
    print(f"Loading data from: {data_path}, expecting shape {expected_shape} for .npy files.")
    for label_name, label_val in [('no_fall', 0), ('fall', 1)]:
        folder = os.path.join(data_path, label_name)
        if not os.path.isdir(folder):
            print(f"Warning: Subfolder not found for label '{label_name}': {folder}")
            continue
        files_in_folder = glob(os.path.join(folder, "*.npy"))
        print(f"Found {len(files_in_folder)} .npy files in {folder}")
        loaded_count_for_label = 0
        for file_path in files_in_folder:
            try: arr = np.load(file_path)
            except Exception as e: print(f"Warning: Could not load file {file_path}: {e}"); continue
            if arr.shape == expected_shape:
                if normalize:
                    arr_normalized = normalize_skeleton(arr, min_confidence=min_confidence_norm)
                    if np.isnan(arr_normalized).any():
                        arr_normalized = np.nan_to_num(arr_normalized, nan=0.0, posinf=0.0, neginf=0.0)
                    X.append(arr_normalized)
                else: X.append(arr)
                y.append(label_val)
                loaded_count_for_label += 1
            else: print(f"Warning: Skipping file {file_path} due to incorrect shape: {arr.shape}. Expected: {expected_shape}")
        print(f"Successfully loaded {loaded_count_for_label} samples for label '{label_name}'.")
    if not X:
        print(f"Critical Warning: No data was loaded from {data_path}. Check paths, subfolder names, .npy files, and NUM_KEYPOINTS.")
        return np.array([]), np.array([])
    return np.array(X), np.array(y)

# %%
# ----- 4. LSTM MODEL DEFINITION -----
def create_lstm_model(input_shape, lstm_units=64, dense_units=32, dropout_rate=0.5):
    model = Sequential([
        LSTM(lstm_units, input_shape=input_shape, return_sequences=False),
        Dropout(dropout_rate),
        Dense(dense_units, activation='relu'),
        Dropout(dropout_rate / 2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Paths 
base_train = '/kaggle/input/fall-dataset6/train'
base_val   = '/kaggle/input/fall-dataset6/val'
base_test  = '/kaggle/input/fall-dataset6/test'

# ----- Parameters -----
TIMESTEPS = 30
EXPECTED_SHAPE_TEMPLATE = (TIMESTEPS, None) # NUM_KEYPOINTS will be used in load_dataset
MIN_CONF_NORM = 0.2

# Load Datasets
print("\n--- Loading Training Data ---")
X_train_orig, y_train_orig = load_dataset(base_train, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM)
print("\n--- Loading Validation Data ---")
X_val_orig, y_val_orig = load_dataset(base_val, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM)
print("\n--- Loading Test Data ---")
X_test_orig, y_test_orig = load_dataset(base_test, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM)

if X_train_orig.size == 0:
    print("FATAL ERROR: Training data is empty.")
    

# print shapes และ lstm_input_shape
print(f"\nShapes after loading:")
print(f"Train: X={X_train_orig.shape if X_train_orig.size > 0 else 'Empty'}, y={y_train_orig.shape if y_train_orig.size > 0 else 'Empty'}")
print(f"Val:   X={X_val_orig.shape if X_val_orig.size > 0 else 'Empty'}, y={y_val_orig.shape if y_val_orig.size > 0 else 'Empty'}")
print(f"Test:  X={X_test_orig.shape if X_test_orig.size > 0 else 'Empty'}, y={y_test_orig.shape if y_test_orig.size > 0 else 'Empty'}")

lstm_input_shape = (TIMESTEPS, NUM_KEYPOINTS * 3)
print(f"\nLSTM Input Shape: {lstm_input_shape}")
# Out:
# --- Loading Training Data ---
# Loading data from: /kaggle/input/fall-dataset6/train, expecting shape (30, 51) for .npy files.
# Found 6279 .npy files in /kaggle/input/fall-dataset6/train/no_fall
# Successfully loaded 6279 samples for label 'no_fall'.
# Found 5722 .npy files in /kaggle/input/fall-dataset6/train/fall
# Successfully loaded 5722 samples for label 'fall'.
#
# --- Loading Validation Data ---
# Loading data from: /kaggle/input/fall-dataset6/val, expecting shape (30, 51) for .npy files.
# Found 1346 .npy files in /kaggle/input/fall-dataset6/val/no_fall
# Successfully loaded 1346 samples for label 'no_fall'.
# Found 1226 .npy files in /kaggle/input/fall-dataset6/val/fall
# Successfully loaded 1226 samples for label 'fall'.
#
# --- Loading Test Data ---
# Loading data from: /kaggle/input/fall-dataset6/test, expecting shape (30, 51) for .npy files.
# Found 1346 .npy files in /kaggle/input/fall-dataset6/test/no_fall
# Successfully loaded 1346 samples for label 'no_fall'.
# Found 1226 .npy files in /kaggle/input/fall-dataset6/test/fall
# Successfully loaded 1226 samples for label 'fall'.
#
# Shapes after loading:
# Train: X=(12001, 30, 51), y=(12001,)
# Val:   X=(2572, 30, 51), y=(2572,)
# Test:  X=(2572, 30, 51), y=(2572,)
#
# LSTM Input Shape: (30, 51)

# %%
# ----- Cross-Validation -----
N_SPLITS_CV = 5
EPOCHS_CV = 30
BATCH_SIZE_CV = 32
cv_accuracies, cv_losses = [], []
fold_no = 1

print(f"\n--- Starting {N_SPLITS_CV}-Fold Cross-Validation ---")
if X_train_orig.size > 0 and y_train_orig.size >= N_SPLITS_CV :
    skf = StratifiedKFold(n_splits=N_SPLITS_CV, shuffle=True, random_state=42)
    for train_idx, val_idx in skf.split(X_train_orig, y_train_orig):
        print(f"--- Fold {fold_no}/{N_SPLITS_CV} ---")
        X_cv_train, X_cv_val = X_train_orig[train_idx], X_train_orig[val_idx]
        y_cv_train, y_cv_val = y_train_orig[train_idx], y_train_orig[val_idx]
        cv_model = create_lstm_model(lstm_input_shape)
        # early_stopping_cv = EarlyStopping(monitor='val_accuracy', patience=7, verbose=1, mode='max', restore_best_weights=True)
        history_cv = cv_model.fit(X_cv_train, y_cv_train, epochs=EPOCHS_CV, batch_size=BATCH_SIZE_CV, validation_data=(X_cv_val, y_cv_val), verbose=1) # callbacks=[early_stopping_cv]
        loss, accuracy = cv_model.evaluate(X_cv_val, y_cv_val, verbose=0)
        print(f"Fold {fold_no} - CV Val Loss: {loss:.4f}, CV Val Accuracy: {accuracy:.4f}")
        cv_losses.append(loss); cv_accuracies.append(accuracy)
        fold_no += 1
    if cv_accuracies:
        print("\n--- Cross-Validation Summary ---")
        print(f"Average CV Loss: {np.mean(cv_losses):.4f} (+/- {np.std(cv_losses):.4f})")
        print(f"Average CV Accuracy: {np.mean(cv_accuracies):.4f} (+/- {np.std(cv_accuracies):.4f})")
    else: print("Cross-validation did not produce results (or was skipped).")
else:
    print(f"Skipping Cross-Validation: Training data is empty or has too few samples ({y_train_orig.size}) for {N_SPLITS_CV} splits.")
# Out:
# --- Starting 5-Fold Cross-Validation ---
# --- Fold 1/5 ---
# I0000 00:00:1747760177.968154      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747760177.968847      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# I0000 00:00:1747760183.089449     101 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7020 - loss: 0.5793 - val_accuracy: 0.7701 - val_loss: 0.4742
# Epoch 2/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7542 - loss: 0.5041 - val_accuracy: 0.8001 - val_loss: 0.4310
# Epoch 3/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7746 - loss: 0.4722 - val_accuracy: 0.8163 - val_loss: 0.4093
# Epoch 4/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7962 - loss: 0.4456 - val_accuracy: 0.8209 - val_loss: 0.4090
# Epoch 5/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8162 - loss: 0.4256 - val_accuracy: 0.8305 - val_loss: 0.3780
# Epoch 6/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8336 - loss: 0.3841 - val_accuracy: 0.8421 - val_loss: 0.3679
# Epoch 7/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8293 - loss: 0.3872 - val_accuracy: 0.8426 - val_loss: 0.3681
# Epoch 8/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8319 - loss: 0.3783 - val_accuracy: 0.8430 - val_loss: 0.3600
# Epoch 9/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8461 - loss: 0.3574 - val_accuracy: 0.8438 - val_loss: 0.3545
# Epoch 10/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8444 - loss: 0.3691 - val_accuracy: 0.8459 - val_loss: 0.3469
# Epoch 11/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8535 - loss: 0.3458 - val_accuracy: 0.8592 - val_loss: 0.3389
# Epoch 12/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8666 - loss: 0.3219 - val_accuracy: 0.8559 - val_loss: 0.3427
# Epoch 13/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8583 - loss: 0.3369 - val_accuracy: 0.8609 - val_loss: 0.3371
# Epoch 14/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8671 - loss: 0.3176 - val_accuracy: 0.8630 - val_loss: 0.3227
# Epoch 15/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8691 - loss: 0.3196 - val_accuracy: 0.8659 - val_loss: 0.3224
# Epoch 16/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8754 - loss: 0.3091 - val_accuracy: 0.8655 - val_loss: 0.3342
# Epoch 17/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8781 - loss: 0.3046 - val_accuracy: 0.8651 - val_loss: 0.3241
# Epoch 18/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8792 - loss: 0.2937 - val_accuracy: 0.8684 - val_loss: 0.3177
# Epoch 19/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8781 - loss: 0.3027 - val_accuracy: 0.8696 - val_loss: 0.3184
# Epoch 20/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8845 - loss: 0.2853 - val_accuracy: 0.8663 - val_loss: 0.3199
# Epoch 21/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8910 - loss: 0.2753 - val_accuracy: 0.8701 - val_loss: 0.3333
# Epoch 22/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8910 - loss: 0.2766 - val_accuracy: 0.8771 - val_loss: 0.3211
# Epoch 23/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8882 - loss: 0.2740 - val_accuracy: 0.8730 - val_loss: 0.3343
# Epoch 24/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8887 - loss: 0.2661 - val_accuracy: 0.8751 - val_loss: 0.3202
# Epoch 25/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8944 - loss: 0.2645 - val_accuracy: 0.8726 - val_loss: 0.3271
# Epoch 26/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8996 - loss: 0.2568 - val_accuracy: 0.8730 - val_loss: 0.3226
# Epoch 27/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9043 - loss: 0.2422 - val_accuracy: 0.8717 - val_loss: 0.3389
# Epoch 28/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8973 - loss: 0.2532 - val_accuracy: 0.8746 - val_loss: 0.3303
# Epoch 29/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8977 - loss: 0.2500 - val_accuracy: 0.8751 - val_loss: 0.3150
# Epoch 30/30
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9024 - loss: 0.2423 - val_accuracy: 0.8738 - val_loss: 0.3189
# Fold 1 - CV Val Loss: 0.3189, CV Val Accuracy: 0.8738
# --- Fold 2/5 ---
# Epoch 1/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7123 - loss: 0.5695 - val_accuracy: 0.7721 - val_loss: 0.4764
# Epoch 2/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7715 - loss: 0.4828 - val_accuracy: 0.7808 - val_loss: 0.4699
# Epoch 3/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7992 - loss: 0.4383 - val_accuracy: 0.8083 - val_loss: 0.4258
# Epoch 4/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8048 - loss: 0.4259 - val_accuracy: 0.8167 - val_loss: 0.4104
# Epoch 5/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8293 - loss: 0.3975 - val_accuracy: 0.8075 - val_loss: 0.4200
# Epoch 6/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8326 - loss: 0.3878 - val_accuracy: 0.8192 - val_loss: 0.4076
# Epoch 7/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8350 - loss: 0.3823 - val_accuracy: 0.8246 - val_loss: 0.3923
# Epoch 8/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8439 - loss: 0.3661 - val_accuracy: 0.8279 - val_loss: 0.3917
# Epoch 9/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8532 - loss: 0.3483 - val_accuracy: 0.8233 - val_loss: 0.3941
# Epoch 10/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8451 - loss: 0.3492 - val_accuracy: 0.8317 - val_loss: 0.3735
# Epoch 11/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8567 - loss: 0.3342 - val_accuracy: 0.8258 - val_loss: 0.3831
# Epoch 12/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8487 - loss: 0.3468 - val_accuracy: 0.8383 - val_loss: 0.3725
# Epoch 13/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8663 - loss: 0.3235 - val_accuracy: 0.8375 - val_loss: 0.3791
# Epoch 14/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8631 - loss: 0.3236 - val_accuracy: 0.8258 - val_loss: 0.3878
# Epoch 15/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8616 - loss: 0.3194 - val_accuracy: 0.8354 - val_loss: 0.3648
# Epoch 16/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8700 - loss: 0.3052 - val_accuracy: 0.8400 - val_loss: 0.3743
# Epoch 17/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8751 - loss: 0.3008 - val_accuracy: 0.8462 - val_loss: 0.3617
# Epoch 18/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8808 - loss: 0.2880 - val_accuracy: 0.8446 - val_loss: 0.3668
# Epoch 19/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8746 - loss: 0.2944 - val_accuracy: 0.8462 - val_loss: 0.3497
# Epoch 20/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8800 - loss: 0.2829 - val_accuracy: 0.8404 - val_loss: 0.3900
# Epoch 21/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8842 - loss: 0.2805 - val_accuracy: 0.8475 - val_loss: 0.3837
# Epoch 22/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8894 - loss: 0.2705 - val_accuracy: 0.8512 - val_loss: 0.3656
# Epoch 23/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8893 - loss: 0.2574 - val_accuracy: 0.8525 - val_loss: 0.3589
# Epoch 24/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8876 - loss: 0.2709 - val_accuracy: 0.8500 - val_loss: 0.3510
# Epoch 25/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8867 - loss: 0.2733 - val_accuracy: 0.8567 - val_loss: 0.3504
# Epoch 26/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8939 - loss: 0.2523 - val_accuracy: 0.8554 - val_loss: 0.3535
# Epoch 27/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8964 - loss: 0.2568 - val_accuracy: 0.8562 - val_loss: 0.3653
# Epoch 28/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.2543 - val_accuracy: 0.8554 - val_loss: 0.3766
# Epoch 29/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9003 - loss: 0.2499 - val_accuracy: 0.8600 - val_loss: 0.3450
# Epoch 30/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8935 - loss: 0.2557 - val_accuracy: 0.8479 - val_loss: 0.3719
# Fold 2 - CV Val Loss: 0.3719, CV Val Accuracy: 0.8479
# --- Fold 3/5 ---
# Epoch 1/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6875 - loss: 0.5878 - val_accuracy: 0.7658 - val_loss: 0.4749
# Epoch 2/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7696 - loss: 0.4911 - val_accuracy: 0.7971 - val_loss: 0.4348
# Epoch 3/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8009 - loss: 0.4450 - val_accuracy: 0.8054 - val_loss: 0.4240
# Epoch 4/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8065 - loss: 0.4352 - val_accuracy: 0.8308 - val_loss: 0.3902
# Epoch 5/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8163 - loss: 0.4154 - val_accuracy: 0.8296 - val_loss: 0.3766
# Epoch 6/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8327 - loss: 0.3941 - val_accuracy: 0.8350 - val_loss: 0.3696
# Epoch 7/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8295 - loss: 0.3861 - val_accuracy: 0.8383 - val_loss: 0.3714
# Epoch 8/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8349 - loss: 0.3720 - val_accuracy: 0.8467 - val_loss: 0.3466
# Epoch 9/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8500 - loss: 0.3506 - val_accuracy: 0.8487 - val_loss: 0.3559
# Epoch 10/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8482 - loss: 0.3537 - val_accuracy: 0.8592 - val_loss: 0.3432
# Epoch 11/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8591 - loss: 0.3309 - val_accuracy: 0.8442 - val_loss: 0.3524
# Epoch 12/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8565 - loss: 0.3272 - val_accuracy: 0.8467 - val_loss: 0.3401
# Epoch 13/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8698 - loss: 0.3197 - val_accuracy: 0.8583 - val_loss: 0.3294
# Epoch 14/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8660 - loss: 0.3226 - val_accuracy: 0.8487 - val_loss: 0.3380
# Epoch 15/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8694 - loss: 0.3124 - val_accuracy: 0.8612 - val_loss: 0.3285
# Epoch 16/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8715 - loss: 0.3065 - val_accuracy: 0.8621 - val_loss: 0.3270
# Epoch 17/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8733 - loss: 0.3025 - val_accuracy: 0.8575 - val_loss: 0.3318
# Epoch 18/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8724 - loss: 0.3081 - val_accuracy: 0.8671 - val_loss: 0.3283
# Epoch 19/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8800 - loss: 0.2949 - val_accuracy: 0.8579 - val_loss: 0.3455
# Epoch 20/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8855 - loss: 0.2847 - val_accuracy: 0.8571 - val_loss: 0.3339
# Epoch 21/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8751 - loss: 0.2939 - val_accuracy: 0.8637 - val_loss: 0.3301
# Epoch 22/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8904 - loss: 0.2682 - val_accuracy: 0.8554 - val_loss: 0.3440
# Epoch 23/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8868 - loss: 0.2739 - val_accuracy: 0.8683 - val_loss: 0.3319
# Epoch 24/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8876 - loss: 0.2693 - val_accuracy: 0.8633 - val_loss: 0.3423
# Epoch 25/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8904 - loss: 0.2654 - val_accuracy: 0.8650 - val_loss: 0.3220
# Epoch 26/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8915 - loss: 0.2650 - val_accuracy: 0.8654 - val_loss: 0.3237
# Epoch 27/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8977 - loss: 0.2591 - val_accuracy: 0.8687 - val_loss: 0.3448
# Epoch 28/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8932 - loss: 0.2642 - val_accuracy: 0.8717 - val_loss: 0.3307
# Epoch 29/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9070 - loss: 0.2423 - val_accuracy: 0.8612 - val_loss: 0.3458
# Epoch 30/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9017 - loss: 0.2472 - val_accuracy: 0.8662 - val_loss: 0.3313
# Fold 3 - CV Val Loss: 0.3313, CV Val Accuracy: 0.8662
# --- Fold 4/5 ---
# Epoch 1/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7030 - loss: 0.5805 - val_accuracy: 0.7583 - val_loss: 0.4861
# Epoch 2/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7521 - loss: 0.5031 - val_accuracy: 0.7879 - val_loss: 0.4535
# Epoch 3/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7853 - loss: 0.4609 - val_accuracy: 0.8104 - val_loss: 0.4250
# Epoch 4/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8097 - loss: 0.4365 - val_accuracy: 0.8138 - val_loss: 0.4107
# Epoch 5/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8160 - loss: 0.4128 - val_accuracy: 0.8242 - val_loss: 0.3967
# Epoch 6/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8293 - loss: 0.3991 - val_accuracy: 0.8300 - val_loss: 0.3769
# Epoch 7/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8330 - loss: 0.3841 - val_accuracy: 0.8304 - val_loss: 0.3841
# Epoch 8/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8418 - loss: 0.3685 - val_accuracy: 0.8313 - val_loss: 0.3914
# Epoch 9/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8407 - loss: 0.3584 - val_accuracy: 0.8388 - val_loss: 0.3669
# Epoch 10/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8565 - loss: 0.3400 - val_accuracy: 0.8383 - val_loss: 0.3571
# Epoch 11/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8488 - loss: 0.3473 - val_accuracy: 0.8421 - val_loss: 0.3540
# Epoch 12/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8603 - loss: 0.3315 - val_accuracy: 0.8404 - val_loss: 0.3475
# Epoch 13/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8622 - loss: 0.3297 - val_accuracy: 0.8533 - val_loss: 0.3575
# Epoch 14/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8625 - loss: 0.3370 - val_accuracy: 0.8467 - val_loss: 0.3398
# Epoch 15/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8706 - loss: 0.3088 - val_accuracy: 0.8425 - val_loss: 0.3515
# Epoch 16/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8777 - loss: 0.2936 - val_accuracy: 0.8496 - val_loss: 0.3367
# Epoch 17/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8778 - loss: 0.2978 - val_accuracy: 0.8537 - val_loss: 0.3359
# Epoch 18/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8837 - loss: 0.2899 - val_accuracy: 0.8567 - val_loss: 0.3295
# Epoch 19/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8804 - loss: 0.2959 - val_accuracy: 0.8592 - val_loss: 0.3421
# Epoch 20/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8837 - loss: 0.2863 - val_accuracy: 0.8487 - val_loss: 0.3420
# Epoch 21/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8814 - loss: 0.2790 - val_accuracy: 0.8537 - val_loss: 0.3281
# Epoch 22/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8883 - loss: 0.2748 - val_accuracy: 0.8587 - val_loss: 0.3294
# Epoch 23/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8956 - loss: 0.2686 - val_accuracy: 0.8571 - val_loss: 0.3363
# Epoch 24/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8973 - loss: 0.2595 - val_accuracy: 0.8554 - val_loss: 0.3285
# Epoch 25/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8963 - loss: 0.2624 - val_accuracy: 0.8592 - val_loss: 0.3274
# Epoch 26/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8984 - loss: 0.2549 - val_accuracy: 0.8592 - val_loss: 0.3238
# Epoch 27/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8813 - loss: 0.2955 - val_accuracy: 0.8592 - val_loss: 0.3414
# Epoch 28/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8933 - loss: 0.2640 - val_accuracy: 0.8617 - val_loss: 0.3316
# Epoch 29/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8961 - loss: 0.2550 - val_accuracy: 0.8604 - val_loss: 0.3365
# Epoch 30/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9127 - loss: 0.2266 - val_accuracy: 0.8625 - val_loss: 0.3328
# Fold 4 - CV Val Loss: 0.3328, CV Val Accuracy: 0.8625
# --- Fold 5/5 ---
# Epoch 1/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7023 - loss: 0.5810 - val_accuracy: 0.7721 - val_loss: 0.4698
# Epoch 2/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7689 - loss: 0.4941 - val_accuracy: 0.8017 - val_loss: 0.4328
# Epoch 3/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8002 - loss: 0.4419 - val_accuracy: 0.8229 - val_loss: 0.4047
# Epoch 4/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7929 - loss: 0.4359 - val_accuracy: 0.8133 - val_loss: 0.4122
# Epoch 5/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8158 - loss: 0.4183 - val_accuracy: 0.8329 - val_loss: 0.3837
# Epoch 6/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8210 - loss: 0.4048 - val_accuracy: 0.8521 - val_loss: 0.3589
# Epoch 7/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8472 - loss: 0.3653 - val_accuracy: 0.8487 - val_loss: 0.3528
# Epoch 8/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8420 - loss: 0.3691 - val_accuracy: 0.8487 - val_loss: 0.3469
# Epoch 9/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8504 - loss: 0.3560 - val_accuracy: 0.8446 - val_loss: 0.3665
# Epoch 10/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8520 - loss: 0.3448 - val_accuracy: 0.8567 - val_loss: 0.3346
# Epoch 11/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8644 - loss: 0.3318 - val_accuracy: 0.8654 - val_loss: 0.3295
# Epoch 12/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8567 - loss: 0.3369 - val_accuracy: 0.8633 - val_loss: 0.3243
# Epoch 13/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8668 - loss: 0.3239 - val_accuracy: 0.8646 - val_loss: 0.3216
# Epoch 14/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8734 - loss: 0.3147 - val_accuracy: 0.8712 - val_loss: 0.3239
# Epoch 15/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8739 - loss: 0.3040 - val_accuracy: 0.8675 - val_loss: 0.3256
# Epoch 16/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8763 - loss: 0.3081 - val_accuracy: 0.8654 - val_loss: 0.3239
# Epoch 17/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8749 - loss: 0.3071 - val_accuracy: 0.8750 - val_loss: 0.3211
# Epoch 18/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8842 - loss: 0.2906 - val_accuracy: 0.8679 - val_loss: 0.3259
# Epoch 19/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8893 - loss: 0.2829 - val_accuracy: 0.8687 - val_loss: 0.3224
# Epoch 20/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8873 - loss: 0.2794 - val_accuracy: 0.8721 - val_loss: 0.3161
# Epoch 21/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8871 - loss: 0.2778 - val_accuracy: 0.8767 - val_loss: 0.3154
# Epoch 22/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8908 - loss: 0.2752 - val_accuracy: 0.8808 - val_loss: 0.3186
# Epoch 23/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.2611 - val_accuracy: 0.8700 - val_loss: 0.3256
# Epoch 24/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8951 - loss: 0.2520 - val_accuracy: 0.8729 - val_loss: 0.3214
# Epoch 25/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8892 - loss: 0.2683 - val_accuracy: 0.8675 - val_loss: 0.3234
# Epoch 26/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8939 - loss: 0.2527 - val_accuracy: 0.8767 - val_loss: 0.3287
# Epoch 27/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9007 - loss: 0.2671 - val_accuracy: 0.8754 - val_loss: 0.3390
# Epoch 28/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8987 - loss: 0.2500 - val_accuracy: 0.8788 - val_loss: 0.3196
# Epoch 29/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8957 - loss: 0.2619 - val_accuracy: 0.8800 - val_loss: 0.3171
# Epoch 30/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9062 - loss: 0.2411 - val_accuracy: 0.8737 - val_loss: 0.3309
# Fold 5 - CV Val Loss: 0.3309, CV Val Accuracy: 0.8737
#
# --- Cross-Validation Summary ---
# Average CV Loss: 0.3372 (+/- 0.0181)
# Average CV Accuracy: 0.8648 (+/- 0.0095)

# %%
# ----- Train Final Model -----
EPOCHS_FINAL = 30 
BATCH_SIZE_FINAL = 32
final_model = None
history_final = None # Initialize history_final

if X_train_orig.size > 0:
    print("\n--- Training Final Model ---")
    final_model = create_lstm_model(lstm_input_shape)
    callbacks_final = []
    validation_data_final = None
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        validation_data_final = (X_val_orig, y_val_orig)
        early_stopping_final = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True)
        callbacks_final.append(early_stopping_final)
        print(f"Training final model with validation data (shape: {X_val_orig.shape}) and EarlyStopping.")
    else:
        print("Training final model without validation data. EarlyStopping on val_accuracy disabled.")
    history_final = final_model.fit(X_train_orig, y_train_orig, epochs=EPOCHS_FINAL, batch_size=BATCH_SIZE_FINAL, validation_data=validation_data_final, callbacks=callbacks_final if callbacks_final else None, verbose=1)
# Out:
# --- Training Final Model ---
# Training final model with validation data (shape: (2572, 30, 51)) and EarlyStopping.
# Epoch 1/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7047 - loss: 0.5747 - val_accuracy: 0.7912 - val_loss: 0.4518
# Epoch 2/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7535 - loss: 0.5121 - val_accuracy: 0.8149 - val_loss: 0.4099
# Epoch 3/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7969 - loss: 0.4510 - val_accuracy: 0.8320 - val_loss: 0.3826
# Epoch 4/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8121 - loss: 0.4223 - val_accuracy: 0.8383 - val_loss: 0.3786
# Epoch 5/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8208 - loss: 0.4078 - val_accuracy: 0.8476 - val_loss: 0.3493
# Epoch 6/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8380 - loss: 0.3769 - val_accuracy: 0.8495 - val_loss: 0.3527
# Epoch 7/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8484 - loss: 0.3599 - val_accuracy: 0.8558 - val_loss: 0.3372
# Epoch 8/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8445 - loss: 0.3733 - val_accuracy: 0.8589 - val_loss: 0.3345
# Epoch 9/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8464 - loss: 0.3541 - val_accuracy: 0.8674 - val_loss: 0.3225
# Epoch 10/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8565 - loss: 0.3323 - val_accuracy: 0.8663 - val_loss: 0.3261
# Epoch 11/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8603 - loss: 0.3384 - val_accuracy: 0.8655 - val_loss: 0.3171
# Epoch 12/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8681 - loss: 0.3267 - val_accuracy: 0.8686 - val_loss: 0.3177
# Epoch 13/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8655 - loss: 0.3151 - val_accuracy: 0.8651 - val_loss: 0.3152
# Epoch 14/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8707 - loss: 0.3133 - val_accuracy: 0.8713 - val_loss: 0.3100
# Epoch 15/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8724 - loss: 0.3106 - val_accuracy: 0.8705 - val_loss: 0.3081
# Epoch 16/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8686 - loss: 0.3079 - val_accuracy: 0.8771 - val_loss: 0.3025
# Epoch 17/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8836 - loss: 0.2912 - val_accuracy: 0.8841 - val_loss: 0.2993
# Epoch 18/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8827 - loss: 0.2929 - val_accuracy: 0.8748 - val_loss: 0.3070
# Epoch 19/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8804 - loss: 0.2880 - val_accuracy: 0.8795 - val_loss: 0.3013
# Epoch 20/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8883 - loss: 0.2821 - val_accuracy: 0.8826 - val_loss: 0.3001
# Epoch 21/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8832 - loss: 0.3009 - val_accuracy: 0.8725 - val_loss: 0.3058
# Epoch 22/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8895 - loss: 0.2694 - val_accuracy: 0.8806 - val_loss: 0.3026
# Epoch 23/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8876 - loss: 0.2828 - val_accuracy: 0.8733 - val_loss: 0.3062
# Epoch 24/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8842 - loss: 0.2853 - val_accuracy: 0.8802 - val_loss: 0.2971
# Epoch 25/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8959 - loss: 0.2630 - val_accuracy: 0.8779 - val_loss: 0.3014
# Epoch 26/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8925 - loss: 0.2612 - val_accuracy: 0.8775 - val_loss: 0.2967
# Epoch 27/30
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9001 - loss: 0.2519 - val_accuracy: 0.8752 - val_loss: 0.2996
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
# ----- Plot Training History of Final Model -----

if history_final and hasattr(history_final, 'history') and history_final.history:
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    if 'accuracy' in history_final.history: plt.plot(history_final.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history_final.history: plt.plot(history_final.history['val_accuracy'], label='Val Accuracy')
    plt.title('Final Model Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    plt.subplot(1, 2, 2)
    if 'loss' in history_final.history: plt.plot(history_final.history['loss'], label='Train Loss')
    if 'val_loss' in history_final.history: plt.plot(history_final.history['val_loss'], label='Val Loss')
    plt.title('Final Model Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)
    plt.tight_layout(); plt.show()
else:
    print("Skipping plotting of training history as final model training was not completed or history is unavailable.")

print("\n--- Script Finished ---")
# Out:
# --- Script Finished ---

# %%
from sklearn.metrics import classification_report, confusion_matrix, fbeta_score, precision_recall_fscore_support

# ----- FUNCTION TO PLOT CONFUSION MATRIX -----
def plot_confusion_matrix_custom(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# ----- FUNCTION TO PLOT METRICS BARCHART  -----
def plot_metrics_barchart(metrics_data, class_names, title='Metrics per Class'):
    """
    Plots a grouped bar chart for precision, recall, f1-score, f2-score for each class.
    metrics_data should be a dictionary like:
    {
        'Precision': [precision_class0, precision_class1],
        'Recall': [recall_class0, recall_class1],
        'F1-score': [f1_class0, f1_class1],
        'F2-score': [f2_class0, f2_class1]
    }
    """
    df_metrics = pd.DataFrame(metrics_data, index=class_names)
    
    ax = df_metrics.plot(kind='bar', figsize=(10, 7), width=0.8, colormap='viridis') # You can change colormap
    plt.title(title, fontsize=15)
    plt.ylabel('Score (%)', fontsize=12)
    plt.xlabel('Class', fontsize=12)
    plt.xticks(rotation=0)
    plt.ylim(0, 1) # Scores are between 0 and 1, display as 0-100 if multiplied by 100 before
    
    # Add text annotations to the bars
    for p in ax.patches:
        ax.annotate(f"{p.get_height()*100:.1f}%", # Format as percentage
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', 
                    xytext=(0, 9), 
                    textcoords='offset points',
                    fontsize=10)
    
    plt.legend(title='Metrics')
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

# ----- DETAILED EVALUATION AND REPORTING -----
target_names = ['no_fall', 'fall'] # สำหรับ classification report
class_labels = [0, 1] # Corresponding numerical labels

if final_model is not None: # ตรวจสอบว่า final_model ถูกสร้างและเทรนแล้ว
    # --- Evaluation on Validation Set ---
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        print("\n\n--- Custom Validation Metrics Report ---")
        y_pred_val_probs = final_model.predict(X_val_orig)
        y_pred_val_classes = (y_pred_val_probs > 0.5).astype(int).flatten()

        # Calculate metrics per class
        precision_val, recall_val, f1_val, support_val = precision_recall_fscore_support(
            y_val_orig, y_pred_val_classes, labels=class_labels, zero_division=0
        )
        f2_val_per_class = fbeta_score(y_val_orig, y_pred_val_classes, beta=2, labels=class_labels, average=None, zero_division=0)

        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_val[i]:>10.4f} {recall_val[i]:>10.4f} {f1_val[i]:>10.4f} {f2_val_per_class[i]:>10.4f} {support_val[i]:>10}")
        
        # For plotting (scores between 0 and 1)
        val_metrics_for_plot = {
            'Precision': precision_val,
            'Recall': recall_val,
            'F1-score': f1_val,
            'F2-score': f2_val_per_class
        }
        plot_metrics_barchart(val_metrics_for_plot, target_names, title='Validation Metrics')

        # Confusion Matrix
        cm_val = confusion_matrix(y_val_orig, y_pred_val_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_val, classes=target_names, title='Validation Confusion Matrix')
    else:
        print("\nValidation data is empty. Skipping detailed validation metrics report.")

    # --- Evaluation on Test Set ---
    if X_test_orig.size > 0 and y_test_orig.size > 0:
        print("\n\n--- Custom Test Metrics Report ---")
        y_pred_test_probs = final_model.predict(X_test_orig)
        y_pred_test_classes = (y_pred_test_probs > 0.5).astype(int).flatten()

        # Calculate metrics per class
        precision_test, recall_test, f1_test, support_test = precision_recall_fscore_support(
            y_test_orig, y_pred_test_classes, labels=class_labels, zero_division=0
        )
        f2_test_per_class = fbeta_score(y_test_orig, y_pred_test_classes, beta=2, labels=class_labels, average=None, zero_division=0)

        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_test[i]:>10.4f} {recall_test[i]:>10.4f} {f1_test[i]:>10.4f} {f2_test_per_class[i]:>10.4f} {support_test[i]:>10}")

        # For plotting
        test_metrics_for_plot = {
            'Precision': precision_test,
            'Recall': recall_test,
            'F1-score': f1_test,
            'F2-score': f2_test_per_class
        }
        plot_metrics_barchart(test_metrics_for_plot, target_names, title='Test Metrics')
        
        # Confusion Matrix
        cm_test = confusion_matrix(y_test_orig, y_pred_test_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_test, classes=target_names, title='Test Confusion Matrix')
    else:
        print("\nTest data is empty. Skipping detailed test metrics report.")
else:
    print("Final model was not trained (likely due to empty training data). Skipping detailed evaluation.")
# Out:
# --- Custom Validation Metrics Report ---
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9081     0.8663     0.8867     0.8743       1346
# fall          0.8602     0.9038     0.8815     0.8947       1226
# --- Custom Test Metrics Report ---
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.8940     0.8588     0.8761     0.8657       1346
# fall          0.8514     0.8883     0.8695     0.8806       1226
