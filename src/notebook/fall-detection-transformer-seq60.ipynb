# %%
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, fbeta_score, precision_recall_fscore_support

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense, Dropout, LayerNormalization, MultiHeadAttention,
    GlobalAveragePooling1D, Embedding, Add, Input
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-06-06 14:10:38.747147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749219038.979469      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749219039.045617      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----- 0. GLOBAL CONSTANTS AND KEYPOINT DEFINITIONS -----
KEYPOINT_NAMES = [
    'Nose', 'Left Eye', 'Right Eye', 'Left Ear', 'Right Ear',
    'Left Shoulder', 'Right Shoulder', 'Left Elbow', 'Right Elbow',
    'Left Wrist', 'Right Wrist', 'Left Hip', 'Right Hip',
    'Left Knee', 'Right Knee', 'Left Ankle', 'Right Ankle'
]
SORTED_KEYPOINT_NAMES = sorted(KEYPOINT_NAMES)
KEYPOINT_DICT = {name: i for i, name in enumerate(SORTED_KEYPOINT_NAMES)}
NUM_KEYPOINTS = len(KEYPOINT_DICT)

print("--- Initializing Keypoint Definitions ---")
print(f"SORTED_KEYPOINT_NAMES (used for ordering): {SORTED_KEYPOINT_NAMES}")
print(f"Generated KEYPOINT_DICT: {KEYPOINT_DICT}")
print(f"NUM_KEYPOINTS: {NUM_KEYPOINTS}")
if NUM_KEYPOINTS != 17:
    print(f"WARNING: NUM_KEYPOINTS is {NUM_KEYPOINTS}, expected 17.")
print("----------------------------------------")
# Out:
# --- Initializing Keypoint Definitions ---
# SORTED_KEYPOINT_NAMES (used for ordering): ['Left Ankle', 'Left Ear', 'Left Elbow', 'Left Eye', 'Left Hip', 'Left Knee', 'Left Shoulder', 'Left Wrist', 'Nose', 'Right Ankle', 'Right Ear', 'Right Elbow', 'Right Eye', 'Right Hip', 'Right Knee', 'Right Shoulder', 'Right Wrist']
# Generated KEYPOINT_DICT: {'Left Ankle': 0, 'Left Ear': 1, 'Left Elbow': 2, 'Left Eye': 3, 'Left Hip': 4, 'Left Knee': 5, 'Left Shoulder': 6, 'Left Wrist': 7, 'Nose': 8, 'Right Ankle': 9, 'Right Ear': 10, 'Right Elbow': 11, 'Right Eye': 12, 'Right Hip': 13, 'Right Knee': 14, 'Right Shoulder': 15, 'Right Wrist': 16}
# NUM_KEYPOINTS: 17
# ----------------------------------------

# %%
# ----- 1. HELPER FUNCTION FOR KEYPOINT INDICES -----
def get_kpt_indices(keypoint_name):
    if keypoint_name not in KEYPOINT_DICT:
        available_keys = list(KEYPOINT_DICT.keys())
        similar_keys = [k for k in available_keys if keypoint_name.lower() in k.lower() or k.lower() in keypoint_name.lower()]
        error_msg = f"Keypoint name '{keypoint_name}' not found in KEYPOINT_DICT. "
        error_msg += f"Available keys: {available_keys}. "
        if similar_keys: error_msg += f"Did you mean: {similar_keys}? "
        raise ValueError(error_msg)
    kp_idx = KEYPOINT_DICT[keypoint_name]
    return kp_idx * 3, kp_idx * 3 + 1, kp_idx * 3 + 2

# %%
# ----- 2. SKELETON NORMALIZATION FUNCTION -----
def normalize_skeleton(sequence_data, min_confidence=0.3):
    normalized_sequence = np.copy(sequence_data)
    ref_kp_names = {
        'ls': 'Left Shoulder', 'rs': 'Right Shoulder',
        'lh': 'Left Hip', 'rh': 'Right Hip'
    }
    for ref_kp_key, ref_kp_name_val in ref_kp_names.items():
        if ref_kp_name_val not in KEYPOINT_DICT:
            print(f"WARNING in normalize_skeleton: Ref keypoint '{ref_kp_name_val}' not in KEYPOINT_DICT.")

    for t in range(sequence_data.shape[0]):
        frame_data = sequence_data[t, :]
        current_frame_normalized = np.copy(frame_data)
        try:
            ls_x_idx, ls_y_idx, ls_c_idx = get_kpt_indices(ref_kp_names['ls'])
            rs_x_idx, rs_y_idx, rs_c_idx = get_kpt_indices(ref_kp_names['rs'])
            lh_x_idx, lh_y_idx, lh_c_idx = get_kpt_indices(ref_kp_names['lh'])
            rh_x_idx, rh_y_idx, rh_c_idx = get_kpt_indices(ref_kp_names['rh'])
        except ValueError:
            normalized_sequence[t, :] = frame_data; continue

        ls_x, ls_y, ls_c = frame_data[ls_x_idx], frame_data[ls_y_idx], frame_data[ls_c_idx]
        rs_x, rs_y, rs_c = frame_data[rs_x_idx], frame_data[rs_y_idx], frame_data[rs_c_idx]
        lh_x, lh_y, lh_c = frame_data[lh_x_idx], frame_data[lh_y_idx], frame_data[lh_c_idx]
        rh_x, rh_y, rh_c = frame_data[rh_x_idx], frame_data[rh_y_idx], frame_data[rh_c_idx]

        mid_shoulder_x, mid_shoulder_y = np.nan, np.nan
        valid_ls, valid_rs = ls_c > min_confidence, rs_c > min_confidence
        if valid_ls and valid_rs: mid_shoulder_x, mid_shoulder_y = (ls_x + rs_x) / 2, (ls_y + rs_y) / 2
        elif valid_ls: mid_shoulder_x, mid_shoulder_y = ls_x, ls_y
        elif valid_rs: mid_shoulder_x, mid_shoulder_y = rs_x, rs_y

        mid_hip_x, mid_hip_y = np.nan, np.nan
        valid_lh, valid_rh = lh_c > min_confidence, rh_c > min_confidence
        if valid_lh and valid_rh: mid_hip_x, mid_hip_y = (lh_x + rh_x) / 2, (lh_y + rh_y) / 2
        elif valid_lh: mid_hip_x, mid_hip_y = lh_x, lh_y
        elif valid_rh: mid_hip_x, mid_hip_y = rh_x, rh_y

        if np.isnan(mid_hip_x) or np.isnan(mid_hip_y):
            normalized_sequence[t, :] = frame_data; continue

        reference_height = np.nan
        if not np.isnan(mid_shoulder_y) and not np.isnan(mid_hip_y):
            reference_height = np.abs(mid_shoulder_y - mid_hip_y)

        perform_scaling = not (np.isnan(reference_height) or reference_height < 1e-5)

        for kp_i in range(NUM_KEYPOINTS):
            x_i_col, y_i_col = kp_i * 3, kp_i * 3 + 1
            current_frame_normalized[x_i_col] -= mid_hip_x
            current_frame_normalized[y_i_col] -= mid_hip_y
            if perform_scaling:
                current_frame_normalized[x_i_col] /= reference_height
                current_frame_normalized[y_i_col] /= reference_height
        normalized_sequence[t, :] = current_frame_normalized
    return normalized_sequence

# %%
# ----- 3. DATA LOADING FUNCTION  -----
def load_dataset(data_path, expected_shape_template=(30, None), normalize=True, min_confidence_norm=0.3):
    if NUM_KEYPOINTS is None or NUM_KEYPOINTS == 0:
        raise ValueError("NUM_KEYPOINTS is not set or is zero.")
    expected_shape = (expected_shape_template[0], NUM_KEYPOINTS * 3)
    
    X, y = [], []
    npy_filepaths = []

    print(f"Loading data from: {data_path}, expecting shape {expected_shape} for .npy files.")
    for label_name, label_val in [('no_fall', 0), ('fall', 1)]:
        folder = os.path.join(data_path, label_name)
        if not os.path.isdir(folder):
            print(f"Warning: Subfolder not found for label '{label_name}': {folder}")
            continue
        
        files_in_folder = glob(os.path.join(folder, "*.npy"))
        print(f"Found {len(files_in_folder)} .npy files in {folder}")
        
        loaded_count_for_label = 0
        for file_path_str in files_in_folder:
            try:
                arr = np.load(file_path_str)
            except Exception as e:
                print(f"Warning: Could not load file {file_path_str}: {e}")
                continue

            if arr.shape == expected_shape:
                if normalize:
                    arr_normalized = normalize_skeleton(arr, min_confidence=min_confidence_norm)
                    if np.isnan(arr_normalized).any():
                        arr_normalized = np.nan_to_num(arr_normalized, nan=0.0, posinf=0.0, neginf=0.0)
                    X.append(arr_normalized)
                else:
                    X.append(arr)
                y.append(label_val)
                npy_filepaths.append(file_path_str)
                loaded_count_for_label += 1
            else:
                print(f"Warning: Skipping file {file_path_str} due to incorrect shape: {arr.shape}. Expected: {expected_shape}")
        print(f"Successfully loaded {loaded_count_for_label} samples for label '{label_name}'.")

    if not X:
        print(f"Critical Warning: No data was loaded from {data_path}.")
        return np.array([]), np.array([]), []
        
    return np.array(X), np.array(y), npy_filepaths

# %%
# --- Transformer Encoder Block ---
def transformer_encoder_block(inputs, d_model, num_heads, ff_dim, dropout_rate=0.1, name_prefix=""):
    attention_output = MultiHeadAttention(
        num_heads=num_heads, key_dim=d_model // num_heads, dropout=dropout_rate,
        name=f"{name_prefix}_mha"
    )(inputs, inputs, inputs)
    attention_output = Dropout(dropout_rate, name=f"{name_prefix}_mha_dropout")(attention_output)
    out1 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm1")(inputs + attention_output)

    ffn_output = Dense(ff_dim, activation="relu", name=f"{name_prefix}_ffn_dense1")(out1)
    ffn_output = Dense(d_model, name=f"{name_prefix}_ffn_dense2")(ffn_output)
    ffn_output = Dropout(dropout_rate, name=f"{name_prefix}_ffn_dropout")(ffn_output)
    out2 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm2")(out1 + ffn_output)
    return out2

# --- Positional Embedding Layer (Learned) ---
def get_positional_embedding(seq_len, d_model, name_prefix=""):
    positions = tf.range(start=0, limit=seq_len, delta=1)
    position_embeddings_2d = Embedding(input_dim=seq_len, output_dim=d_model, name=f"{name_prefix}_pos_embed")(positions)
    position_embeddings_3d = tf.expand_dims(position_embeddings_2d, axis=0)
    return position_embeddings_3d

# %%
# --- Model Creation Function ---
def create_transformer_classifier(
    input_shape,
    num_encoder_blocks=2,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    projection_dim=None,
    final_dense_units=32,
    dropout_rate=0.1,
    learning_rate=0.0005
):
    timesteps, num_features = input_shape
    if projection_dim is None: projection_dim = d_model

    inputs = Input(shape=input_shape, name="input_features")
    projected_x = Dense(projection_dim, name="feature_projection")(inputs)
    positional_embeddings = get_positional_embedding(timesteps, projection_dim, name_prefix="pos_enc")
    x = Add(name="add_positional_encoding")([projected_x, positional_embeddings])
    x = Dropout(dropout_rate, name="input_dropout_after_pos_enc")(x)

    for i in range(num_encoder_blocks):
        x = transformer_encoder_block(x, projection_dim, num_heads, ff_dim, dropout_rate, name_prefix=f"encoder_block_{i+1}")

    x = GlobalAveragePooling1D(name="global_avg_pooling")(x)
    x = Dropout(dropout_rate, name="dropout_after_pooling")(x)
    x = Dense(final_dense_units, activation="relu", name="final_dense_1")(x)
    x = Dropout(dropout_rate / 2, name="dropout_final_dense")(x)
    outputs = Dense(1, activation="sigmoid", name="output_sigmoid")(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    # ใช้ tf.keras.metrics.F1Score
    # สำหรับ binary classification ที่มี output เป็น sigmoid และ target เป็น 0 หรือ 1,
    # Keras F1Score จะคำนวณ F1 ของ positive class (1) โดย default
    # ถ้าต้องการ Macro F1 (เฉลี่ย F1 ของ class 0 และ class 1)
    f1_macro_metric = tf.keras.metrics.F1Score(
        average='macro', # คำนวณ F1 สำหรับแต่ละคลาสแล้วเฉลี่ย
        threshold=0.5,   # Threshold สำหรับการแปลง probability เป็น class label
        name='f1_macro'  # ชื่อนี้จะปรากฏใน history.history
    )
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), 
                  loss='binary_crossentropy',
                  metrics=['accuracy', f1_macro_metric]) # เพิ่ม f1_macro_metric
    return model

# %%
#--- Load Dataset ---

# Paths 
base_train = '/kaggle/input/fall-dataset60/train'
base_val   = '/kaggle/input/fall-dataset60/val'
base_test  = '/kaggle/input/fall-dataset60/test'

# ----- Parameters -----
TIMESTEPS = 60
EXPECTED_SHAPE_TEMPLATE = (TIMESTEPS, None)
MIN_CONF_NORM = 0.2

print("\n--- Loading Training Data ---")
X_train_orig, y_train_orig, train_npy_filepaths = load_dataset(
    base_train, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Validation Data ---")
X_val_orig, y_val_orig, val_npy_filepaths = load_dataset(
    base_val, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Test Data ---")
X_test_orig, y_test_orig, test_npy_filepaths = load_dataset(
    base_test, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)

if X_train_orig.size == 0:
    print("FATAL ERROR: Training data is empty.")
else:
    if len(X_train_orig) == len(train_npy_filepaths): print(f"Training set: Loaded {len(X_train_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Training set! Samples: {len(X_train_orig)}, Filepaths: {len(train_npy_filepaths)}.")

if X_val_orig.size > 0:
    if len(X_val_orig) == len(val_npy_filepaths): print(f"Validation set: Loaded {len(X_val_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Validation set! Samples: {len(X_val_orig)}, Filepaths: {len(val_npy_filepaths)}.")
else: print("Validation data is empty or was not loaded.")

if X_test_orig.size > 0:
    if len(X_test_orig) == len(test_npy_filepaths): print(f"Test set: Loaded {len(X_test_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Test set! Samples: {len(X_test_orig)}, Filepaths: {len(test_npy_filepaths)}.")
else: print("Test data is empty or was not loaded.")
    
print(f"\nShapes after loading:")
print(f"Train: X={X_train_orig.shape if X_train_orig.size > 0 else 'Empty'}, y={y_train_orig.shape if y_train_orig.size > 0 else 'Empty'}")
print(f"Val:   X={X_val_orig.shape if X_val_orig.size > 0 else 'Empty'}, y={y_val_orig.shape if y_val_orig.size > 0 else 'Empty'}")
print(f"Test:  X={X_test_orig.shape if X_test_orig.size > 0 else 'Empty'}, y={y_test_orig.shape if y_test_orig.size > 0 else 'Empty'}")

if 'NUM_KEYPOINTS' in locals() and isinstance(NUM_KEYPOINTS, int) and NUM_KEYPOINTS > 0:
    transformer_input_shape = (TIMESTEPS, NUM_KEYPOINTS * 3)
    print(f"\nTransformer Input Shape: {transformer_input_shape}")
else:
    print("\nERROR: NUM_KEYPOINTS not defined correctly. Cannot determine Transformer Input Shape.")
    transformer_input_shape = (TIMESTEPS, -1)
# Out:
# --- Loading Training Data ---
# Loading data from: /kaggle/input/fall-dataset60/train, expecting shape (60, 51) for .npy files.
# Found 5953 .npy files in /kaggle/input/fall-dataset60/train/no_fall
# Successfully loaded 5953 samples for label 'no_fall'.
# Found 5564 .npy files in /kaggle/input/fall-dataset60/train/fall
# Successfully loaded 5564 samples for label 'fall'.
#
# --- Loading Validation Data ---
# Loading data from: /kaggle/input/fall-dataset60/val, expecting shape (60, 51) for .npy files.
# Found 1276 .npy files in /kaggle/input/fall-dataset60/val/no_fall
# Successfully loaded 1276 samples for label 'no_fall'.
# Found 1192 .npy files in /kaggle/input/fall-dataset60/val/fall
# Successfully loaded 1192 samples for label 'fall'.
#
# --- Loading Test Data ---
# Loading data from: /kaggle/input/fall-dataset60/test, expecting shape (60, 51) for .npy files.
# Found 1276 .npy files in /kaggle/input/fall-dataset60/test/no_fall
# Successfully loaded 1276 samples for label 'no_fall'.
# Found 1193 .npy files in /kaggle/input/fall-dataset60/test/fall
# Successfully loaded 1193 samples for label 'fall'.
# Training set: Loaded 11517 samples and filepaths.
# Validation set: Loaded 2468 samples and filepaths.
# Test set: Loaded 2469 samples and filepaths.
#
# Shapes after loading:
# Train: X=(11517, 60, 51), y=(11517,)
# Val:   X=(2468, 60, 51), y=(2468,)
# Test:  X=(2469, 60, 51), y=(2469,)
#
# Transformer Input Shape: (60, 51)

# %%
# ----- Model Parameters -----
NUM_ENCODER_BLOCKS = 3
D_MODEL = 64
NUM_HEADS = 4
FF_DIM = D_MODEL * 2
PROJECTION_DIM = D_MODEL
FINAL_DENSE_UNITS = 32
DROPOUT_RATE = 0.1
LEARNING_RATE = 0.0001

# ----- Cross-Validation -----
N_SPLITS_CV = 5
EPOCHS_CV = 60
PATIENCE_VAL = 10
BATCH_SIZE_CV = 32
cv_accuracies, cv_losses, cv_f1_macros = [], [], []
fold_no = 1

print(f"\n--- Starting {N_SPLITS_CV}-Fold Cross-Validation with Transformer Classifier ---")
if X_train_orig.shape[0] > 0 and y_train_orig.shape[0] >= N_SPLITS_CV:
    skf = StratifiedKFold(n_splits=N_SPLITS_CV, shuffle=True, random_state=42)
    for train_idx, val_idx in skf.split(X_train_orig, y_train_orig):
        print(f"--- Fold {fold_no}/{N_SPLITS_CV} ---")
        X_cv_train, X_cv_val = X_train_orig[train_idx], X_train_orig[val_idx]
        y_cv_train_1d, y_cv_val_1d = y_train_orig[train_idx], y_train_orig[val_idx] # Keep 1D versions if needed elsewhere

        # --- RESHAPE y_true for Keras F1Score metric ---
        y_cv_train_2d = y_cv_train_1d.reshape(-1, 1)
        y_cv_val_2d = y_cv_val_1d.reshape(-1, 1)
        
        cv_model = create_transformer_classifier(
            input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
            d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
            projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
            dropout_rate=DROPOUT_RATE, learning_rate=LEARNING_RATE
        )
        
        early_stopping_cv = EarlyStopping(monitor='val_f1_macro', patience=PATIENCE_VAL, verbose=1, mode='max', restore_best_weights=True)
        
        history_cv = cv_model.fit(X_cv_train, y_cv_train_2d, # Use 2D y_true for training
                                  epochs=EPOCHS_CV, batch_size=BATCH_SIZE_CV, 
                                  validation_data=(X_cv_val, y_cv_val_2d), # Use 2D y_true for validation
                                  callbacks=[early_stopping_cv],
                                  verbose=1) 
        
        # Evaluate with 2D y_true
        eval_results_cv = cv_model.evaluate(X_cv_val, y_cv_val_2d, verbose=0)
        loss, accuracy, f1_macro = eval_results_cv[0], eval_results_cv[1], eval_results_cv[2]

        print(f"Fold {fold_no} - CV Val Loss: {loss:.4f}, CV Val Acc: {accuracy:.4f}, CV Val F1-Macro: {f1_macro:.4f}")
        cv_losses.append(loss); cv_accuracies.append(accuracy); cv_f1_macros.append(f1_macro)
        fold_no += 1

    if cv_accuracies:
        print("\n--- Cross-Validation Summary ---")
        print(f"Average CV Loss: {np.mean(cv_losses):.4f} (+/- {np.std(cv_losses):.4f})")
        print(f"Average CV Accuracy: {np.mean(cv_accuracies):.4f} (+/- {np.std(cv_accuracies):.4f})")
        if cv_f1_macros:
             print(f"Average CV F1-Macro: {np.mean(cv_f1_macros):.4f} (+/- {np.std(cv_f1_macros):.4f})")
    else: 
        print("Cross-validation did not produce results (or was skipped).")
else:
    print(f"Skipping CV: Training data empty or too few samples for {N_SPLITS_CV} splits.")
# Out:
# --- Starting 5-Fold Cross-Validation with Transformer Classifier ---
# --- Fold 1/5 ---
# I0000 00:00:1749219303.449123      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749219303.449860      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749219319.186243      96 service.cc:148] XLA service 0x7daa2c005640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749219319.186882      96 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749219319.186905      96 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749219320.497443      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  21/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5080 - f1_macro: 0.4724 - loss: 0.7325
# I0000 00:00:1749219329.096073      96 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.6732 - f1_macro: 0.6554 - loss: 0.5978 - val_accuracy: 0.7912 - val_f1_macro: 0.7522 - val_loss: 0.4485
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8000 - f1_macro: 0.7822 - loss: 0.4529 - val_accuracy: 0.8346 - val_f1_macro: 0.8107 - val_loss: 0.4071
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8266 - f1_macro: 0.8114 - loss: 0.3977 - val_accuracy: 0.8542 - val_f1_macro: 0.8423 - val_loss: 0.3641
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8543 - f1_macro: 0.8432 - loss: 0.3561 - val_accuracy: 0.8672 - val_f1_macro: 0.8562 - val_loss: 0.3439
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8596 - f1_macro: 0.8498 - loss: 0.3428 - val_accuracy: 0.8707 - val_f1_macro: 0.8567 - val_loss: 0.3484
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8650 - f1_macro: 0.8576 - loss: 0.3298 - val_accuracy: 0.8806 - val_f1_macro: 0.8726 - val_loss: 0.3357
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8803 - f1_macro: 0.8735 - loss: 0.3055 - val_accuracy: 0.8872 - val_f1_macro: 0.8800 - val_loss: 0.3075
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8818 - f1_macro: 0.8725 - loss: 0.2961 - val_accuracy: 0.8872 - val_f1_macro: 0.8811 - val_loss: 0.3037
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8862 - f1_macro: 0.8828 - loss: 0.2930 - val_accuracy: 0.8837 - val_f1_macro: 0.8726 - val_loss: 0.3185
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8950 - f1_macro: 0.8885 - loss: 0.2739 - val_accuracy: 0.8850 - val_f1_macro: 0.8775 - val_loss: 0.3112
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8897 - f1_macro: 0.8842 - loss: 0.2804 - val_accuracy: 0.8824 - val_f1_macro: 0.8699 - val_loss: 0.3446
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8980 - f1_macro: 0.8914 - loss: 0.2634 - val_accuracy: 0.8832 - val_f1_macro: 0.8714 - val_loss: 0.3174
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8979 - f1_macro: 0.8914 - loss: 0.2629 - val_accuracy: 0.8902 - val_f1_macro: 0.8824 - val_loss: 0.2964
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8992 - f1_macro: 0.8924 - loss: 0.2630 - val_accuracy: 0.8863 - val_f1_macro: 0.8765 - val_loss: 0.3021
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9019 - f1_macro: 0.8981 - loss: 0.2513 - val_accuracy: 0.8932 - val_f1_macro: 0.8857 - val_loss: 0.2860
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8980 - f1_macro: 0.8927 - loss: 0.2519 - val_accuracy: 0.8872 - val_f1_macro: 0.8767 - val_loss: 0.2970
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9082 - f1_macro: 0.9023 - loss: 0.2414 - val_accuracy: 0.8850 - val_f1_macro: 0.8768 - val_loss: 0.2848
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9146 - f1_macro: 0.9116 - loss: 0.2329 - val_accuracy: 0.8950 - val_f1_macro: 0.8856 - val_loss: 0.2900
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9072 - f1_macro: 0.9002 - loss: 0.2366 - val_accuracy: 0.8954 - val_f1_macro: 0.8868 - val_loss: 0.2822
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9137 - f1_macro: 0.9091 - loss: 0.2271 - val_accuracy: 0.8980 - val_f1_macro: 0.8893 - val_loss: 0.2878
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9113 - f1_macro: 0.9066 - loss: 0.2277 - val_accuracy: 0.8924 - val_f1_macro: 0.8817 - val_loss: 0.3066
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9180 - f1_macro: 0.9132 - loss: 0.2178 - val_accuracy: 0.8971 - val_f1_macro: 0.8883 - val_loss: 0.2867
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9159 - f1_macro: 0.9119 - loss: 0.2166 - val_accuracy: 0.8876 - val_f1_macro: 0.8770 - val_loss: 0.3083
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9204 - f1_macro: 0.9152 - loss: 0.2092 - val_accuracy: 0.8950 - val_f1_macro: 0.8893 - val_loss: 0.2769
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9241 - f1_macro: 0.9199 - loss: 0.2033 - val_accuracy: 0.8950 - val_f1_macro: 0.8855 - val_loss: 0.2871
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9158 - f1_macro: 0.9117 - loss: 0.2082 - val_accuracy: 0.8980 - val_f1_macro: 0.8886 - val_loss: 0.2957
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9219 - f1_macro: 0.9182 - loss: 0.2061 - val_accuracy: 0.8941 - val_f1_macro: 0.8875 - val_loss: 0.2882
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9215 - f1_macro: 0.9190 - loss: 0.2088 - val_accuracy: 0.9054 - val_f1_macro: 0.8978 - val_loss: 0.2718
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9244 - f1_macro: 0.9203 - loss: 0.1953 - val_accuracy: 0.9062 - val_f1_macro: 0.8998 - val_loss: 0.2681
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9276 - f1_macro: 0.9251 - loss: 0.1913 - val_accuracy: 0.8989 - val_f1_macro: 0.8907 - val_loss: 0.2801
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9292 - f1_macro: 0.9264 - loss: 0.1890 - val_accuracy: 0.8889 - val_f1_macro: 0.8758 - val_loss: 0.3148
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9271 - f1_macro: 0.9229 - loss: 0.1885 - val_accuracy: 0.9093 - val_f1_macro: 0.9032 - val_loss: 0.2554
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9311 - f1_macro: 0.9272 - loss: 0.1810 - val_accuracy: 0.9071 - val_f1_macro: 0.8991 - val_loss: 0.2644
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9278 - f1_macro: 0.9255 - loss: 0.1952 - val_accuracy: 0.9110 - val_f1_macro: 0.9034 - val_loss: 0.2646
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9354 - f1_macro: 0.9327 - loss: 0.1769 - val_accuracy: 0.9036 - val_f1_macro: 0.8956 - val_loss: 0.2687
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9405 - f1_macro: 0.9375 - loss: 0.1616 - val_accuracy: 0.9158 - val_f1_macro: 0.9102 - val_loss: 0.2394
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9353 - f1_macro: 0.9319 - loss: 0.1736 - val_accuracy: 0.9115 - val_f1_macro: 0.9042 - val_loss: 0.2646
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9335 - f1_macro: 0.9308 - loss: 0.1761 - val_accuracy: 0.9097 - val_f1_macro: 0.9024 - val_loss: 0.2670
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9359 - f1_macro: 0.9332 - loss: 0.1697 - val_accuracy: 0.9106 - val_f1_macro: 0.9032 - val_loss: 0.2725
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9417 - f1_macro: 0.9387 - loss: 0.1621 - val_accuracy: 0.9102 - val_f1_macro: 0.9040 - val_loss: 0.2594
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9402 - f1_macro: 0.9365 - loss: 0.1667 - val_accuracy: 0.9158 - val_f1_macro: 0.9102 - val_loss: 0.2466
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9410 - f1_macro: 0.9384 - loss: 0.1498 - val_accuracy: 0.9084 - val_f1_macro: 0.9030 - val_loss: 0.2592
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9402 - f1_macro: 0.9377 - loss: 0.1604 - val_accuracy: 0.9136 - val_f1_macro: 0.9094 - val_loss: 0.2600
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9416 - f1_macro: 0.9396 - loss: 0.1603 - val_accuracy: 0.9106 - val_f1_macro: 0.9032 - val_loss: 0.2641
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9470 - f1_macro: 0.9440 - loss: 0.1463 - val_accuracy: 0.9188 - val_f1_macro: 0.9140 - val_loss: 0.2350
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9445 - f1_macro: 0.9423 - loss: 0.1450 - val_accuracy: 0.9102 - val_f1_macro: 0.9045 - val_loss: 0.2642
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9434 - f1_macro: 0.9412 - loss: 0.1493 - val_accuracy: 0.9175 - val_f1_macro: 0.9130 - val_loss: 0.2408
# Epoch 48/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9488 - f1_macro: 0.9460 - loss: 0.1415 - val_accuracy: 0.9175 - val_f1_macro: 0.9115 - val_loss: 0.2604
# Epoch 49/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9523 - f1_macro: 0.9503 - loss: 0.1315 - val_accuracy: 0.9115 - val_f1_macro: 0.9040 - val_loss: 0.2823
# Epoch 50/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9475 - f1_macro: 0.9455 - loss: 0.1349 - val_accuracy: 0.9175 - val_f1_macro: 0.9123 - val_loss: 0.2579
# Epoch 51/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9505 - f1_macro: 0.9486 - loss: 0.1341 - val_accuracy: 0.9149 - val_f1_macro: 0.9083 - val_loss: 0.2593
# Epoch 52/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9488 - f1_macro: 0.9457 - loss: 0.1432 - val_accuracy: 0.9214 - val_f1_macro: 0.9165 - val_loss: 0.2483
# Epoch 53/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9478 - f1_macro: 0.9450 - loss: 0.1288 - val_accuracy: 0.9253 - val_f1_macro: 0.9215 - val_loss: 0.2388
# Epoch 54/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9565 - f1_macro: 0.9547 - loss: 0.1205 - val_accuracy: 0.9119 - val_f1_macro: 0.9047 - val_loss: 0.2705
# Epoch 55/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9560 - f1_macro: 0.9538 - loss: 0.1340 - val_accuracy: 0.9193 - val_f1_macro: 0.9144 - val_loss: 0.2546
# Epoch 56/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9515 - f1_macro: 0.9491 - loss: 0.1311 - val_accuracy: 0.9284 - val_f1_macro: 0.9240 - val_loss: 0.2348
# Epoch 57/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9521 - f1_macro: 0.9493 - loss: 0.1286 - val_accuracy: 0.9219 - val_f1_macro: 0.9167 - val_loss: 0.2450
# Epoch 58/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9525 - f1_macro: 0.9495 - loss: 0.1298 - val_accuracy: 0.9275 - val_f1_macro: 0.9229 - val_loss: 0.2411
# Epoch 59/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9553 - f1_macro: 0.9536 - loss: 0.1202 - val_accuracy: 0.9089 - val_f1_macro: 0.9010 - val_loss: 0.2808
# Epoch 60/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9552 - f1_macro: 0.9531 - loss: 0.1234 - val_accuracy: 0.9258 - val_f1_macro: 0.9208 - val_loss: 0.2469
# Restoring model weights from the end of the best epoch: 56.
# Fold 1 - CV Val Loss: 0.2348, CV Val Acc: 0.9284, CV Val F1-Macro: 0.9240
# --- Fold 2/5 ---
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7036 - f1_macro: 0.6743 - loss: 0.5764 - val_accuracy: 0.7856 - val_f1_macro: 0.7557 - val_loss: 0.4765
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8096 - f1_macro: 0.7877 - loss: 0.4315 - val_accuracy: 0.8433 - val_f1_macro: 0.8308 - val_loss: 0.3933
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8494 - f1_macro: 0.8392 - loss: 0.3683 - val_accuracy: 0.8585 - val_f1_macro: 0.8459 - val_loss: 0.3737
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8645 - f1_macro: 0.8555 - loss: 0.3415 - val_accuracy: 0.8594 - val_f1_macro: 0.8494 - val_loss: 0.3596
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8713 - f1_macro: 0.8648 - loss: 0.3342 - val_accuracy: 0.8798 - val_f1_macro: 0.8733 - val_loss: 0.3232
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8757 - f1_macro: 0.8706 - loss: 0.3256 - val_accuracy: 0.8780 - val_f1_macro: 0.8716 - val_loss: 0.3324
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8877 - f1_macro: 0.8824 - loss: 0.2990 - val_accuracy: 0.8798 - val_f1_macro: 0.8705 - val_loss: 0.3019
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8858 - f1_macro: 0.8822 - loss: 0.3016 - val_accuracy: 0.8811 - val_f1_macro: 0.8721 - val_loss: 0.3181
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8787 - f1_macro: 0.8719 - loss: 0.3062 - val_accuracy: 0.8863 - val_f1_macro: 0.8796 - val_loss: 0.3081
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8926 - f1_macro: 0.8874 - loss: 0.2839 - val_accuracy: 0.8824 - val_f1_macro: 0.8740 - val_loss: 0.3073
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8944 - f1_macro: 0.8899 - loss: 0.2760 - val_accuracy: 0.8780 - val_f1_macro: 0.8674 - val_loss: 0.3181
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8969 - f1_macro: 0.8917 - loss: 0.2665 - val_accuracy: 0.8928 - val_f1_macro: 0.8887 - val_loss: 0.2953
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8943 - f1_macro: 0.8895 - loss: 0.2751 - val_accuracy: 0.8889 - val_f1_macro: 0.8806 - val_loss: 0.2894
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9004 - f1_macro: 0.8954 - loss: 0.2539 - val_accuracy: 0.8924 - val_f1_macro: 0.8851 - val_loss: 0.2844
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9065 - f1_macro: 0.9025 - loss: 0.2416 - val_accuracy: 0.8989 - val_f1_macro: 0.8951 - val_loss: 0.2899
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9105 - f1_macro: 0.9064 - loss: 0.2383 - val_accuracy: 0.8967 - val_f1_macro: 0.8887 - val_loss: 0.2852
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9110 - f1_macro: 0.9063 - loss: 0.2355 - val_accuracy: 0.8997 - val_f1_macro: 0.8930 - val_loss: 0.2718
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9168 - f1_macro: 0.9127 - loss: 0.2200 - val_accuracy: 0.8989 - val_f1_macro: 0.8935 - val_loss: 0.2758
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9196 - f1_macro: 0.9155 - loss: 0.2213 - val_accuracy: 0.9036 - val_f1_macro: 0.8970 - val_loss: 0.2671
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9181 - f1_macro: 0.9133 - loss: 0.2160 - val_accuracy: 0.9071 - val_f1_macro: 0.9004 - val_loss: 0.2733
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9211 - f1_macro: 0.9180 - loss: 0.2113 - val_accuracy: 0.9141 - val_f1_macro: 0.9095 - val_loss: 0.2599
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9209 - f1_macro: 0.9188 - loss: 0.2090 - val_accuracy: 0.9097 - val_f1_macro: 0.9040 - val_loss: 0.2564
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9237 - f1_macro: 0.9212 - loss: 0.2046 - val_accuracy: 0.9119 - val_f1_macro: 0.9064 - val_loss: 0.2475
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9274 - f1_macro: 0.9233 - loss: 0.1949 - val_accuracy: 0.9084 - val_f1_macro: 0.9040 - val_loss: 0.2463
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9238 - f1_macro: 0.9185 - loss: 0.1993 - val_accuracy: 0.9062 - val_f1_macro: 0.8997 - val_loss: 0.2562
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9284 - f1_macro: 0.9234 - loss: 0.1861 - val_accuracy: 0.9141 - val_f1_macro: 0.9116 - val_loss: 0.2502
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9280 - f1_macro: 0.9237 - loss: 0.1915 - val_accuracy: 0.9136 - val_f1_macro: 0.9083 - val_loss: 0.2428
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9334 - f1_macro: 0.9295 - loss: 0.1800 - val_accuracy: 0.9128 - val_f1_macro: 0.9105 - val_loss: 0.2469
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9275 - f1_macro: 0.9246 - loss: 0.1907 - val_accuracy: 0.9076 - val_f1_macro: 0.9020 - val_loss: 0.2558
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9336 - f1_macro: 0.9303 - loss: 0.1802 - val_accuracy: 0.9106 - val_f1_macro: 0.9039 - val_loss: 0.2462
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9343 - f1_macro: 0.9307 - loss: 0.1779 - val_accuracy: 0.9171 - val_f1_macro: 0.9128 - val_loss: 0.2471
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9391 - f1_macro: 0.9372 - loss: 0.1677 - val_accuracy: 0.9076 - val_f1_macro: 0.9013 - val_loss: 0.2564
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9377 - f1_macro: 0.9339 - loss: 0.1740 - val_accuracy: 0.9158 - val_f1_macro: 0.9114 - val_loss: 0.2540
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9379 - f1_macro: 0.9342 - loss: 0.1639 - val_accuracy: 0.9158 - val_f1_macro: 0.9108 - val_loss: 0.2363
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9384 - f1_macro: 0.9359 - loss: 0.1606 - val_accuracy: 0.9219 - val_f1_macro: 0.9181 - val_loss: 0.2364
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9427 - f1_macro: 0.9396 - loss: 0.1504 - val_accuracy: 0.9093 - val_f1_macro: 0.9018 - val_loss: 0.2585
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9444 - f1_macro: 0.9428 - loss: 0.1526 - val_accuracy: 0.9158 - val_f1_macro: 0.9103 - val_loss: 0.2456
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9396 - f1_macro: 0.9380 - loss: 0.1601 - val_accuracy: 0.9184 - val_f1_macro: 0.9134 - val_loss: 0.2401
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9458 - f1_macro: 0.9438 - loss: 0.1492 - val_accuracy: 0.9162 - val_f1_macro: 0.9104 - val_loss: 0.2509
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9465 - f1_macro: 0.9445 - loss: 0.1424 - val_accuracy: 0.9136 - val_f1_macro: 0.9083 - val_loss: 0.2469
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9511 - f1_macro: 0.9487 - loss: 0.1352 - val_accuracy: 0.9123 - val_f1_macro: 0.9065 - val_loss: 0.2506
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9486 - f1_macro: 0.9464 - loss: 0.1409 - val_accuracy: 0.9214 - val_f1_macro: 0.9169 - val_loss: 0.2374
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9503 - f1_macro: 0.9486 - loss: 0.1348 - val_accuracy: 0.9180 - val_f1_macro: 0.9122 - val_loss: 0.2447
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9524 - f1_macro: 0.9497 - loss: 0.1317 - val_accuracy: 0.9175 - val_f1_macro: 0.9139 - val_loss: 0.2496
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9523 - f1_macro: 0.9504 - loss: 0.1311 - val_accuracy: 0.9149 - val_f1_macro: 0.9089 - val_loss: 0.2508
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Fold 2 - CV Val Loss: 0.2364, CV Val Acc: 0.9219, CV Val F1-Macro: 0.9181
# --- Fold 3/5 ---
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.7173 - f1_macro: 0.6785 - loss: 0.5578 - val_accuracy: 0.8046 - val_f1_macro: 0.7818 - val_loss: 0.4440
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8042 - f1_macro: 0.7868 - loss: 0.4386 - val_accuracy: 0.8259 - val_f1_macro: 0.8104 - val_loss: 0.4144
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8386 - f1_macro: 0.8275 - loss: 0.3833 - val_accuracy: 0.8532 - val_f1_macro: 0.8422 - val_loss: 0.3732
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8555 - f1_macro: 0.8479 - loss: 0.3546 - val_accuracy: 0.8558 - val_f1_macro: 0.8453 - val_loss: 0.3694
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8714 - f1_macro: 0.8649 - loss: 0.3247 - val_accuracy: 0.8619 - val_f1_macro: 0.8540 - val_loss: 0.3430
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8778 - f1_macro: 0.8699 - loss: 0.3121 - val_accuracy: 0.8728 - val_f1_macro: 0.8637 - val_loss: 0.3360
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8856 - f1_macro: 0.8788 - loss: 0.3027 - val_accuracy: 0.8706 - val_f1_macro: 0.8617 - val_loss: 0.3361
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8775 - f1_macro: 0.8691 - loss: 0.3016 - val_accuracy: 0.8823 - val_f1_macro: 0.8741 - val_loss: 0.3147
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8826 - f1_macro: 0.8790 - loss: 0.2927 - val_accuracy: 0.8693 - val_f1_macro: 0.8562 - val_loss: 0.3415
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8885 - f1_macro: 0.8825 - loss: 0.2831 - val_accuracy: 0.8749 - val_f1_macro: 0.8648 - val_loss: 0.3274
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8934 - f1_macro: 0.8886 - loss: 0.2746 - val_accuracy: 0.8780 - val_f1_macro: 0.8671 - val_loss: 0.3338
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8984 - f1_macro: 0.8934 - loss: 0.2672 - val_accuracy: 0.8806 - val_f1_macro: 0.8744 - val_loss: 0.3167
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9057 - f1_macro: 0.8996 - loss: 0.2574 - val_accuracy: 0.8849 - val_f1_macro: 0.8777 - val_loss: 0.3106
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8965 - f1_macro: 0.8894 - loss: 0.2683 - val_accuracy: 0.8789 - val_f1_macro: 0.8693 - val_loss: 0.3178
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9015 - f1_macro: 0.8959 - loss: 0.2590 - val_accuracy: 0.8754 - val_f1_macro: 0.8625 - val_loss: 0.3324
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9017 - f1_macro: 0.8946 - loss: 0.2545 - val_accuracy: 0.8836 - val_f1_macro: 0.8737 - val_loss: 0.3086
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9123 - f1_macro: 0.9067 - loss: 0.2363 - val_accuracy: 0.8888 - val_f1_macro: 0.8806 - val_loss: 0.3025
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9142 - f1_macro: 0.9099 - loss: 0.2268 - val_accuracy: 0.8880 - val_f1_macro: 0.8786 - val_loss: 0.3061
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9152 - f1_macro: 0.9115 - loss: 0.2270 - val_accuracy: 0.8936 - val_f1_macro: 0.8873 - val_loss: 0.2859
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9146 - f1_macro: 0.9102 - loss: 0.2196 - val_accuracy: 0.8910 - val_f1_macro: 0.8823 - val_loss: 0.2974
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9126 - f1_macro: 0.9080 - loss: 0.2256 - val_accuracy: 0.8958 - val_f1_macro: 0.8872 - val_loss: 0.3070
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9183 - f1_macro: 0.9149 - loss: 0.2163 - val_accuracy: 0.8988 - val_f1_macro: 0.8922 - val_loss: 0.2818
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9172 - f1_macro: 0.9119 - loss: 0.2180 - val_accuracy: 0.8975 - val_f1_macro: 0.8900 - val_loss: 0.2724
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9244 - f1_macro: 0.9205 - loss: 0.2095 - val_accuracy: 0.8962 - val_f1_macro: 0.8885 - val_loss: 0.2863
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9238 - f1_macro: 0.9200 - loss: 0.2068 - val_accuracy: 0.9032 - val_f1_macro: 0.8968 - val_loss: 0.2772
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9197 - f1_macro: 0.9142 - loss: 0.2058 - val_accuracy: 0.9045 - val_f1_macro: 0.8991 - val_loss: 0.2806
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9249 - f1_macro: 0.9221 - loss: 0.2068 - val_accuracy: 0.9027 - val_f1_macro: 0.8966 - val_loss: 0.2748
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9291 - f1_macro: 0.9255 - loss: 0.1987 - val_accuracy: 0.9032 - val_f1_macro: 0.8990 - val_loss: 0.2720
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9308 - f1_macro: 0.9274 - loss: 0.1893 - val_accuracy: 0.9071 - val_f1_macro: 0.9019 - val_loss: 0.2650
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9270 - f1_macro: 0.9230 - loss: 0.1920 - val_accuracy: 0.9014 - val_f1_macro: 0.8941 - val_loss: 0.2809
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9340 - f1_macro: 0.9300 - loss: 0.1864 - val_accuracy: 0.9014 - val_f1_macro: 0.8963 - val_loss: 0.2727
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9309 - f1_macro: 0.9279 - loss: 0.1843 - val_accuracy: 0.9079 - val_f1_macro: 0.9008 - val_loss: 0.2701
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9286 - f1_macro: 0.9251 - loss: 0.1894 - val_accuracy: 0.9032 - val_f1_macro: 0.8971 - val_loss: 0.2855
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9330 - f1_macro: 0.9306 - loss: 0.1796 - val_accuracy: 0.9045 - val_f1_macro: 0.8987 - val_loss: 0.2568
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9352 - f1_macro: 0.9332 - loss: 0.1692 - val_accuracy: 0.9106 - val_f1_macro: 0.9052 - val_loss: 0.2669
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9354 - f1_macro: 0.9309 - loss: 0.1768 - val_accuracy: 0.9092 - val_f1_macro: 0.9034 - val_loss: 0.2542
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9388 - f1_macro: 0.9359 - loss: 0.1718 - val_accuracy: 0.9110 - val_f1_macro: 0.9067 - val_loss: 0.2455
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9338 - f1_macro: 0.9316 - loss: 0.1677 - val_accuracy: 0.9053 - val_f1_macro: 0.8985 - val_loss: 0.2823
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9331 - f1_macro: 0.9313 - loss: 0.1763 - val_accuracy: 0.9184 - val_f1_macro: 0.9145 - val_loss: 0.2617
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9355 - f1_macro: 0.9321 - loss: 0.1651 - val_accuracy: 0.9071 - val_f1_macro: 0.9002 - val_loss: 0.2702
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9469 - f1_macro: 0.9455 - loss: 0.1508 - val_accuracy: 0.9045 - val_f1_macro: 0.8962 - val_loss: 0.2691
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9396 - f1_macro: 0.9371 - loss: 0.1493 - val_accuracy: 0.9158 - val_f1_macro: 0.9102 - val_loss: 0.2554
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9447 - f1_macro: 0.9418 - loss: 0.1522 - val_accuracy: 0.9166 - val_f1_macro: 0.9125 - val_loss: 0.2463
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9396 - f1_macro: 0.9357 - loss: 0.1547 - val_accuracy: 0.9171 - val_f1_macro: 0.9123 - val_loss: 0.2650
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9470 - f1_macro: 0.9437 - loss: 0.1462 - val_accuracy: 0.9214 - val_f1_macro: 0.9179 - val_loss: 0.2466
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9449 - f1_macro: 0.9421 - loss: 0.1429 - val_accuracy: 0.9201 - val_f1_macro: 0.9151 - val_loss: 0.2381
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9465 - f1_macro: 0.9439 - loss: 0.1452 - val_accuracy: 0.9197 - val_f1_macro: 0.9145 - val_loss: 0.2531
# Epoch 48/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9437 - f1_macro: 0.9413 - loss: 0.1479 - val_accuracy: 0.9175 - val_f1_macro: 0.9131 - val_loss: 0.2520
# Epoch 49/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9472 - f1_macro: 0.9455 - loss: 0.1369 - val_accuracy: 0.9227 - val_f1_macro: 0.9180 - val_loss: 0.2489
# Epoch 50/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9483 - f1_macro: 0.9463 - loss: 0.1389 - val_accuracy: 0.9188 - val_f1_macro: 0.9152 - val_loss: 0.2534
# Epoch 51/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9499 - f1_macro: 0.9482 - loss: 0.1317 - val_accuracy: 0.9227 - val_f1_macro: 0.9177 - val_loss: 0.2590
# Epoch 52/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9545 - f1_macro: 0.9532 - loss: 0.1215 - val_accuracy: 0.9197 - val_f1_macro: 0.9136 - val_loss: 0.2628
# Epoch 53/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9553 - f1_macro: 0.9535 - loss: 0.1255 - val_accuracy: 0.9271 - val_f1_macro: 0.9229 - val_loss: 0.2396
# Epoch 54/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9486 - f1_macro: 0.9470 - loss: 0.1379 - val_accuracy: 0.9227 - val_f1_macro: 0.9195 - val_loss: 0.2528
# Epoch 55/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9594 - f1_macro: 0.9580 - loss: 0.1117 - val_accuracy: 0.9244 - val_f1_macro: 0.9203 - val_loss: 0.2543
# Epoch 56/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9549 - f1_macro: 0.9524 - loss: 0.1221 - val_accuracy: 0.9244 - val_f1_macro: 0.9208 - val_loss: 0.2572
# Epoch 57/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9522 - f1_macro: 0.9513 - loss: 0.1181 - val_accuracy: 0.9201 - val_f1_macro: 0.9161 - val_loss: 0.2608
# Epoch 58/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9501 - f1_macro: 0.9475 - loss: 0.1280 - val_accuracy: 0.9218 - val_f1_macro: 0.9181 - val_loss: 0.2616
# Epoch 59/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9511 - f1_macro: 0.9494 - loss: 0.1262 - val_accuracy: 0.9236 - val_f1_macro: 0.9205 - val_loss: 0.2504
# Epoch 60/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9531 - f1_macro: 0.9506 - loss: 0.1230 - val_accuracy: 0.9284 - val_f1_macro: 0.9246 - val_loss: 0.2552
# Restoring model weights from the end of the best epoch: 60.
# Fold 3 - CV Val Loss: 0.2552, CV Val Acc: 0.9284, CV Val F1-Macro: 0.9246
# --- Fold 4/5 ---
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7159 - f1_macro: 0.6720 - loss: 0.5573 - val_accuracy: 0.8137 - val_f1_macro: 0.8065 - val_loss: 0.4519
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8109 - f1_macro: 0.7905 - loss: 0.4364 - val_accuracy: 0.8519 - val_f1_macro: 0.8375 - val_loss: 0.3552
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8326 - f1_macro: 0.8179 - loss: 0.3955 - val_accuracy: 0.8650 - val_f1_macro: 0.8530 - val_loss: 0.3340
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8550 - f1_macro: 0.8436 - loss: 0.3545 - val_accuracy: 0.8732 - val_f1_macro: 0.8646 - val_loss: 0.3287
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8572 - f1_macro: 0.8508 - loss: 0.3524 - val_accuracy: 0.8780 - val_f1_macro: 0.8712 - val_loss: 0.2986
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8693 - f1_macro: 0.8647 - loss: 0.3254 - val_accuracy: 0.8880 - val_f1_macro: 0.8817 - val_loss: 0.2823
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8728 - f1_macro: 0.8659 - loss: 0.3172 - val_accuracy: 0.8901 - val_f1_macro: 0.8851 - val_loss: 0.2827
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8749 - f1_macro: 0.8677 - loss: 0.3109 - val_accuracy: 0.8858 - val_f1_macro: 0.8803 - val_loss: 0.2818
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8811 - f1_macro: 0.8719 - loss: 0.3014 - val_accuracy: 0.8936 - val_f1_macro: 0.8901 - val_loss: 0.2666
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8828 - f1_macro: 0.8762 - loss: 0.2978 - val_accuracy: 0.9027 - val_f1_macro: 0.8986 - val_loss: 0.2543
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8864 - f1_macro: 0.8797 - loss: 0.2845 - val_accuracy: 0.8967 - val_f1_macro: 0.8945 - val_loss: 0.2665
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8876 - f1_macro: 0.8813 - loss: 0.2853 - val_accuracy: 0.9010 - val_f1_macro: 0.8970 - val_loss: 0.2563
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8982 - f1_macro: 0.8929 - loss: 0.2705 - val_accuracy: 0.9075 - val_f1_macro: 0.9042 - val_loss: 0.2412
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8946 - f1_macro: 0.8886 - loss: 0.2719 - val_accuracy: 0.9066 - val_f1_macro: 0.9022 - val_loss: 0.2458
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8995 - f1_macro: 0.8942 - loss: 0.2534 - val_accuracy: 0.9049 - val_f1_macro: 0.9032 - val_loss: 0.2440
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8938 - f1_macro: 0.8867 - loss: 0.2594 - val_accuracy: 0.9097 - val_f1_macro: 0.9050 - val_loss: 0.2354
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9084 - f1_macro: 0.9023 - loss: 0.2475 - val_accuracy: 0.9101 - val_f1_macro: 0.9071 - val_loss: 0.2297
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9073 - f1_macro: 0.9018 - loss: 0.2473 - val_accuracy: 0.9058 - val_f1_macro: 0.9026 - val_loss: 0.2428
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9096 - f1_macro: 0.9062 - loss: 0.2376 - val_accuracy: 0.9079 - val_f1_macro: 0.9043 - val_loss: 0.2474
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9077 - f1_macro: 0.9013 - loss: 0.2439 - val_accuracy: 0.9119 - val_f1_macro: 0.9080 - val_loss: 0.2283
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9198 - f1_macro: 0.9153 - loss: 0.2163 - val_accuracy: 0.9127 - val_f1_macro: 0.9089 - val_loss: 0.2218
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9173 - f1_macro: 0.9127 - loss: 0.2203 - val_accuracy: 0.9166 - val_f1_macro: 0.9141 - val_loss: 0.2262
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9157 - f1_macro: 0.9119 - loss: 0.2172 - val_accuracy: 0.9166 - val_f1_macro: 0.9123 - val_loss: 0.2157
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9222 - f1_macro: 0.9176 - loss: 0.2068 - val_accuracy: 0.9162 - val_f1_macro: 0.9124 - val_loss: 0.2126
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9205 - f1_macro: 0.9165 - loss: 0.2144 - val_accuracy: 0.9249 - val_f1_macro: 0.9224 - val_loss: 0.2000
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9219 - f1_macro: 0.9188 - loss: 0.2104 - val_accuracy: 0.9257 - val_f1_macro: 0.9212 - val_loss: 0.2035
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9241 - f1_macro: 0.9212 - loss: 0.2032 - val_accuracy: 0.9240 - val_f1_macro: 0.9203 - val_loss: 0.1992
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9246 - f1_macro: 0.9199 - loss: 0.1980 - val_accuracy: 0.9179 - val_f1_macro: 0.9163 - val_loss: 0.2181
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9216 - f1_macro: 0.9161 - loss: 0.2056 - val_accuracy: 0.9227 - val_f1_macro: 0.9203 - val_loss: 0.2014
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9305 - f1_macro: 0.9264 - loss: 0.1930 - val_accuracy: 0.9210 - val_f1_macro: 0.9176 - val_loss: 0.2093
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9304 - f1_macro: 0.9271 - loss: 0.1877 - val_accuracy: 0.9257 - val_f1_macro: 0.9233 - val_loss: 0.1946
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9301 - f1_macro: 0.9268 - loss: 0.1815 - val_accuracy: 0.9257 - val_f1_macro: 0.9230 - val_loss: 0.2083
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9365 - f1_macro: 0.9337 - loss: 0.1783 - val_accuracy: 0.9301 - val_f1_macro: 0.9278 - val_loss: 0.1962
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9381 - f1_macro: 0.9347 - loss: 0.1705 - val_accuracy: 0.9262 - val_f1_macro: 0.9230 - val_loss: 0.2056
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9314 - f1_macro: 0.9283 - loss: 0.1784 - val_accuracy: 0.9253 - val_f1_macro: 0.9222 - val_loss: 0.1998
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9403 - f1_macro: 0.9369 - loss: 0.1671 - val_accuracy: 0.9271 - val_f1_macro: 0.9249 - val_loss: 0.1898
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9407 - f1_macro: 0.9398 - loss: 0.1635 - val_accuracy: 0.9271 - val_f1_macro: 0.9251 - val_loss: 0.1969
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9383 - f1_macro: 0.9351 - loss: 0.1665 - val_accuracy: 0.9284 - val_f1_macro: 0.9260 - val_loss: 0.1993
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9364 - f1_macro: 0.9333 - loss: 0.1686 - val_accuracy: 0.9301 - val_f1_macro: 0.9272 - val_loss: 0.1930
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9394 - f1_macro: 0.9366 - loss: 0.1660 - val_accuracy: 0.9271 - val_f1_macro: 0.9246 - val_loss: 0.2015
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9420 - f1_macro: 0.9389 - loss: 0.1567 - val_accuracy: 0.9349 - val_f1_macro: 0.9327 - val_loss: 0.1888
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9408 - f1_macro: 0.9381 - loss: 0.1578 - val_accuracy: 0.9383 - val_f1_macro: 0.9366 - val_loss: 0.1798
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9379 - f1_macro: 0.9356 - loss: 0.1584 - val_accuracy: 0.9179 - val_f1_macro: 0.9169 - val_loss: 0.2293
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9386 - f1_macro: 0.9349 - loss: 0.1589 - val_accuracy: 0.9244 - val_f1_macro: 0.9210 - val_loss: 0.2048
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9439 - f1_macro: 0.9422 - loss: 0.1504 - val_accuracy: 0.9249 - val_f1_macro: 0.9217 - val_loss: 0.1942
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9466 - f1_macro: 0.9437 - loss: 0.1492 - val_accuracy: 0.9318 - val_f1_macro: 0.9295 - val_loss: 0.1863
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9452 - f1_macro: 0.9427 - loss: 0.1510 - val_accuracy: 0.9318 - val_f1_macro: 0.9285 - val_loss: 0.1922
# Epoch 48/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9522 - f1_macro: 0.9511 - loss: 0.1303 - val_accuracy: 0.9279 - val_f1_macro: 0.9277 - val_loss: 0.1975
# Epoch 49/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9457 - f1_macro: 0.9446 - loss: 0.1446 - val_accuracy: 0.9318 - val_f1_macro: 0.9288 - val_loss: 0.1873
# Epoch 50/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9519 - f1_macro: 0.9499 - loss: 0.1329 - val_accuracy: 0.9297 - val_f1_macro: 0.9272 - val_loss: 0.1846
# Epoch 51/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9505 - f1_macro: 0.9474 - loss: 0.1348 - val_accuracy: 0.9288 - val_f1_macro: 0.9260 - val_loss: 0.2039
# Epoch 52/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9532 - f1_macro: 0.9509 - loss: 0.1282 - val_accuracy: 0.9314 - val_f1_macro: 0.9283 - val_loss: 0.1975
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 42.
# Fold 4 - CV Val Loss: 0.1798, CV Val Acc: 0.9383, CV Val F1-Macro: 0.9366
# --- Fold 5/5 ---
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.6999 - f1_macro: 0.6915 - loss: 0.5633 - val_accuracy: 0.8094 - val_f1_macro: 0.7909 - val_loss: 0.4243
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8235 - f1_macro: 0.8083 - loss: 0.4193 - val_accuracy: 0.8437 - val_f1_macro: 0.8246 - val_loss: 0.3666
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8434 - f1_macro: 0.8340 - loss: 0.3820 - val_accuracy: 0.8528 - val_f1_macro: 0.8352 - val_loss: 0.3505
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8644 - f1_macro: 0.8540 - loss: 0.3432 - val_accuracy: 0.8667 - val_f1_macro: 0.8551 - val_loss: 0.3252
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8647 - f1_macro: 0.8546 - loss: 0.3338 - val_accuracy: 0.8754 - val_f1_macro: 0.8648 - val_loss: 0.3101
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8762 - f1_macro: 0.8694 - loss: 0.3202 - val_accuracy: 0.8771 - val_f1_macro: 0.8659 - val_loss: 0.3097
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8744 - f1_macro: 0.8666 - loss: 0.3144 - val_accuracy: 0.8793 - val_f1_macro: 0.8690 - val_loss: 0.2987
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8734 - f1_macro: 0.8666 - loss: 0.3136 - val_accuracy: 0.8771 - val_f1_macro: 0.8656 - val_loss: 0.3084
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8792 - f1_macro: 0.8718 - loss: 0.3082 - val_accuracy: 0.8819 - val_f1_macro: 0.8715 - val_loss: 0.2962
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8846 - f1_macro: 0.8762 - loss: 0.2961 - val_accuracy: 0.8914 - val_f1_macro: 0.8844 - val_loss: 0.2836
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8925 - f1_macro: 0.8875 - loss: 0.2810 - val_accuracy: 0.8923 - val_f1_macro: 0.8841 - val_loss: 0.2811
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8773 - f1_macro: 0.8703 - loss: 0.3005 - val_accuracy: 0.8958 - val_f1_macro: 0.8907 - val_loss: 0.2756
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8927 - f1_macro: 0.8850 - loss: 0.2770 - val_accuracy: 0.8941 - val_f1_macro: 0.8880 - val_loss: 0.2771
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8954 - f1_macro: 0.8904 - loss: 0.2710 - val_accuracy: 0.9006 - val_f1_macro: 0.8954 - val_loss: 0.2664
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8942 - f1_macro: 0.8897 - loss: 0.2700 - val_accuracy: 0.9058 - val_f1_macro: 0.9004 - val_loss: 0.2497
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8983 - f1_macro: 0.8923 - loss: 0.2654 - val_accuracy: 0.9106 - val_f1_macro: 0.9073 - val_loss: 0.2448
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9062 - f1_macro: 0.8998 - loss: 0.2524 - val_accuracy: 0.9032 - val_f1_macro: 0.8977 - val_loss: 0.2544
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9054 - f1_macro: 0.8993 - loss: 0.2517 - val_accuracy: 0.9075 - val_f1_macro: 0.9029 - val_loss: 0.2606
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9028 - f1_macro: 0.8993 - loss: 0.2480 - val_accuracy: 0.9110 - val_f1_macro: 0.9057 - val_loss: 0.2404
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9011 - f1_macro: 0.8964 - loss: 0.2486 - val_accuracy: 0.9149 - val_f1_macro: 0.9107 - val_loss: 0.2246
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9143 - f1_macro: 0.9115 - loss: 0.2313 - val_accuracy: 0.9066 - val_f1_macro: 0.9007 - val_loss: 0.2528
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9141 - f1_macro: 0.9098 - loss: 0.2233 - val_accuracy: 0.9088 - val_f1_macro: 0.9014 - val_loss: 0.2409
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9071 - f1_macro: 0.9034 - loss: 0.2380 - val_accuracy: 0.9088 - val_f1_macro: 0.9035 - val_loss: 0.2363
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9097 - f1_macro: 0.9036 - loss: 0.2368 - val_accuracy: 0.9153 - val_f1_macro: 0.9099 - val_loss: 0.2361
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9116 - f1_macro: 0.9086 - loss: 0.2233 - val_accuracy: 0.9179 - val_f1_macro: 0.9142 - val_loss: 0.2348
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9207 - f1_macro: 0.9174 - loss: 0.2141 - val_accuracy: 0.9192 - val_f1_macro: 0.9143 - val_loss: 0.2203
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9168 - f1_macro: 0.9125 - loss: 0.2172 - val_accuracy: 0.9001 - val_f1_macro: 0.8905 - val_loss: 0.2605
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9176 - f1_macro: 0.9129 - loss: 0.2185 - val_accuracy: 0.9214 - val_f1_macro: 0.9182 - val_loss: 0.2285
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9227 - f1_macro: 0.9180 - loss: 0.2057 - val_accuracy: 0.9205 - val_f1_macro: 0.9159 - val_loss: 0.2247
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9266 - f1_macro: 0.9238 - loss: 0.1962 - val_accuracy: 0.9288 - val_f1_macro: 0.9255 - val_loss: 0.2095
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9217 - f1_macro: 0.9186 - loss: 0.2040 - val_accuracy: 0.9231 - val_f1_macro: 0.9197 - val_loss: 0.2274
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9219 - f1_macro: 0.9190 - loss: 0.2070 - val_accuracy: 0.9314 - val_f1_macro: 0.9281 - val_loss: 0.2089
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9283 - f1_macro: 0.9242 - loss: 0.1873 - val_accuracy: 0.9240 - val_f1_macro: 0.9186 - val_loss: 0.2238
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9299 - f1_macro: 0.9265 - loss: 0.1855 - val_accuracy: 0.9218 - val_f1_macro: 0.9185 - val_loss: 0.2258
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9246 - f1_macro: 0.9216 - loss: 0.1990 - val_accuracy: 0.9310 - val_f1_macro: 0.9274 - val_loss: 0.2070
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9321 - f1_macro: 0.9289 - loss: 0.1831 - val_accuracy: 0.9323 - val_f1_macro: 0.9283 - val_loss: 0.2018
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9287 - f1_macro: 0.9265 - loss: 0.1814 - val_accuracy: 0.9349 - val_f1_macro: 0.9316 - val_loss: 0.1963
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9395 - f1_macro: 0.9383 - loss: 0.1647 - val_accuracy: 0.9284 - val_f1_macro: 0.9256 - val_loss: 0.2102
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9349 - f1_macro: 0.9311 - loss: 0.1750 - val_accuracy: 0.9249 - val_f1_macro: 0.9204 - val_loss: 0.2248
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9277 - f1_macro: 0.9237 - loss: 0.1872 - val_accuracy: 0.9223 - val_f1_macro: 0.9175 - val_loss: 0.2189
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9354 - f1_macro: 0.9326 - loss: 0.1690 - val_accuracy: 0.9158 - val_f1_macro: 0.9087 - val_loss: 0.2353
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9409 - f1_macro: 0.9371 - loss: 0.1705 - val_accuracy: 0.9179 - val_f1_macro: 0.9123 - val_loss: 0.2303
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9338 - f1_macro: 0.9316 - loss: 0.1751 - val_accuracy: 0.9257 - val_f1_macro: 0.9222 - val_loss: 0.2156
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9369 - f1_macro: 0.9346 - loss: 0.1648 - val_accuracy: 0.9297 - val_f1_macro: 0.9264 - val_loss: 0.2069
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9394 - f1_macro: 0.9376 - loss: 0.1617 - val_accuracy: 0.9275 - val_f1_macro: 0.9234 - val_loss: 0.2093
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9427 - f1_macro: 0.9408 - loss: 0.1527 - val_accuracy: 0.9318 - val_f1_macro: 0.9282 - val_loss: 0.2080
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9454 - f1_macro: 0.9426 - loss: 0.1486 - val_accuracy: 0.9331 - val_f1_macro: 0.9303 - val_loss: 0.2026
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# Fold 5 - CV Val Loss: 0.1963, CV Val Acc: 0.9349, CV Val F1-Macro: 0.9316
#
# --- Cross-Validation Summary ---
# Average CV Loss: 0.2205 (+/- 0.0279)
# Average CV Accuracy: 0.9304 (+/- 0.0057)
# Average CV F1-Macro: 0.9270 (+/- 0.0064)

# %%
# ----- Train Final Model -----

BATCH_SIZE_FINAL = 32
EPOCHS_FINAL_NEW = 80  # เพิ่มจำนวน Epochs สำหรับการฝึกที่นานขึ้น
PATIENCE_FINAL_NEW = 10 # เพิ่ม Patience สำหรับ EarlyStopping
history_final = None 

# --- LEARNING RATE PARAMETERS FOR FINAL MODEL SCHEDULER ---
INITIAL_LR_FINAL = 0.0001  # <<<<----- ปรับค่าเริ่มต้นที่นี่ (เช่น 0.0005 หรือ 0.00025)
END_LR_FINAL = 0.00005     # <<<<----- ปรับค่าสุดท้ายที่นี่ (เช่น 0.00001 หรือ 0.000005)

if X_train_orig.shape[0] > 0:
    y_train_orig_2d = y_train_orig.reshape(-1, 1)
    y_val_orig_2d = None
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        y_val_orig_2d = y_val_orig.reshape(-1, 1)

    print("\n--- Training Final Model with Transformer Classifier ---")
    
    # สร้าง final_model ด้วย create_transformer_classifier
    # learning_rate ที่ส่งเข้าไปใน create_transformer_classifier จะไม่ถูกใช้
    # ถ้าเรา recompile ด้วย optimizer ใหม่ด้านล่าง
    final_model = create_transformer_classifier(
        input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
        d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
        projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
        dropout_rate=DROPOUT_RATE, # ใช้ DROPOUT_RATE ที่ตั้งไว้
        learning_rate=0.0005 # ค่า dummy หรือ initial LR เดิม, เพราะจะ recompile อยู่ดี
    )

    # --- DEFINE LEARNING RATE SCHEDULE FOR FINAL MODEL ---
    num_train_samples_final = X_train_orig.shape[0]
    total_decay_steps_final = (num_train_samples_final // BATCH_SIZE_FINAL) * EPOCHS_FINAL_NEW 
    
    final_lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        initial_learning_rate=INITIAL_LR_FINAL, 
        decay_steps=total_decay_steps_final,
        end_learning_rate=END_LR_FINAL,         
        power=0.5 # Linear decay (หรือลองค่าอื่น เช่น 0.5)
    )
    
    # สร้าง Optimizer ใหม่ด้วย Learning Rate Schedule
    optimizer_with_schedule_final = Adam(learning_rate=final_lr_schedule)

    # Recompile final_model ด้วย Optimizer ใหม่ที่มี Schedule
    f1_metric_for_recompile = tf.keras.metrics.F1Score(average='macro', threshold=0.5, name='f1_macro')
    final_model.compile(optimizer=optimizer_with_schedule_final,
                        loss='binary_crossentropy',
                        metrics=['accuracy', f1_metric_for_recompile])
    print(f"Recompiled final_model with PolynomialDecay LR schedule (Initial: {INITIAL_LR_FINAL}, End: {END_LR_FINAL}).")

    callbacks_final = []
    validation_data_for_fit = None
    if y_val_orig_2d is not None:
        validation_data_for_fit = (X_val_orig, y_val_orig_2d)
        early_stopping_final = EarlyStopping(
            monitor='val_f1_macro', 
            patience=PATIENCE_FINAL_NEW, # ใช้ PATIENCE_FINAL_NEW ที่ตั้งไว้
            verbose=1, 
            mode='max', 
            restore_best_weights=True
        )
        callbacks_final.append(early_stopping_final)
        
        class PrintLR(tf.keras.callbacks.Callback): # Optional: Callback to print LR
            def on_epoch_end(self, epoch, logs=None):
                current_lr_value = self.model.optimizer.learning_rate
                if isinstance(current_lr_value, tf.keras.optimizers.schedules.LearningRateSchedule):
                    current_lr_value = current_lr_value(self.model.optimizer.iterations)
                try:
                    current_lr_value = tf.keras.backend.get_value(current_lr_value)
                except: pass
                print(f" - LR: {current_lr_value:.7f}", end="")
        callbacks_final.append(PrintLR())

        print(f"Training final model with validation data, LR schedule, and EarlyStopping (patience={PATIENCE_FINAL_NEW}).")
    else:
        print("Training final model without validation data. EarlyStopping on val_f1_macro disabled.")
    
    history_final = final_model.fit(X_train_orig, y_train_orig_2d, 
                                    epochs=EPOCHS_FINAL_NEW, # ใช้ EPOCHS_FINAL_NEW
                                    batch_size=BATCH_SIZE_FINAL, 
                                    validation_data=validation_data_for_fit, 
                                    callbacks=callbacks_final if callbacks_final else None, 
                                    verbose=1)
    
    if final_model:
        if X_test_orig.shape[0] > 0 and y_test_orig.shape[0] > 0:
            y_test_orig_2d = y_test_orig.reshape(-1, 1)
            print("\n--- Evaluating on Test Set (after final training) ---")
            eval_results_final = final_model.evaluate(X_test_orig, y_test_orig_2d, verbose=0)
            test_loss, test_accuracy, test_f1_macro = eval_results_final[0], eval_results_final[1], eval_results_final[2]
            print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Test F1-Macro: {test_f1_macro:.4f}")
        else:
            print("Skipping evaluation on Test Set: Test data is empty or not provided.")
else:
    print("Final model was not trained (likely due to empty training data).")


# ----- Export Model and Convert to TFLite -----
if 'final_model' in locals() and isinstance(final_model, tf.keras.Model):
    print("\n--- Evaluating on Test Set (Before Export) ---")
    if 'X_test_orig' in locals() and 'y_test_orig' in locals() and X_test_orig.size > 0:
        # --- RESHAPE y_test_orig for Keras F1Score metric during evaluation ---
        y_test_orig_2d_export = y_test_orig.reshape(-1, 1) # Use a different variable name or ensure it's reshaped if not already
        eval_results_export = final_model.evaluate(X_test_orig, y_test_orig_2d_export, verbose=0) # Use 2D y_true
        test_loss_exp, test_acc_exp, test_f1_exp = eval_results_export[0], eval_results_export[1], eval_results_export[2]
        print(f"Test Loss: {test_loss_exp:.4f}, Test Acc: {test_acc_exp:.4f}, Test F1-Macro: {test_f1_exp:.4f}")
    else:
        print("Test data not found or empty for pre-export evaluation.")

    export_directory = 'fall_model_exported_sm'
    try:
        final_model.export(export_directory)
        print(f"Model exported successfully in SavedModel format at: ./{export_directory}")

        print("\nConverting exported SavedModel to TensorFlow Lite...")
        try:
            converter = tf.lite.TFLiteConverter.from_saved_model(export_directory)
            tflite_model_content = converter.convert()
            tflite_model_path = 'fall_detection_transformer.tflite'
            with open(tflite_model_path, 'wb') as f: f.write(tflite_model_content)
            print(f"Model converted to TFLite and saved as {tflite_model_path} ({len(tflite_model_content)/1024:.2f} KB)")
        except Exception as tflite_e:
            print(f"Error during TFLite conversion: {tflite_e}")
    except Exception as e:
        print(f"Error during model export: {e}")
else:
    print("ERROR: 'final_model' not defined or not a Keras Model. Skipping export and TFLite conversion.")
# Out:
# --- Training Final Model with Transformer Classifier ---
# Recompiled final_model with PolynomialDecay LR schedule (Initial: 0.0001, End: 5e-05).
# Training final model with validation data, LR schedule, and EarlyStopping (patience=10).
# Epoch 1/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 37s 42ms/step - accuracy: 0.6986 - f1_macro: 0.6645 - loss: 0.5822 - val_accuracy: 0.8059 - val_f1_macro: 0.7898 - val_loss: 0.4222
# Epoch 2/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8052 - f1_macro: 0.7876 - loss: 0.4293 - val_accuracy: 0.8464 - val_f1_macro: 0.8380 - val_loss: 0.3683
# Epoch 3/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8538 - f1_macro: 0.8466 - loss: 0.3587 - val_accuracy: 0.8590 - val_f1_macro: 0.8490 - val_loss: 0.3457
# Epoch 4/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8683 - f1_macro: 0.8624 - loss: 0.3359 - val_accuracy: 0.8716 - val_f1_macro: 0.8625 - val_loss: 0.3260
# Epoch 5/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8735 - f1_macro: 0.8676 - loss: 0.3279 - val_accuracy: 0.8679 - val_f1_macro: 0.8581 - val_loss: 0.3254
# Epoch 6/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8781 - f1_macro: 0.8718 - loss: 0.3116 - val_accuracy: 0.8578 - val_f1_macro: 0.8463 - val_loss: 0.3785
# Epoch 7/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8771 - f1_macro: 0.8701 - loss: 0.3095 - val_accuracy: 0.8732 - val_f1_macro: 0.8651 - val_loss: 0.3277
# Epoch 8/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8858 - f1_macro: 0.8787 - loss: 0.2909 - val_accuracy: 0.8764 - val_f1_macro: 0.8665 - val_loss: 0.3064
# Epoch 9/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8872 - f1_macro: 0.8809 - loss: 0.2833 - val_accuracy: 0.8772 - val_f1_macro: 0.8660 - val_loss: 0.3100
# Epoch 10/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8891 - f1_macro: 0.8849 - loss: 0.2872 - val_accuracy: 0.8870 - val_f1_macro: 0.8792 - val_loss: 0.2867
# Epoch 11/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8970 - f1_macro: 0.8928 - loss: 0.2686 - val_accuracy: 0.8870 - val_f1_macro: 0.8801 - val_loss: 0.3070
# Epoch 12/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8924 - f1_macro: 0.8853 - loss: 0.2609 - val_accuracy: 0.8821 - val_f1_macro: 0.8744 - val_loss: 0.3117
# Epoch 13/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8997 - f1_macro: 0.8938 - loss: 0.2500 - val_accuracy: 0.8959 - val_f1_macro: 0.8899 - val_loss: 0.2727
# Epoch 14/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8988 - f1_macro: 0.8942 - loss: 0.2559 - val_accuracy: 0.8959 - val_f1_macro: 0.8918 - val_loss: 0.2657
# Epoch 15/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9089 - f1_macro: 0.9053 - loss: 0.2343 - val_accuracy: 0.9048 - val_f1_macro: 0.9006 - val_loss: 0.2492
# Epoch 16/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9087 - f1_macro: 0.9049 - loss: 0.2338 - val_accuracy: 0.8975 - val_f1_macro: 0.8905 - val_loss: 0.2718
# Epoch 17/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9110 - f1_macro: 0.9075 - loss: 0.2307 - val_accuracy: 0.9048 - val_f1_macro: 0.8990 - val_loss: 0.2663
# Epoch 18/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9107 - f1_macro: 0.9079 - loss: 0.2289 - val_accuracy: 0.9064 - val_f1_macro: 0.9014 - val_loss: 0.2490
# Epoch 19/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9146 - f1_macro: 0.9118 - loss: 0.2200 - val_accuracy: 0.9019 - val_f1_macro: 0.8965 - val_loss: 0.2553
# Epoch 20/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9165 - f1_macro: 0.9135 - loss: 0.2179 - val_accuracy: 0.9007 - val_f1_macro: 0.8952 - val_loss: 0.2526
# Epoch 21/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9098 - f1_macro: 0.9057 - loss: 0.2181 - val_accuracy: 0.9036 - val_f1_macro: 0.9000 - val_loss: 0.2579
# Epoch 22/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9159 - f1_macro: 0.9133 - loss: 0.2138 - val_accuracy: 0.8995 - val_f1_macro: 0.8925 - val_loss: 0.2678
# Epoch 23/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9223 - f1_macro: 0.9210 - loss: 0.2097 - val_accuracy: 0.9072 - val_f1_macro: 0.9015 - val_loss: 0.2466
# Epoch 24/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9217 - f1_macro: 0.9164 - loss: 0.2009 - val_accuracy: 0.9052 - val_f1_macro: 0.8992 - val_loss: 0.2512
# Epoch 25/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9255 - f1_macro: 0.9226 - loss: 0.1952 - val_accuracy: 0.9190 - val_f1_macro: 0.9142 - val_loss: 0.2257
# Epoch 26/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9186 - f1_macro: 0.9138 - loss: 0.2011 - val_accuracy: 0.9161 - val_f1_macro: 0.9123 - val_loss: 0.2264
# Epoch 27/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9231 - f1_macro: 0.9183 - loss: 0.1902 - val_accuracy: 0.9182 - val_f1_macro: 0.9156 - val_loss: 0.2329
# Epoch 28/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9322 - f1_macro: 0.9296 - loss: 0.1814 - val_accuracy: 0.9129 - val_f1_macro: 0.9113 - val_loss: 0.2367
# Epoch 29/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9301 - f1_macro: 0.9262 - loss: 0.1815 - val_accuracy: 0.9157 - val_f1_macro: 0.9119 - val_loss: 0.2299
# Epoch 30/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9317 - f1_macro: 0.9279 - loss: 0.1771 - val_accuracy: 0.9149 - val_f1_macro: 0.9117 - val_loss: 0.2215
# Epoch 31/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9307 - f1_macro: 0.9289 - loss: 0.1796 - val_accuracy: 0.9092 - val_f1_macro: 0.9061 - val_loss: 0.2292
# Epoch 32/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9352 - f1_macro: 0.9317 - loss: 0.1703 - val_accuracy: 0.9173 - val_f1_macro: 0.9144 - val_loss: 0.2473
# Epoch 33/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9374 - f1_macro: 0.9348 - loss: 0.1688 - val_accuracy: 0.9182 - val_f1_macro: 0.9151 - val_loss: 0.2224
# Epoch 34/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9394 - f1_macro: 0.9371 - loss: 0.1618 - val_accuracy: 0.9222 - val_f1_macro: 0.9182 - val_loss: 0.2158
# Epoch 35/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9452 - f1_macro: 0.9429 - loss: 0.1501 - val_accuracy: 0.9267 - val_f1_macro: 0.9231 - val_loss: 0.2107
# Epoch 36/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9400 - f1_macro: 0.9364 - loss: 0.1555 - val_accuracy: 0.9182 - val_f1_macro: 0.9157 - val_loss: 0.2426
# Epoch 37/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9423 - f1_macro: 0.9401 - loss: 0.1501 - val_accuracy: 0.9287 - val_f1_macro: 0.9252 - val_loss: 0.2126
# Epoch 38/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9465 - f1_macro: 0.9443 - loss: 0.1441 - val_accuracy: 0.9182 - val_f1_macro: 0.9126 - val_loss: 0.2382
# Epoch 39/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9442 - f1_macro: 0.9417 - loss: 0.1499 - val_accuracy: 0.9303 - val_f1_macro: 0.9286 - val_loss: 0.2110
# Epoch 40/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9392 - f1_macro: 0.9383 - loss: 0.1565 - val_accuracy: 0.9226 - val_f1_macro: 0.9187 - val_loss: 0.2193
# Epoch 41/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9466 - f1_macro: 0.9443 - loss: 0.1469 - val_accuracy: 0.9238 - val_f1_macro: 0.9204 - val_loss: 0.2218
# Epoch 42/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9435 - f1_macro: 0.9408 - loss: 0.1521 - val_accuracy: 0.9250 - val_f1_macro: 0.9199 - val_loss: 0.2169
# Epoch 43/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9502 - f1_macro: 0.9483 - loss: 0.1342 - val_accuracy: 0.9315 - val_f1_macro: 0.9284 - val_loss: 0.2024
# Epoch 44/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9527 - f1_macro: 0.9508 - loss: 0.1320 - val_accuracy: 0.9186 - val_f1_macro: 0.9136 - val_loss: 0.2304
# Epoch 45/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9433 - f1_macro: 0.9413 - loss: 0.1435 - val_accuracy: 0.9283 - val_f1_macro: 0.9248 - val_loss: 0.2181
# Epoch 46/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9447 - f1_macro: 0.9432 - loss: 0.1423 - val_accuracy: 0.9307 - val_f1_macro: 0.9270 - val_loss: 0.2112
# Epoch 47/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9487 - f1_macro: 0.9462 - loss: 0.1382 - val_accuracy: 0.9267 - val_f1_macro: 0.9226 - val_loss: 0.2205
# Epoch 48/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9548 - f1_macro: 0.9540 - loss: 0.1304 - val_accuracy: 0.9299 - val_f1_macro: 0.9259 - val_loss: 0.2202
# Epoch 49/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9507 - f1_macro: 0.9482 - loss: 0.1298 - val_accuracy: 0.9327 - val_f1_macro: 0.9298 - val_loss: 0.2037
# Epoch 50/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9540 - f1_macro: 0.9531 - loss: 0.1250 - val_accuracy: 0.9271 - val_f1_macro: 0.9233 - val_loss: 0.2277
# Epoch 51/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9583 - f1_macro: 0.9570 - loss: 0.1145 - val_accuracy: 0.9283 - val_f1_macro: 0.9248 - val_loss: 0.2167
# Epoch 52/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9501 - f1_macro: 0.9486 - loss: 0.1330 - val_accuracy: 0.9283 - val_f1_macro: 0.9250 - val_loss: 0.2193
# Epoch 53/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9519 - f1_macro: 0.9499 - loss: 0.1222 - val_accuracy: 0.9327 - val_f1_macro: 0.9291 - val_loss: 0.2215
# Epoch 54/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9532 - f1_macro: 0.9518 - loss: 0.1143 - val_accuracy: 0.9303 - val_f1_macro: 0.9268 - val_loss: 0.2208
# Epoch 55/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9594 - f1_macro: 0.9578 - loss: 0.1164 - val_accuracy: 0.9263 - val_f1_macro: 0.9231 - val_loss: 0.2210
# Epoch 56/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9550 - f1_macro: 0.9535 - loss: 0.1147 - val_accuracy: 0.9287 - val_f1_macro: 0.9249 - val_loss: 0.2198
# Epoch 57/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9546 - f1_macro: 0.9534 - loss: 0.1231 - val_accuracy: 0.9344 - val_f1_macro: 0.9315 - val_loss: 0.2108
# Epoch 58/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9588 - f1_macro: 0.9563 - loss: 0.1124 - val_accuracy: 0.9291 - val_f1_macro: 0.9252 - val_loss: 0.2099
# Epoch 59/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9592 - f1_macro: 0.9578 - loss: 0.1120 - val_accuracy: 0.9303 - val_f1_macro: 0.9279 - val_loss: 0.2146
# Epoch 60/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9607 - f1_macro: 0.9602 - loss: 0.1109 - val_accuracy: 0.9319 - val_f1_macro: 0.9283 - val_loss: 0.2189
# Epoch 61/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9610 - f1_macro: 0.9589 - loss: 0.1056 - val_accuracy: 0.9327 - val_f1_macro: 0.9290 - val_loss: 0.2265
# Epoch 62/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9623 - f1_macro: 0.9608 - loss: 0.1092 - val_accuracy: 0.9291 - val_f1_macro: 0.9247 - val_loss: 0.2354
# Epoch 63/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9618 - f1_macro: 0.9594 - loss: 0.1044 - val_accuracy: 0.9315 - val_f1_macro: 0.9285 - val_loss: 0.2185
# Epoch 64/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9630 - f1_macro: 0.9613 - loss: 0.0993 - val_accuracy: 0.9327 - val_f1_macro: 0.9294 - val_loss: 0.2155
# Epoch 65/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9560 - f1_macro: 0.9548 - loss: 0.1084 - val_accuracy: 0.9287 - val_f1_macro: 0.9234 - val_loss: 0.2420
# Epoch 66/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9598 - f1_macro: 0.9584 - loss: 0.1001 - val_accuracy: 0.9323 - val_f1_macro: 0.9299 - val_loss: 0.2195
# Epoch 67/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9631 - f1_macro: 0.9614 - loss: 0.1058 - val_accuracy: 0.9348 - val_f1_macro: 0.9309 - val_loss: 0.2206
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 57.
#
# --- Evaluating on Test Set (after final training) ---
# Test Loss: 0.2133, Test Accuracy: 0.9307, Test F1-Macro: 0.9284
#
# --- Evaluating on Test Set (Before Export) ---
# Test Loss: 0.2133, Test Acc: 0.9307, Test F1-Macro: 0.9284
# Saved artifact at 'fall_model_exported_sm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 51), dtype=tf.float32, name='input_features')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   138173581783120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173581771984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173581785808: TensorSpec(shape=(1, 60, 64), dtype=tf.float32, name=None)
#   138173581779664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173581775824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173581786576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173581786960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471887760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471888336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471883728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471891792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471883920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471890640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471890832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471886992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471892752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471890256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471891600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471892944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471889680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471893712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471892368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471893904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471896784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471895824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471897552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471897936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471895440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471898896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471899280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471899472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173471898128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138170911573392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138170911573584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138170911574544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138170911574928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173573322640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173585016400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173550767632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173550768016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173550769168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173550769936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138175440604048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138175440614992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138175440614032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173742243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138173742243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model exported successfully in SavedModel format at: ./fall_model_exported_sm
#
# Converting exported SavedModel to TensorFlow Lite...
# Model converted to TFLite and saved as fall_detection_transformer.tflite (461.57 KB)
# W0000 00:00:1749220278.371527      35 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749220278.371563      35 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1749220278.405521      35 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
# ----- Plot Training History of Final Model -----
if history_final and hasattr(history_final, 'history') and history_final.history:
    plt.figure(figsize=(18, 5)) # Adjusted for 3 subplots
    
    plt.subplot(1, 3, 1)
    if 'accuracy' in history_final.history: plt.plot(history_final.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history_final.history: plt.plot(history_final.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    
    plt.subplot(1, 3, 2)
    if 'loss' in history_final.history: plt.plot(history_final.history['loss'], label='Train Loss')
    if 'val_loss' in history_final.history: plt.plot(history_final.history['val_loss'], label='Val Loss')
    plt.title('Model Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)

    plt.subplot(1, 3, 3) # New subplot for F1-Macro
    if 'f1_macro' in history_final.history: plt.plot(history_final.history['f1_macro'], label='Train F1-Macro')
    if 'val_f1_macro' in history_final.history: plt.plot(history_final.history['val_f1_macro'], label='Val F1-Macro')
    plt.title('Model F1-Macro Score'); plt.xlabel('Epoch'); plt.ylabel('F1-Macro'); plt.legend(); plt.grid(True)
    
    plt.tight_layout(); plt.show()
else:
    print("Skipping plotting: final model training history unavailable.")

# %%
# ----- FUNCTION TO PLOT CONFUSION MATRIX -----
def plot_confusion_matrix_custom(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title); plt.ylabel('True label'); plt.xlabel('Predicted label'); plt.show()

# ----- FUNCTION TO PLOT METRICS BARCHART  -----
def plot_metrics_barchart(metrics_data, class_names, title='Metrics per Class'):
    df_metrics = pd.DataFrame(metrics_data, index=class_names)
    ax = df_metrics.plot(kind='bar', figsize=(10, 7), width=0.8, colormap='viridis')
    plt.title(title, fontsize=15); plt.ylabel('Score (%)', fontsize=12); plt.xlabel('Class', fontsize=12)
    plt.xticks(rotation=0); plt.ylim(0, 1)
    for p in ax.patches:
        ax.annotate(f"{p.get_height()*100:.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 9), textcoords='offset points', fontsize=10)
    plt.legend(title='Metrics'); plt.tight_layout(); plt.show()

# ----- DETAILED EVALUATION AND REPORTING -----
target_names = ['no_fall', 'fall']
class_labels = [0, 1] # Corresponding numerical labels

# Initialize prediction variables to None
y_pred_val_probs = None
y_pred_val_classes = None
y_pred_test_probs = None
y_pred_test_classes = None

# --- กำหนด Optimized Threshold ที่คุณได้มา ---
OPTIMIZED_THRESHOLD = 0.50 # หรือค่าที่คุณได้จากการทดลองล่าสุด

if final_model is not None:
    # --- Evaluation on Validation Set ---
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        print(f"\n\n--- Custom Validation Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_val_probs = final_model.predict(X_val_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_val_classes = (y_pred_val_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_val, recall_val, f1_val, support_val = precision_recall_fscore_support(
            y_val_orig, y_pred_val_classes, labels=class_labels, zero_division=0
        )
        f2_val_per_class = fbeta_score(y_val_orig, y_pred_val_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ validation) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_val[i]:>10.4f} {recall_val[i]:>10.4f} {f1_val[i]:>10.4f} {f2_val_per_class[i]:>10.4f} {support_val[i]:>10}")
        val_metrics_for_plot = {'Precision': precision_val, 'Recall': recall_val, 'F1-score': f1_val, 'F2-score': f2_val_per_class}
        plot_metrics_barchart(val_metrics_for_plot, target_names, title=f'Validation Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_val = confusion_matrix(y_val_orig, y_pred_val_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_val, classes=target_names, title=f'Validation Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')

    else: print("\nValidation data empty. Skipping detailed validation metrics report.")

    # --- Evaluation on Test Set ---
    if X_test_orig.size > 0 and y_test_orig.size > 0:
        print(f"\n\n--- Custom Test Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_test_probs = final_model.predict(X_test_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_test_classes = (y_pred_test_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_test, recall_test, f1_test, support_test = precision_recall_fscore_support(
            y_test_orig, y_pred_test_classes, labels=class_labels, zero_division=0
        )
        f2_test_per_class = fbeta_score(y_test_orig, y_pred_test_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ test) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_test[i]:>10.4f} {recall_test[i]:>10.4f} {f1_test[i]:>10.4f} {f2_test_per_class[i]:>10.4f} {support_test[i]:>10}")
        test_metrics_for_plot = {'Precision': precision_test, 'Recall': recall_test, 'F1-score': f1_test, 'F2-score': f2_test_per_class}
        plot_metrics_barchart(test_metrics_for_plot, target_names, title=f'Test Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_test = confusion_matrix(y_test_orig, y_pred_test_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_test, classes=target_names, title=f'Test Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')
    else: print("\nTest data empty. Skipping detailed test metrics.")
else:
    print("Final model not trained. Skipping detailed evaluation.")
# Out:
# --- Custom Validation Metrics Report (Threshold: 0.5) ---
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9298     0.9444     0.9370     0.9414       1276
# fall          0.9394     0.9237     0.9315     0.9268       1192
# --- Custom Test Metrics Report (Threshold: 0.5) ---
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9340     0.9318     0.9329     0.9323       1276
# fall          0.9273     0.9296     0.9284     0.9291       1193

# %%
from sklearn.metrics import f1_score

# y_pred_val_probs ได้จากการ predict บน X_val_orig
best_threshold = 0.5
best_f1 = 0.0
thresholds = np.arange(0.1, 0.9, 0.01)
for thresh in thresholds:
    current_preds = (y_pred_val_probs > thresh).astype(int)
    current_f1 = f1_score(y_val_orig, current_preds, average='macro') # หรือ average='binary' ถ้าสนใจ F1 ของคลาส fall
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_threshold = thresh
print(f"Best threshold on validation set: {best_threshold:.2f} with F1-Macro: {best_f1:.4f}")
# Out:
# Best threshold on validation set: 0.38 with F1-Macro: 0.9371

# %%
# ----- Error Analysis and Logging to CSV -----
import numpy as np
import pandas as pd
from pathlib import Path
import csv


print("\nStarting Error Analysis and Logging to CSV...")
csv_error_log_filename = "error_analysis_report.csv"

# --- DEFINITION OF TARGET NAMES (IMPORTANT!) ---
# ตรวจสอบให้แน่ใจว่าการ map นี้ถูกต้องตาม labels ที่โมเดลของคุณใช้ (0 และ 1)
target_names_map_global = {
    0: 'no_fall',  # Label 0 คือ 'no_fall'
    1: 'fall'      # Label 1 คือ 'fall'
}
# ---------------------------------------------

# --- Function to process and write errors for a given set (val or test) ---
def log_errors_to_csv_list(data_set_name, y_true, y_pred_classes, y_pred_probs, filepaths, target_names_dict, csv_rows_list):
    # ตรวจสอบว่า target_names_dict เป็น dictionary
    if not isinstance(target_names_dict, dict):
        print(f"ERROR in log_errors_to_csv_list: target_names_dict for {data_set_name} is not a dictionary. Skipping.")
        return False

    if not (y_true is not None and y_pred_classes is not None and y_pred_probs is not None and filepaths is not None and
            y_true.size > 0 and len(filepaths) > 0 and y_pred_classes.size > 0 and y_pred_probs.size > 0 and
            len(y_true) == len(filepaths) == len(y_pred_classes) == y_pred_probs.shape[0]):
        print(f"Warning: Data for {data_set_name} error analysis is incomplete or mismatched. Skipping {data_set_name} set.")
        return False

    fp_indices = np.where((y_pred_classes == 1) & (y_true == 0))[0]
    fn_indices = np.where((y_pred_classes == 0) & (y_true == 1))[0]

    print(f"\n--- Analyzing {data_set_name} Set ---")
    print(f"Total {data_set_name} Samples: {len(y_true)}")
    print(f"False Positives (No_Fall predicted as Fall): {len(fp_indices)}")
    print(f"False Negatives (Fall predicted as No_Fall): {len(fn_indices)}")

    # Process False Positives
    for fp_idx in fp_indices:
        true_label_int = int(y_true[fp_idx]) # Ensure integer for dict key
        pred_label_int = int(y_pred_classes[fp_idx])
        
        pred_prob_fall = y_pred_probs[fp_idx]
        if isinstance(pred_prob_fall, (np.ndarray, list)): # Handle if probs are in array/list per sample
            pred_prob_fall = pred_prob_fall[0] if len(pred_prob_fall) == 1 else (pred_prob_fall[1] if len(pred_prob_fall) > 1 and pred_label_int == 1 else pred_prob_fall[pred_label_int])


        npy_full_path_str = filepaths[fp_idx]
        npy_filename = Path(npy_full_path_str).name
        
        csv_rows_list.append({
            'File Name': npy_filename,
            'True': target_names_dict.get(true_label_int, str(true_label_int)),
            'Pred': target_names_dict.get(pred_label_int, str(pred_label_int)),
            'Prob': f"{pred_prob_fall:.4f}",
            'Type': 'FP',
            'Set': data_set_name
        })

    # Process False Negatives
    for fn_idx in fn_indices:
        true_label_int = int(y_true[fn_idx]) # Ensure integer
        pred_label_int = int(y_pred_classes[fn_idx])
        
        pred_prob_fall = y_pred_probs[fn_idx]
        if isinstance(pred_prob_fall, (np.ndarray, list)): # Handle if probs are in array/list per sample
            pred_prob_fall = pred_prob_fall[0] # Assuming sigmoid output P(Fall)

        npy_full_path_str = filepaths[fn_idx]
        npy_filename = Path(npy_full_path_str).name
        
        csv_rows_list.append({
            'File Name': npy_filename,
            'True': target_names_dict.get(true_label_int, str(true_label_int)),
            'Pred': target_names_dict.get(pred_label_int, str(pred_label_int)),
            'Prob': f"{pred_prob_fall:.4f}",
            'Type': 'FN',
            'Set': data_set_name
        })
    return True


# --- Main CSV Logging Logic ---
all_error_rows = []

# ใช้ target_names_map_global ที่กำหนดไว้ด้านบน
print(f"Using target names map: {target_names_map_global}")

# --- Validation Set Analysis ---
val_analyzed_success = False # เปลี่ยนชื่อตัวแปรเพื่อความชัดเจน
if 'y_val_orig' in locals() and 'y_pred_val_classes' in locals() and \
   'y_pred_val_probs' in locals() and 'val_npy_filepaths' in locals():
    print("Proceeding with Validation Set Error Analysis...")
    val_analyzed_success = log_errors_to_csv_list(
        data_set_name='val',
        y_true=np.array(y_val_orig).flatten(), # Ensure y_val_orig is 1D
        y_pred_classes=np.array(y_pred_val_classes).flatten(),
        y_pred_probs=np.array(y_pred_val_probs).flatten(), # Ensure y_pred_val_probs is 1D for P(Fall)
        filepaths=val_npy_filepaths,
        target_names_dict=target_names_map_global, # ส่ง dictionary เข้าไป
        csv_rows_list=all_error_rows
    )
else:
    print("Skipping Validation Set Error Analysis: One or more required variables are missing "
          "(y_val_orig, y_pred_val_classes, y_pred_val_probs, val_npy_filepaths).")

# --- Test Set Analysis ---
test_analyzed_success = False # เปลี่ยนชื่อตัวแปรเพื่อความชัดเจน
if 'y_test_orig' in locals() and 'y_pred_test_classes' in locals() and \
   'y_pred_test_probs' in locals() and 'test_npy_filepaths' in locals():
    print("Proceeding with Test Set Error Analysis...")
    test_analyzed_success = log_errors_to_csv_list(
        data_set_name='test',
        y_true=np.array(y_test_orig).flatten(), # Ensure y_test_orig is 1D
        y_pred_classes=np.array(y_pred_test_classes).flatten(),
        y_pred_probs=np.array(y_pred_test_probs).flatten(), # Ensure y_pred_test_probs is 1D for P(Fall)
        filepaths=test_npy_filepaths,
        target_names_dict=target_names_map_global, # ส่ง dictionary เข้าไป
        csv_rows_list=all_error_rows
    )
else:
    print("Skipping Test Set Error Analysis: One or more required variables are missing "
          "(y_test_orig, y_pred_test_classes, y_pred_test_probs, test_npy_filepaths).")

# --- Write to CSV File ---
if all_error_rows:
    fieldnames = ['#', 'File Name', 'True', 'Pred', 'Prob', 'Type', 'Set']
    
    with open(csv_error_log_filename, "w", newline='', encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, row_dict in enumerate(all_error_rows):
            row_dict_with_index = {'#': i + 1, **row_dict}
            writer.writerow(row_dict_with_index)
    print(f"\nError Analysis Report (CSV) saved to: {csv_error_log_filename}")
elif not val_analyzed_success and not test_analyzed_success:
    fieldnames = ['#', 'File Name', 'True', 'Pred', 'Prob', 'Type', 'Set']
    with open(csv_error_log_filename, "w", newline='', encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerow({'#': '', 'File Name': 'No data available for analysis or required variables missing.',
                         'True': '', 'Pred': '', 'Prob': '', 'Type': '', 'Set': ''})
    print(f"Empty Error Analysis Report (CSV) created at: {csv_error_log_filename} (No data for analysis).")
else: # กรณีที่ val หรือ test ถูกวิเคราะห์ แต่ไม่มี error ให้ log
    if not all_error_rows and (val_analyzed_success or test_analyzed_success):
        fieldnames = ['#', 'File Name', 'True', 'Pred', 'Prob', 'Type', 'Set']
        with open(csv_error_log_filename, "w", newline='', encoding="utf-8") as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerow({'#': '', 'File Name': 'No False Positives or False Negatives found in the analyzed set(s).',
                             'True': '', 'Pred': '', 'Prob': '', 'Type': '', 'Set': ''})
        print(f"\nError Analysis Report (CSV) indicates no FP/FN found: {csv_error_log_filename}")
# Out:
# Starting Error Analysis and Logging to CSV...
# Using target names map: {0: 'no_fall', 1: 'fall'}
# Proceeding with Validation Set Error Analysis...
#
# --- Analyzing val Set ---
# Total val Samples: 2468
# False Positives (No_Fall predicted as Fall): 71
# False Negatives (Fall predicted as No_Fall): 91
# Proceeding with Test Set Error Analysis...
#
# --- Analyzing test Set ---
# Total test Samples: 2469
# False Positives (No_Fall predicted as Fall): 87
# False Negatives (Fall predicted as No_Fall): 84
#
# Error Analysis Report (CSV) saved to: error_analysis_report.csv
