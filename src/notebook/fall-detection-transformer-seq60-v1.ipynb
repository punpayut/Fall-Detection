# %%
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, fbeta_score, precision_recall_fscore_support

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense, Dropout, LayerNormalization, MultiHeadAttention,
    GlobalAveragePooling1D, Embedding, Add, Input
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-06-05 08:28:23.572988: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749112103.773585      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749112103.832194      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----- 0. GLOBAL CONSTANTS AND KEYPOINT DEFINITIONS -----
KEYPOINT_NAMES = [
    'Nose', 'Left Eye', 'Right Eye', 'Left Ear', 'Right Ear',
    'Left Shoulder', 'Right Shoulder', 'Left Elbow', 'Right Elbow',
    'Left Wrist', 'Right Wrist', 'Left Hip', 'Right Hip',
    'Left Knee', 'Right Knee', 'Left Ankle', 'Right Ankle'
]
SORTED_KEYPOINT_NAMES = sorted(KEYPOINT_NAMES)
KEYPOINT_DICT = {name: i for i, name in enumerate(SORTED_KEYPOINT_NAMES)}
NUM_KEYPOINTS = len(KEYPOINT_DICT)

print("--- Initializing Keypoint Definitions ---")
print(f"SORTED_KEYPOINT_NAMES (used for ordering): {SORTED_KEYPOINT_NAMES}")
print(f"Generated KEYPOINT_DICT: {KEYPOINT_DICT}")
print(f"NUM_KEYPOINTS: {NUM_KEYPOINTS}")
if NUM_KEYPOINTS != 17:
    print(f"WARNING: NUM_KEYPOINTS is {NUM_KEYPOINTS}, expected 17.")
print("----------------------------------------")
# Out:
# --- Initializing Keypoint Definitions ---
# SORTED_KEYPOINT_NAMES (used for ordering): ['Left Ankle', 'Left Ear', 'Left Elbow', 'Left Eye', 'Left Hip', 'Left Knee', 'Left Shoulder', 'Left Wrist', 'Nose', 'Right Ankle', 'Right Ear', 'Right Elbow', 'Right Eye', 'Right Hip', 'Right Knee', 'Right Shoulder', 'Right Wrist']
# Generated KEYPOINT_DICT: {'Left Ankle': 0, 'Left Ear': 1, 'Left Elbow': 2, 'Left Eye': 3, 'Left Hip': 4, 'Left Knee': 5, 'Left Shoulder': 6, 'Left Wrist': 7, 'Nose': 8, 'Right Ankle': 9, 'Right Ear': 10, 'Right Elbow': 11, 'Right Eye': 12, 'Right Hip': 13, 'Right Knee': 14, 'Right Shoulder': 15, 'Right Wrist': 16}
# NUM_KEYPOINTS: 17
# ----------------------------------------

# %%
# ----- 1. HELPER FUNCTION FOR KEYPOINT INDICES -----
def get_kpt_indices(keypoint_name):
    if keypoint_name not in KEYPOINT_DICT:
        available_keys = list(KEYPOINT_DICT.keys())
        similar_keys = [k for k in available_keys if keypoint_name.lower() in k.lower() or k.lower() in keypoint_name.lower()]
        error_msg = f"Keypoint name '{keypoint_name}' not found in KEYPOINT_DICT. "
        error_msg += f"Available keys: {available_keys}. "
        if similar_keys: error_msg += f"Did you mean: {similar_keys}? "
        raise ValueError(error_msg)
    kp_idx = KEYPOINT_DICT[keypoint_name]
    return kp_idx * 3, kp_idx * 3 + 1, kp_idx * 3 + 2

# %%
# ----- 2. SKELETON NORMALIZATION FUNCTION -----
def normalize_skeleton(sequence_data, min_confidence=0.3):
    normalized_sequence = np.copy(sequence_data)
    ref_kp_names = {
        'ls': 'Left Shoulder', 'rs': 'Right Shoulder',
        'lh': 'Left Hip', 'rh': 'Right Hip'
    }
    for ref_kp_key, ref_kp_name_val in ref_kp_names.items():
        if ref_kp_name_val not in KEYPOINT_DICT:
            print(f"WARNING in normalize_skeleton: Ref keypoint '{ref_kp_name_val}' not in KEYPOINT_DICT.")

    for t in range(sequence_data.shape[0]):
        frame_data = sequence_data[t, :]
        current_frame_normalized = np.copy(frame_data)
        try:
            ls_x_idx, ls_y_idx, ls_c_idx = get_kpt_indices(ref_kp_names['ls'])
            rs_x_idx, rs_y_idx, rs_c_idx = get_kpt_indices(ref_kp_names['rs'])
            lh_x_idx, lh_y_idx, lh_c_idx = get_kpt_indices(ref_kp_names['lh'])
            rh_x_idx, rh_y_idx, rh_c_idx = get_kpt_indices(ref_kp_names['rh'])
        except ValueError:
            normalized_sequence[t, :] = frame_data; continue

        ls_x, ls_y, ls_c = frame_data[ls_x_idx], frame_data[ls_y_idx], frame_data[ls_c_idx]
        rs_x, rs_y, rs_c = frame_data[rs_x_idx], frame_data[rs_y_idx], frame_data[rs_c_idx]
        lh_x, lh_y, lh_c = frame_data[lh_x_idx], frame_data[lh_y_idx], frame_data[lh_c_idx]
        rh_x, rh_y, rh_c = frame_data[rh_x_idx], frame_data[rh_y_idx], frame_data[rh_c_idx]

        mid_shoulder_x, mid_shoulder_y = np.nan, np.nan
        valid_ls, valid_rs = ls_c > min_confidence, rs_c > min_confidence
        if valid_ls and valid_rs: mid_shoulder_x, mid_shoulder_y = (ls_x + rs_x) / 2, (ls_y + rs_y) / 2
        elif valid_ls: mid_shoulder_x, mid_shoulder_y = ls_x, ls_y
        elif valid_rs: mid_shoulder_x, mid_shoulder_y = rs_x, rs_y

        mid_hip_x, mid_hip_y = np.nan, np.nan
        valid_lh, valid_rh = lh_c > min_confidence, rh_c > min_confidence
        if valid_lh and valid_rh: mid_hip_x, mid_hip_y = (lh_x + rh_x) / 2, (lh_y + rh_y) / 2
        elif valid_lh: mid_hip_x, mid_hip_y = lh_x, lh_y
        elif valid_rh: mid_hip_x, mid_hip_y = rh_x, rh_y

        if np.isnan(mid_hip_x) or np.isnan(mid_hip_y):
            normalized_sequence[t, :] = frame_data; continue

        reference_height = np.nan
        if not np.isnan(mid_shoulder_y) and not np.isnan(mid_hip_y):
            reference_height = np.abs(mid_shoulder_y - mid_hip_y)

        perform_scaling = not (np.isnan(reference_height) or reference_height < 1e-5)

        for kp_i in range(NUM_KEYPOINTS):
            x_i_col, y_i_col = kp_i * 3, kp_i * 3 + 1
            current_frame_normalized[x_i_col] -= mid_hip_x
            current_frame_normalized[y_i_col] -= mid_hip_y
            if perform_scaling:
                current_frame_normalized[x_i_col] /= reference_height
                current_frame_normalized[y_i_col] /= reference_height
        normalized_sequence[t, :] = current_frame_normalized
    return normalized_sequence

# %%
# ----- 3. DATA LOADING FUNCTION  -----
def load_dataset(data_path, expected_shape_template=(30, None), normalize=True, min_confidence_norm=0.3):
    if NUM_KEYPOINTS is None or NUM_KEYPOINTS == 0:
        raise ValueError("NUM_KEYPOINTS is not set or is zero.")
    expected_shape = (expected_shape_template[0], NUM_KEYPOINTS * 3)
    
    X, y = [], []
    npy_filepaths = []

    print(f"Loading data from: {data_path}, expecting shape {expected_shape} for .npy files.")
    for label_name, label_val in [('no_fall', 0), ('fall', 1)]:
        folder = os.path.join(data_path, label_name)
        if not os.path.isdir(folder):
            print(f"Warning: Subfolder not found for label '{label_name}': {folder}")
            continue
        
        files_in_folder = glob(os.path.join(folder, "*.npy"))
        print(f"Found {len(files_in_folder)} .npy files in {folder}")
        
        loaded_count_for_label = 0
        for file_path_str in files_in_folder:
            try:
                arr = np.load(file_path_str)
            except Exception as e:
                print(f"Warning: Could not load file {file_path_str}: {e}")
                continue

            if arr.shape == expected_shape:
                if normalize:
                    arr_normalized = normalize_skeleton(arr, min_confidence=min_confidence_norm)
                    if np.isnan(arr_normalized).any():
                        arr_normalized = np.nan_to_num(arr_normalized, nan=0.0, posinf=0.0, neginf=0.0)
                    X.append(arr_normalized)
                else:
                    X.append(arr)
                y.append(label_val)
                npy_filepaths.append(file_path_str)
                loaded_count_for_label += 1
            else:
                print(f"Warning: Skipping file {file_path_str} due to incorrect shape: {arr.shape}. Expected: {expected_shape}")
        print(f"Successfully loaded {loaded_count_for_label} samples for label '{label_name}'.")

    if not X:
        print(f"Critical Warning: No data was loaded from {data_path}.")
        return np.array([]), np.array([]), []
        
    return np.array(X), np.array(y), npy_filepaths

# %%
# --- Transformer Encoder Block ---
def transformer_encoder_block(inputs, d_model, num_heads, ff_dim, dropout_rate=0.1, name_prefix=""):
    attention_output = MultiHeadAttention(
        num_heads=num_heads, key_dim=d_model // num_heads, dropout=dropout_rate,
        name=f"{name_prefix}_mha"
    )(inputs, inputs, inputs)
    attention_output = Dropout(dropout_rate, name=f"{name_prefix}_mha_dropout")(attention_output)
    out1 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm1")(inputs + attention_output)

    ffn_output = Dense(ff_dim, activation="relu", name=f"{name_prefix}_ffn_dense1")(out1)
    ffn_output = Dense(d_model, name=f"{name_prefix}_ffn_dense2")(ffn_output)
    ffn_output = Dropout(dropout_rate, name=f"{name_prefix}_ffn_dropout")(ffn_output)
    out2 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm2")(out1 + ffn_output)
    return out2

# --- Positional Embedding Layer (Learned) ---
def get_positional_embedding(seq_len, d_model, name_prefix=""):
    positions = tf.range(start=0, limit=seq_len, delta=1)
    position_embeddings_2d = Embedding(input_dim=seq_len, output_dim=d_model, name=f"{name_prefix}_pos_embed")(positions)
    position_embeddings_3d = tf.expand_dims(position_embeddings_2d, axis=0)
    return position_embeddings_3d

# %%
# --- Model Creation Function ---
def create_transformer_classifier(
    input_shape,
    num_encoder_blocks=2,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    projection_dim=None,
    final_dense_units=32,
    dropout_rate=0.1,
    learning_rate=0.0005
):
    timesteps, num_features = input_shape
    if projection_dim is None: projection_dim = d_model

    inputs = Input(shape=input_shape, name="input_features")
    projected_x = Dense(projection_dim, name="feature_projection")(inputs)
    positional_embeddings = get_positional_embedding(timesteps, projection_dim, name_prefix="pos_enc")
    x = Add(name="add_positional_encoding")([projected_x, positional_embeddings])
    x = Dropout(dropout_rate, name="input_dropout_after_pos_enc")(x)

    for i in range(num_encoder_blocks):
        x = transformer_encoder_block(x, projection_dim, num_heads, ff_dim, dropout_rate, name_prefix=f"encoder_block_{i+1}")

    x = GlobalAveragePooling1D(name="global_avg_pooling")(x)
    x = Dropout(dropout_rate, name="dropout_after_pooling")(x)
    x = Dense(final_dense_units, activation="relu", name="final_dense_1")(x)
    x = Dropout(dropout_rate / 2, name="dropout_final_dense")(x)
    outputs = Dense(1, activation="sigmoid", name="output_sigmoid")(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    # ใช้ tf.keras.metrics.F1Score
    # สำหรับ binary classification ที่มี output เป็น sigmoid และ target เป็น 0 หรือ 1,
    # Keras F1Score จะคำนวณ F1 ของ positive class (1) โดย default
    # ถ้าต้องการ Macro F1 (เฉลี่ย F1 ของ class 0 และ class 1)
    f1_macro_metric = tf.keras.metrics.F1Score(
        average='macro', # คำนวณ F1 สำหรับแต่ละคลาสแล้วเฉลี่ย
        threshold=0.5,   # Threshold สำหรับการแปลง probability เป็น class label
        name='f1_macro'  # ชื่อนี้จะปรากฏใน history.history
    )
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), 
                  loss='binary_crossentropy',
                  metrics=['accuracy', f1_macro_metric]) # เพิ่ม f1_macro_metric
    return model

# %%
#--- Load Dataset ---

# Paths 
base_train = '/kaggle/input/fall-dataset60/train'
base_val   = '/kaggle/input/fall-dataset60/val'
base_test  = '/kaggle/input/fall-dataset60/test'

# ----- Parameters -----
TIMESTEPS = 60
EXPECTED_SHAPE_TEMPLATE = (TIMESTEPS, None)
MIN_CONF_NORM = 0.2

print("\n--- Loading Training Data ---")
X_train_orig, y_train_orig, train_npy_filepaths = load_dataset(
    base_train, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Validation Data ---")
X_val_orig, y_val_orig, val_npy_filepaths = load_dataset(
    base_val, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Test Data ---")
X_test_orig, y_test_orig, test_npy_filepaths = load_dataset(
    base_test, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)

if X_train_orig.size == 0:
    print("FATAL ERROR: Training data is empty.")
else:
    if len(X_train_orig) == len(train_npy_filepaths): print(f"Training set: Loaded {len(X_train_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Training set! Samples: {len(X_train_orig)}, Filepaths: {len(train_npy_filepaths)}.")

if X_val_orig.size > 0:
    if len(X_val_orig) == len(val_npy_filepaths): print(f"Validation set: Loaded {len(X_val_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Validation set! Samples: {len(X_val_orig)}, Filepaths: {len(val_npy_filepaths)}.")
else: print("Validation data is empty or was not loaded.")

if X_test_orig.size > 0:
    if len(X_test_orig) == len(test_npy_filepaths): print(f"Test set: Loaded {len(X_test_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Test set! Samples: {len(X_test_orig)}, Filepaths: {len(test_npy_filepaths)}.")
else: print("Test data is empty or was not loaded.")
    
print(f"\nShapes after loading:")
print(f"Train: X={X_train_orig.shape if X_train_orig.size > 0 else 'Empty'}, y={y_train_orig.shape if y_train_orig.size > 0 else 'Empty'}")
print(f"Val:   X={X_val_orig.shape if X_val_orig.size > 0 else 'Empty'}, y={y_val_orig.shape if y_val_orig.size > 0 else 'Empty'}")
print(f"Test:  X={X_test_orig.shape if X_test_orig.size > 0 else 'Empty'}, y={y_test_orig.shape if y_test_orig.size > 0 else 'Empty'}")

if 'NUM_KEYPOINTS' in locals() and isinstance(NUM_KEYPOINTS, int) and NUM_KEYPOINTS > 0:
    transformer_input_shape = (TIMESTEPS, NUM_KEYPOINTS * 3)
    print(f"\nTransformer Input Shape: {transformer_input_shape}")
else:
    print("\nERROR: NUM_KEYPOINTS not defined correctly. Cannot determine Transformer Input Shape.")
    transformer_input_shape = (TIMESTEPS, -1)
# Out:
# --- Loading Training Data ---
# Loading data from: /kaggle/input/fall-dataset60/train, expecting shape (60, 51) for .npy files.
# Found 5953 .npy files in /kaggle/input/fall-dataset60/train/no_fall
# Successfully loaded 5953 samples for label 'no_fall'.
# Found 5564 .npy files in /kaggle/input/fall-dataset60/train/fall
# Successfully loaded 5564 samples for label 'fall'.
#
# --- Loading Validation Data ---
# Loading data from: /kaggle/input/fall-dataset60/val, expecting shape (60, 51) for .npy files.
# Found 1276 .npy files in /kaggle/input/fall-dataset60/val/no_fall
# Successfully loaded 1276 samples for label 'no_fall'.
# Found 1192 .npy files in /kaggle/input/fall-dataset60/val/fall
# Successfully loaded 1192 samples for label 'fall'.
#
# --- Loading Test Data ---
# Loading data from: /kaggle/input/fall-dataset60/test, expecting shape (60, 51) for .npy files.
# Found 1276 .npy files in /kaggle/input/fall-dataset60/test/no_fall
# Successfully loaded 1276 samples for label 'no_fall'.
# Found 1193 .npy files in /kaggle/input/fall-dataset60/test/fall
# Successfully loaded 1193 samples for label 'fall'.
# Training set: Loaded 11517 samples and filepaths.
# Validation set: Loaded 2468 samples and filepaths.
# Test set: Loaded 2469 samples and filepaths.
#
# Shapes after loading:
# Train: X=(11517, 60, 51), y=(11517,)
# Val:   X=(2468, 60, 51), y=(2468,)
# Test:  X=(2469, 60, 51), y=(2469,)
#
# Transformer Input Shape: (60, 51)

# %%
# ----- Model Parameters -----
NUM_ENCODER_BLOCKS = 3
D_MODEL = 64
NUM_HEADS = 4
FF_DIM = D_MODEL * 2
PROJECTION_DIM = D_MODEL
FINAL_DENSE_UNITS = 32
DROPOUT_RATE = 0.06
LEARNING_RATE = 0.0001

# ----- Cross-Validation -----
N_SPLITS_CV = 5
EPOCHS_CV = 50
PATIENCE_VAL = 10
BATCH_SIZE_CV = 32
cv_accuracies, cv_losses, cv_f1_macros = [], [], []
fold_no = 1

print(f"\n--- Starting {N_SPLITS_CV}-Fold Cross-Validation with Transformer Classifier ---")
if X_train_orig.shape[0] > 0 and y_train_orig.shape[0] >= N_SPLITS_CV:
    skf = StratifiedKFold(n_splits=N_SPLITS_CV, shuffle=True, random_state=42)
    for train_idx, val_idx in skf.split(X_train_orig, y_train_orig):
        print(f"--- Fold {fold_no}/{N_SPLITS_CV} ---")
        X_cv_train, X_cv_val = X_train_orig[train_idx], X_train_orig[val_idx]
        y_cv_train_1d, y_cv_val_1d = y_train_orig[train_idx], y_train_orig[val_idx] # Keep 1D versions if needed elsewhere

        # --- RESHAPE y_true for Keras F1Score metric ---
        y_cv_train_2d = y_cv_train_1d.reshape(-1, 1)
        y_cv_val_2d = y_cv_val_1d.reshape(-1, 1)
        
        cv_model = create_transformer_classifier(
            input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
            d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
            projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
            dropout_rate=DROPOUT_RATE, learning_rate=LEARNING_RATE
        )
        
        early_stopping_cv = EarlyStopping(monitor='val_f1_macro', patience=PATIENCE_VAL, verbose=1, mode='max', restore_best_weights=True)
        
        history_cv = cv_model.fit(X_cv_train, y_cv_train_2d, # Use 2D y_true for training
                                  epochs=EPOCHS_CV, batch_size=BATCH_SIZE_CV, 
                                  validation_data=(X_cv_val, y_cv_val_2d), # Use 2D y_true for validation
                                  callbacks=[early_stopping_cv],
                                  verbose=1) 
        
        # Evaluate with 2D y_true
        eval_results_cv = cv_model.evaluate(X_cv_val, y_cv_val_2d, verbose=0)
        loss, accuracy, f1_macro = eval_results_cv[0], eval_results_cv[1], eval_results_cv[2]

        print(f"Fold {fold_no} - CV Val Loss: {loss:.4f}, CV Val Acc: {accuracy:.4f}, CV Val F1-Macro: {f1_macro:.4f}")
        cv_losses.append(loss); cv_accuracies.append(accuracy); cv_f1_macros.append(f1_macro)
        fold_no += 1

    if cv_accuracies:
        print("\n--- Cross-Validation Summary ---")
        print(f"Average CV Loss: {np.mean(cv_losses):.4f} (+/- {np.std(cv_losses):.4f})")
        print(f"Average CV Accuracy: {np.mean(cv_accuracies):.4f} (+/- {np.std(cv_accuracies):.4f})")
        if cv_f1_macros:
             print(f"Average CV F1-Macro: {np.mean(cv_f1_macros):.4f} (+/- {np.std(cv_f1_macros):.4f})")
    else: 
        print("Cross-validation did not produce results (or was skipped).")
else:
    print(f"Skipping CV: Training data empty or too few samples for {N_SPLITS_CV} splits.")
# Out:
# --- Starting 5-Fold Cross-Validation with Transformer Classifier ---
# --- Fold 1/5 ---
# I0000 00:00:1749112542.567400      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749112542.568235      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749112561.499088      96 service.cc:148] XLA service 0x7e9d14002720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749112561.499641      96 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749112561.499661      96 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749112563.129923      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  17/288 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6457 - f1_macro: 0.5728 - loss: 0.6466
# I0000 00:00:1749112574.107741      96 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 46s 60ms/step - accuracy: 0.7335 - f1_macro: 0.7085 - loss: 0.5439 - val_accuracy: 0.8147 - val_f1_macro: 0.7932 - val_loss: 0.4140
# Epoch 2/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8213 - f1_macro: 0.8059 - loss: 0.4145 - val_accuracy: 0.8628 - val_f1_macro: 0.8492 - val_loss: 0.3729
# Epoch 3/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8513 - f1_macro: 0.8410 - loss: 0.3661 - val_accuracy: 0.8733 - val_f1_macro: 0.8665 - val_loss: 0.3213
# Epoch 4/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8715 - f1_macro: 0.8637 - loss: 0.3215 - val_accuracy: 0.8776 - val_f1_macro: 0.8685 - val_loss: 0.3153
# Epoch 5/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8828 - f1_macro: 0.8791 - loss: 0.3022 - val_accuracy: 0.8854 - val_f1_macro: 0.8771 - val_loss: 0.3257
# Epoch 6/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8779 - f1_macro: 0.8725 - loss: 0.3043 - val_accuracy: 0.8915 - val_f1_macro: 0.8852 - val_loss: 0.2991
# Epoch 7/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8897 - f1_macro: 0.8850 - loss: 0.2871 - val_accuracy: 0.8915 - val_f1_macro: 0.8826 - val_loss: 0.3043
# Epoch 8/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8888 - f1_macro: 0.8841 - loss: 0.2839 - val_accuracy: 0.8932 - val_f1_macro: 0.8873 - val_loss: 0.2926
# Epoch 9/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9040 - f1_macro: 0.9008 - loss: 0.2548 - val_accuracy: 0.8945 - val_f1_macro: 0.8872 - val_loss: 0.3011
# Epoch 10/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9004 - f1_macro: 0.8977 - loss: 0.2630 - val_accuracy: 0.8950 - val_f1_macro: 0.8867 - val_loss: 0.2908
# Epoch 11/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9006 - f1_macro: 0.8971 - loss: 0.2511 - val_accuracy: 0.9028 - val_f1_macro: 0.8986 - val_loss: 0.2645
# Epoch 12/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9086 - f1_macro: 0.9054 - loss: 0.2381 - val_accuracy: 0.8993 - val_f1_macro: 0.8925 - val_loss: 0.2695
# Epoch 13/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9074 - f1_macro: 0.9027 - loss: 0.2413 - val_accuracy: 0.8911 - val_f1_macro: 0.8808 - val_loss: 0.3076
# Epoch 14/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9067 - f1_macro: 0.9012 - loss: 0.2304 - val_accuracy: 0.8980 - val_f1_macro: 0.8919 - val_loss: 0.2997
# Epoch 15/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9064 - f1_macro: 0.9017 - loss: 0.2402 - val_accuracy: 0.9006 - val_f1_macro: 0.8971 - val_loss: 0.2535
# Epoch 16/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9159 - f1_macro: 0.9131 - loss: 0.2234 - val_accuracy: 0.9062 - val_f1_macro: 0.9011 - val_loss: 0.2552
# Epoch 17/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9196 - f1_macro: 0.9159 - loss: 0.2136 - val_accuracy: 0.9058 - val_f1_macro: 0.8998 - val_loss: 0.2496
# Epoch 18/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9236 - f1_macro: 0.9205 - loss: 0.2082 - val_accuracy: 0.9023 - val_f1_macro: 0.8939 - val_loss: 0.2740
# Epoch 19/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9250 - f1_macro: 0.9227 - loss: 0.1976 - val_accuracy: 0.8989 - val_f1_macro: 0.8938 - val_loss: 0.2631
# Epoch 20/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9242 - f1_macro: 0.9230 - loss: 0.2028 - val_accuracy: 0.8997 - val_f1_macro: 0.8909 - val_loss: 0.2647
# Epoch 21/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9280 - f1_macro: 0.9245 - loss: 0.1924 - val_accuracy: 0.9028 - val_f1_macro: 0.8972 - val_loss: 0.2556
# Epoch 22/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9279 - f1_macro: 0.9251 - loss: 0.1884 - val_accuracy: 0.9106 - val_f1_macro: 0.9042 - val_loss: 0.2398
# Epoch 23/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9334 - f1_macro: 0.9302 - loss: 0.1829 - val_accuracy: 0.9067 - val_f1_macro: 0.8982 - val_loss: 0.2547
# Epoch 24/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9339 - f1_macro: 0.9296 - loss: 0.1749 - val_accuracy: 0.9110 - val_f1_macro: 0.9074 - val_loss: 0.2303
# Epoch 25/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9395 - f1_macro: 0.9374 - loss: 0.1708 - val_accuracy: 0.9036 - val_f1_macro: 0.8960 - val_loss: 0.2411
# Epoch 26/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9327 - f1_macro: 0.9304 - loss: 0.1788 - val_accuracy: 0.9123 - val_f1_macro: 0.9064 - val_loss: 0.2412
# Epoch 27/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9430 - f1_macro: 0.9411 - loss: 0.1583 - val_accuracy: 0.9162 - val_f1_macro: 0.9115 - val_loss: 0.2282
# Epoch 28/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9464 - f1_macro: 0.9438 - loss: 0.1492 - val_accuracy: 0.9110 - val_f1_macro: 0.9063 - val_loss: 0.2455
# Epoch 29/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9398 - f1_macro: 0.9374 - loss: 0.1618 - val_accuracy: 0.9115 - val_f1_macro: 0.9066 - val_loss: 0.2398
# Epoch 30/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9404 - f1_macro: 0.9382 - loss: 0.1642 - val_accuracy: 0.9184 - val_f1_macro: 0.9125 - val_loss: 0.2370
# Epoch 31/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9404 - f1_macro: 0.9386 - loss: 0.1621 - val_accuracy: 0.9062 - val_f1_macro: 0.8984 - val_loss: 0.2615
# Epoch 32/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9458 - f1_macro: 0.9431 - loss: 0.1465 - val_accuracy: 0.9123 - val_f1_macro: 0.9065 - val_loss: 0.2325
# Epoch 33/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9478 - f1_macro: 0.9460 - loss: 0.1436 - val_accuracy: 0.9193 - val_f1_macro: 0.9158 - val_loss: 0.2225
# Epoch 34/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9454 - f1_macro: 0.9435 - loss: 0.1452 - val_accuracy: 0.9184 - val_f1_macro: 0.9144 - val_loss: 0.2290
# Epoch 35/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9482 - f1_macro: 0.9460 - loss: 0.1399 - val_accuracy: 0.9227 - val_f1_macro: 0.9187 - val_loss: 0.2221
# Epoch 36/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9458 - f1_macro: 0.9430 - loss: 0.1402 - val_accuracy: 0.9201 - val_f1_macro: 0.9156 - val_loss: 0.2389
# Epoch 37/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9480 - f1_macro: 0.9459 - loss: 0.1350 - val_accuracy: 0.9240 - val_f1_macro: 0.9194 - val_loss: 0.2234
# Epoch 38/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9523 - f1_macro: 0.9501 - loss: 0.1282 - val_accuracy: 0.9110 - val_f1_macro: 0.9078 - val_loss: 0.2561
# Epoch 39/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9513 - f1_macro: 0.9498 - loss: 0.1262 - val_accuracy: 0.9158 - val_f1_macro: 0.9125 - val_loss: 0.2435
# Epoch 40/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9535 - f1_macro: 0.9524 - loss: 0.1262 - val_accuracy: 0.9149 - val_f1_macro: 0.9086 - val_loss: 0.2516
# Epoch 41/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9542 - f1_macro: 0.9522 - loss: 0.1268 - val_accuracy: 0.9210 - val_f1_macro: 0.9177 - val_loss: 0.2415
# Epoch 42/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9614 - f1_macro: 0.9596 - loss: 0.1076 - val_accuracy: 0.9249 - val_f1_macro: 0.9211 - val_loss: 0.2320
# Epoch 43/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9605 - f1_macro: 0.9583 - loss: 0.1125 - val_accuracy: 0.9262 - val_f1_macro: 0.9215 - val_loss: 0.2281
# Epoch 44/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9566 - f1_macro: 0.9547 - loss: 0.1203 - val_accuracy: 0.9149 - val_f1_macro: 0.9088 - val_loss: 0.2518
# Epoch 45/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9543 - f1_macro: 0.9538 - loss: 0.1224 - val_accuracy: 0.9149 - val_f1_macro: 0.9114 - val_loss: 0.2511
# Epoch 46/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9623 - f1_macro: 0.9613 - loss: 0.1070 - val_accuracy: 0.9262 - val_f1_macro: 0.9234 - val_loss: 0.2274
# Epoch 47/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9605 - f1_macro: 0.9589 - loss: 0.1072 - val_accuracy: 0.9223 - val_f1_macro: 0.9187 - val_loss: 0.2368
# Epoch 48/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9605 - f1_macro: 0.9590 - loss: 0.1073 - val_accuracy: 0.9266 - val_f1_macro: 0.9229 - val_loss: 0.2315
# Epoch 49/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9615 - f1_macro: 0.9602 - loss: 0.1046 - val_accuracy: 0.9201 - val_f1_macro: 0.9167 - val_loss: 0.2520
# Epoch 50/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9599 - f1_macro: 0.9588 - loss: 0.1092 - val_accuracy: 0.9262 - val_f1_macro: 0.9218 - val_loss: 0.2455
# Restoring model weights from the end of the best epoch: 46.
# Fold 1 - CV Val Loss: 0.2274, CV Val Acc: 0.9262, CV Val F1-Macro: 0.9234
# --- Fold 2/5 ---
# Epoch 1/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.7128 - f1_macro: 0.6890 - loss: 0.5599 - val_accuracy: 0.8047 - val_f1_macro: 0.7847 - val_loss: 0.4574
# Epoch 2/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8236 - f1_macro: 0.8083 - loss: 0.4149 - val_accuracy: 0.8264 - val_f1_macro: 0.8075 - val_loss: 0.4042
# Epoch 3/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8470 - f1_macro: 0.8361 - loss: 0.3691 - val_accuracy: 0.8459 - val_f1_macro: 0.8383 - val_loss: 0.3684
# Epoch 4/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8683 - f1_macro: 0.8618 - loss: 0.3250 - val_accuracy: 0.8663 - val_f1_macro: 0.8600 - val_loss: 0.3332
# Epoch 5/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8798 - f1_macro: 0.8736 - loss: 0.3052 - val_accuracy: 0.8672 - val_f1_macro: 0.8601 - val_loss: 0.3379
# Epoch 6/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8894 - f1_macro: 0.8861 - loss: 0.2941 - val_accuracy: 0.8720 - val_f1_macro: 0.8658 - val_loss: 0.3158
# Epoch 7/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8900 - f1_macro: 0.8851 - loss: 0.2841 - val_accuracy: 0.8785 - val_f1_macro: 0.8744 - val_loss: 0.3072
# Epoch 8/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8951 - f1_macro: 0.8915 - loss: 0.2753 - val_accuracy: 0.8793 - val_f1_macro: 0.8741 - val_loss: 0.2969
# Epoch 9/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9022 - f1_macro: 0.8991 - loss: 0.2550 - val_accuracy: 0.8806 - val_f1_macro: 0.8764 - val_loss: 0.3034
# Epoch 10/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8995 - f1_macro: 0.8956 - loss: 0.2602 - val_accuracy: 0.8806 - val_f1_macro: 0.8738 - val_loss: 0.3011
# Epoch 11/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9018 - f1_macro: 0.8966 - loss: 0.2558 - val_accuracy: 0.8906 - val_f1_macro: 0.8885 - val_loss: 0.2902
# Epoch 12/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9060 - f1_macro: 0.9021 - loss: 0.2493 - val_accuracy: 0.8932 - val_f1_macro: 0.8887 - val_loss: 0.2864
# Epoch 13/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9094 - f1_macro: 0.9057 - loss: 0.2400 - val_accuracy: 0.8872 - val_f1_macro: 0.8854 - val_loss: 0.2778
# Epoch 14/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9114 - f1_macro: 0.9079 - loss: 0.2326 - val_accuracy: 0.8963 - val_f1_macro: 0.8908 - val_loss: 0.2808
# Epoch 15/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9074 - f1_macro: 0.9016 - loss: 0.2373 - val_accuracy: 0.8963 - val_f1_macro: 0.8936 - val_loss: 0.2649
# Epoch 16/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9162 - f1_macro: 0.9139 - loss: 0.2186 - val_accuracy: 0.8902 - val_f1_macro: 0.8868 - val_loss: 0.2759
# Epoch 17/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9149 - f1_macro: 0.9108 - loss: 0.2174 - val_accuracy: 0.8915 - val_f1_macro: 0.8893 - val_loss: 0.2736
# Epoch 18/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9136 - f1_macro: 0.9120 - loss: 0.2216 - val_accuracy: 0.8971 - val_f1_macro: 0.8938 - val_loss: 0.2716
# Epoch 19/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9268 - f1_macro: 0.9236 - loss: 0.1958 - val_accuracy: 0.8950 - val_f1_macro: 0.8910 - val_loss: 0.2650
# Epoch 20/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9208 - f1_macro: 0.9169 - loss: 0.2100 - val_accuracy: 0.9002 - val_f1_macro: 0.8963 - val_loss: 0.2700
# Epoch 21/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9232 - f1_macro: 0.9192 - loss: 0.1966 - val_accuracy: 0.8932 - val_f1_macro: 0.8905 - val_loss: 0.2623
# Epoch 22/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9328 - f1_macro: 0.9302 - loss: 0.1959 - val_accuracy: 0.9019 - val_f1_macro: 0.8974 - val_loss: 0.2650
# Epoch 23/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9268 - f1_macro: 0.9257 - loss: 0.1852 - val_accuracy: 0.9015 - val_f1_macro: 0.8986 - val_loss: 0.2564
# Epoch 24/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9240 - f1_macro: 0.9207 - loss: 0.1909 - val_accuracy: 0.9028 - val_f1_macro: 0.8999 - val_loss: 0.2637
# Epoch 25/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9298 - f1_macro: 0.9275 - loss: 0.1874 - val_accuracy: 0.9023 - val_f1_macro: 0.8992 - val_loss: 0.2679
# Epoch 26/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9337 - f1_macro: 0.9319 - loss: 0.1703 - val_accuracy: 0.8989 - val_f1_macro: 0.8939 - val_loss: 0.2701
# Epoch 27/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9315 - f1_macro: 0.9281 - loss: 0.1759 - val_accuracy: 0.9097 - val_f1_macro: 0.9064 - val_loss: 0.2489
# Epoch 28/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9366 - f1_macro: 0.9338 - loss: 0.1626 - val_accuracy: 0.9102 - val_f1_macro: 0.9066 - val_loss: 0.2535
# Epoch 29/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9394 - f1_macro: 0.9375 - loss: 0.1631 - val_accuracy: 0.9028 - val_f1_macro: 0.8970 - val_loss: 0.2738
# Epoch 30/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9403 - f1_macro: 0.9378 - loss: 0.1571 - val_accuracy: 0.9041 - val_f1_macro: 0.8996 - val_loss: 0.2678
# Epoch 31/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9394 - f1_macro: 0.9372 - loss: 0.1574 - val_accuracy: 0.9028 - val_f1_macro: 0.8978 - val_loss: 0.2851
# Epoch 32/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9424 - f1_macro: 0.9410 - loss: 0.1571 - val_accuracy: 0.9028 - val_f1_macro: 0.8991 - val_loss: 0.2668
# Epoch 33/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9419 - f1_macro: 0.9388 - loss: 0.1555 - val_accuracy: 0.9067 - val_f1_macro: 0.9033 - val_loss: 0.2524
# Epoch 34/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9447 - f1_macro: 0.9430 - loss: 0.1554 - val_accuracy: 0.9067 - val_f1_macro: 0.9025 - val_loss: 0.2723
# Epoch 35/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9452 - f1_macro: 0.9437 - loss: 0.1460 - val_accuracy: 0.9128 - val_f1_macro: 0.9088 - val_loss: 0.2553
# Epoch 36/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9472 - f1_macro: 0.9447 - loss: 0.1419 - val_accuracy: 0.9093 - val_f1_macro: 0.9062 - val_loss: 0.2763
# Epoch 37/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9489 - f1_macro: 0.9467 - loss: 0.1379 - val_accuracy: 0.9132 - val_f1_macro: 0.9106 - val_loss: 0.2638
# Epoch 38/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9463 - f1_macro: 0.9437 - loss: 0.1405 - val_accuracy: 0.9080 - val_f1_macro: 0.9035 - val_loss: 0.2604
# Epoch 39/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9455 - f1_macro: 0.9437 - loss: 0.1449 - val_accuracy: 0.9136 - val_f1_macro: 0.9118 - val_loss: 0.2578
# Epoch 40/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9490 - f1_macro: 0.9472 - loss: 0.1337 - val_accuracy: 0.9058 - val_f1_macro: 0.9009 - val_loss: 0.2672
# Epoch 41/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9516 - f1_macro: 0.9492 - loss: 0.1258 - val_accuracy: 0.9102 - val_f1_macro: 0.9048 - val_loss: 0.2608
# Epoch 42/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9525 - f1_macro: 0.9507 - loss: 0.1287 - val_accuracy: 0.9102 - val_f1_macro: 0.9047 - val_loss: 0.2657
# Epoch 43/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9536 - f1_macro: 0.9515 - loss: 0.1252 - val_accuracy: 0.9102 - val_f1_macro: 0.9060 - val_loss: 0.2635
# Epoch 44/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9558 - f1_macro: 0.9538 - loss: 0.1226 - val_accuracy: 0.9149 - val_f1_macro: 0.9123 - val_loss: 0.2679
# Epoch 45/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9559 - f1_macro: 0.9543 - loss: 0.1154 - val_accuracy: 0.9193 - val_f1_macro: 0.9170 - val_loss: 0.2597
# Epoch 46/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9557 - f1_macro: 0.9545 - loss: 0.1188 - val_accuracy: 0.9128 - val_f1_macro: 0.9092 - val_loss: 0.2770
# Epoch 47/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9463 - f1_macro: 0.9441 - loss: 0.1372 - val_accuracy: 0.9197 - val_f1_macro: 0.9176 - val_loss: 0.2584
# Epoch 48/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9568 - f1_macro: 0.9541 - loss: 0.1166 - val_accuracy: 0.9180 - val_f1_macro: 0.9160 - val_loss: 0.2514
# Epoch 49/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9613 - f1_macro: 0.9606 - loss: 0.1054 - val_accuracy: 0.9197 - val_f1_macro: 0.9159 - val_loss: 0.2476
# Epoch 50/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9563 - f1_macro: 0.9547 - loss: 0.1188 - val_accuracy: 0.9132 - val_f1_macro: 0.9097 - val_loss: 0.2697
# Restoring model weights from the end of the best epoch: 47.
# Fold 2 - CV Val Loss: 0.2584, CV Val Acc: 0.9197, CV Val F1-Macro: 0.9176
# --- Fold 3/5 ---
# Epoch 1/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 46s 66ms/step - accuracy: 0.6846 - f1_macro: 0.6800 - loss: 0.5995 - val_accuracy: 0.8055 - val_f1_macro: 0.7819 - val_loss: 0.4432
# Epoch 2/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8230 - f1_macro: 0.8059 - loss: 0.4104 - val_accuracy: 0.8359 - val_f1_macro: 0.8190 - val_loss: 0.3839
# Epoch 3/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8517 - f1_macro: 0.8381 - loss: 0.3652 - val_accuracy: 0.8571 - val_f1_macro: 0.8425 - val_loss: 0.3560
# Epoch 4/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8674 - f1_macro: 0.8598 - loss: 0.3290 - val_accuracy: 0.8563 - val_f1_macro: 0.8411 - val_loss: 0.3544
# Epoch 5/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8707 - f1_macro: 0.8638 - loss: 0.3233 - val_accuracy: 0.8758 - val_f1_macro: 0.8676 - val_loss: 0.3286
# Epoch 6/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8836 - f1_macro: 0.8772 - loss: 0.2973 - val_accuracy: 0.8767 - val_f1_macro: 0.8682 - val_loss: 0.3171
# Epoch 7/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8886 - f1_macro: 0.8830 - loss: 0.2850 - val_accuracy: 0.8767 - val_f1_macro: 0.8728 - val_loss: 0.3154
# Epoch 8/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8856 - f1_macro: 0.8780 - loss: 0.2870 - val_accuracy: 0.8789 - val_f1_macro: 0.8678 - val_loss: 0.3278
# Epoch 9/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8898 - f1_macro: 0.8855 - loss: 0.2764 - val_accuracy: 0.8828 - val_f1_macro: 0.8774 - val_loss: 0.3123
# Epoch 10/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8904 - f1_macro: 0.8860 - loss: 0.2774 - val_accuracy: 0.8875 - val_f1_macro: 0.8849 - val_loss: 0.3009
# Epoch 11/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9030 - f1_macro: 0.8986 - loss: 0.2587 - val_accuracy: 0.8806 - val_f1_macro: 0.8694 - val_loss: 0.2987
# Epoch 12/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9020 - f1_macro: 0.8970 - loss: 0.2568 - val_accuracy: 0.8810 - val_f1_macro: 0.8693 - val_loss: 0.3138
# Epoch 13/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9100 - f1_macro: 0.9054 - loss: 0.2347 - val_accuracy: 0.8906 - val_f1_macro: 0.8821 - val_loss: 0.2983
# Epoch 14/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9102 - f1_macro: 0.9064 - loss: 0.2410 - val_accuracy: 0.8923 - val_f1_macro: 0.8876 - val_loss: 0.2919
# Epoch 15/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9099 - f1_macro: 0.9049 - loss: 0.2359 - val_accuracy: 0.8949 - val_f1_macro: 0.8888 - val_loss: 0.2936
# Epoch 16/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9152 - f1_macro: 0.9120 - loss: 0.2281 - val_accuracy: 0.8923 - val_f1_macro: 0.8879 - val_loss: 0.2978
# Epoch 17/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9206 - f1_macro: 0.9166 - loss: 0.2144 - val_accuracy: 0.8880 - val_f1_macro: 0.8837 - val_loss: 0.2806
# Epoch 18/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9149 - f1_macro: 0.9117 - loss: 0.2190 - val_accuracy: 0.9032 - val_f1_macro: 0.8968 - val_loss: 0.2629
# Epoch 19/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9174 - f1_macro: 0.9137 - loss: 0.2258 - val_accuracy: 0.8997 - val_f1_macro: 0.8961 - val_loss: 0.2727
# Epoch 20/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9219 - f1_macro: 0.9176 - loss: 0.2111 - val_accuracy: 0.9001 - val_f1_macro: 0.8960 - val_loss: 0.2636
# Epoch 21/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9279 - f1_macro: 0.9242 - loss: 0.1967 - val_accuracy: 0.9023 - val_f1_macro: 0.8962 - val_loss: 0.2697
# Epoch 22/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9239 - f1_macro: 0.9200 - loss: 0.2073 - val_accuracy: 0.8936 - val_f1_macro: 0.8908 - val_loss: 0.2884
# Epoch 23/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9164 - f1_macro: 0.9116 - loss: 0.2085 - val_accuracy: 0.9023 - val_f1_macro: 0.8982 - val_loss: 0.2823
# Epoch 24/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9313 - f1_macro: 0.9269 - loss: 0.1863 - val_accuracy: 0.9097 - val_f1_macro: 0.9059 - val_loss: 0.2613
# Epoch 25/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9314 - f1_macro: 0.9271 - loss: 0.1812 - val_accuracy: 0.9088 - val_f1_macro: 0.9055 - val_loss: 0.2622
# Epoch 26/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9276 - f1_macro: 0.9235 - loss: 0.1904 - val_accuracy: 0.9140 - val_f1_macro: 0.9090 - val_loss: 0.2542
# Epoch 27/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9334 - f1_macro: 0.9299 - loss: 0.1858 - val_accuracy: 0.9053 - val_f1_macro: 0.9025 - val_loss: 0.2830
# Epoch 28/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9344 - f1_macro: 0.9312 - loss: 0.1776 - val_accuracy: 0.9127 - val_f1_macro: 0.9105 - val_loss: 0.2595
# Epoch 29/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9352 - f1_macro: 0.9313 - loss: 0.1732 - val_accuracy: 0.9049 - val_f1_macro: 0.8983 - val_loss: 0.2727
# Epoch 30/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9335 - f1_macro: 0.9297 - loss: 0.1751 - val_accuracy: 0.9127 - val_f1_macro: 0.9069 - val_loss: 0.2600
# Epoch 31/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9379 - f1_macro: 0.9356 - loss: 0.1693 - val_accuracy: 0.9175 - val_f1_macro: 0.9133 - val_loss: 0.2529
# Epoch 32/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9372 - f1_macro: 0.9329 - loss: 0.1632 - val_accuracy: 0.9179 - val_f1_macro: 0.9126 - val_loss: 0.2385
# Epoch 33/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9371 - f1_macro: 0.9345 - loss: 0.1666 - val_accuracy: 0.9127 - val_f1_macro: 0.9085 - val_loss: 0.2612
# Epoch 34/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9436 - f1_macro: 0.9404 - loss: 0.1525 - val_accuracy: 0.9188 - val_f1_macro: 0.9143 - val_loss: 0.2466
# Epoch 35/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9362 - f1_macro: 0.9348 - loss: 0.1650 - val_accuracy: 0.9240 - val_f1_macro: 0.9215 - val_loss: 0.2456
# Epoch 36/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9444 - f1_macro: 0.9418 - loss: 0.1496 - val_accuracy: 0.9149 - val_f1_macro: 0.9107 - val_loss: 0.2745
# Epoch 37/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9415 - f1_macro: 0.9390 - loss: 0.1619 - val_accuracy: 0.9188 - val_f1_macro: 0.9147 - val_loss: 0.2517
# Epoch 38/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9458 - f1_macro: 0.9424 - loss: 0.1521 - val_accuracy: 0.9210 - val_f1_macro: 0.9184 - val_loss: 0.2513
# Epoch 39/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9435 - f1_macro: 0.9412 - loss: 0.1512 - val_accuracy: 0.9257 - val_f1_macro: 0.9223 - val_loss: 0.2398
# Epoch 40/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9490 - f1_macro: 0.9471 - loss: 0.1324 - val_accuracy: 0.9192 - val_f1_macro: 0.9169 - val_loss: 0.2643
# Epoch 41/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9495 - f1_macro: 0.9475 - loss: 0.1333 - val_accuracy: 0.9188 - val_f1_macro: 0.9154 - val_loss: 0.2537
# Epoch 42/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9534 - f1_macro: 0.9516 - loss: 0.1271 - val_accuracy: 0.9301 - val_f1_macro: 0.9279 - val_loss: 0.2427
# Epoch 43/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9528 - f1_macro: 0.9513 - loss: 0.1260 - val_accuracy: 0.9231 - val_f1_macro: 0.9179 - val_loss: 0.2484
# Epoch 44/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9521 - f1_macro: 0.9495 - loss: 0.1264 - val_accuracy: 0.9266 - val_f1_macro: 0.9229 - val_loss: 0.2448
# Epoch 45/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9590 - f1_macro: 0.9573 - loss: 0.1155 - val_accuracy: 0.9184 - val_f1_macro: 0.9173 - val_loss: 0.2684
# Epoch 46/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9489 - f1_macro: 0.9469 - loss: 0.1344 - val_accuracy: 0.9201 - val_f1_macro: 0.9171 - val_loss: 0.2603
# Epoch 47/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9470 - f1_macro: 0.9450 - loss: 0.1368 - val_accuracy: 0.9236 - val_f1_macro: 0.9214 - val_loss: 0.2564
# Epoch 48/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9487 - f1_macro: 0.9481 - loss: 0.1326 - val_accuracy: 0.9214 - val_f1_macro: 0.9161 - val_loss: 0.2602
# Epoch 49/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9496 - f1_macro: 0.9477 - loss: 0.1345 - val_accuracy: 0.9201 - val_f1_macro: 0.9181 - val_loss: 0.2745
# Epoch 50/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9514 - f1_macro: 0.9502 - loss: 0.1293 - val_accuracy: 0.9175 - val_f1_macro: 0.9142 - val_loss: 0.2689
# Restoring model weights from the end of the best epoch: 42.
# Fold 3 - CV Val Loss: 0.2427, CV Val Acc: 0.9301, CV Val F1-Macro: 0.9279
# --- Fold 4/5 ---
# Epoch 1/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 43s 58ms/step - accuracy: 0.7056 - f1_macro: 0.6744 - loss: 0.5696 - val_accuracy: 0.8215 - val_f1_macro: 0.8042 - val_loss: 0.4099
# Epoch 2/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8172 - f1_macro: 0.8039 - loss: 0.4189 - val_accuracy: 0.8697 - val_f1_macro: 0.8626 - val_loss: 0.3479
# Epoch 3/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8477 - f1_macro: 0.8384 - loss: 0.3696 - val_accuracy: 0.8715 - val_f1_macro: 0.8637 - val_loss: 0.3101
# Epoch 4/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8570 - f1_macro: 0.8509 - loss: 0.3433 - val_accuracy: 0.8828 - val_f1_macro: 0.8794 - val_loss: 0.2944
# Epoch 5/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8740 - f1_macro: 0.8674 - loss: 0.3155 - val_accuracy: 0.8867 - val_f1_macro: 0.8820 - val_loss: 0.2844
# Epoch 6/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8759 - f1_macro: 0.8681 - loss: 0.3110 - val_accuracy: 0.8862 - val_f1_macro: 0.8851 - val_loss: 0.2812
# Epoch 7/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8837 - f1_macro: 0.8776 - loss: 0.2966 - val_accuracy: 0.8914 - val_f1_macro: 0.8870 - val_loss: 0.2646
# Epoch 8/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8867 - f1_macro: 0.8792 - loss: 0.2861 - val_accuracy: 0.8932 - val_f1_macro: 0.8897 - val_loss: 0.2696
# Epoch 9/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8892 - f1_macro: 0.8831 - loss: 0.2885 - val_accuracy: 0.8980 - val_f1_macro: 0.8942 - val_loss: 0.2539
# Epoch 10/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8923 - f1_macro: 0.8855 - loss: 0.2735 - val_accuracy: 0.8927 - val_f1_macro: 0.8889 - val_loss: 0.2776
# Epoch 11/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8954 - f1_macro: 0.8910 - loss: 0.2690 - val_accuracy: 0.9006 - val_f1_macro: 0.8991 - val_loss: 0.2484
# Epoch 12/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8955 - f1_macro: 0.8907 - loss: 0.2679 - val_accuracy: 0.9045 - val_f1_macro: 0.9033 - val_loss: 0.2424
# Epoch 13/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9063 - f1_macro: 0.9021 - loss: 0.2519 - val_accuracy: 0.9036 - val_f1_macro: 0.9000 - val_loss: 0.2422
# Epoch 14/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9006 - f1_macro: 0.8967 - loss: 0.2588 - val_accuracy: 0.8984 - val_f1_macro: 0.8916 - val_loss: 0.2541
# Epoch 15/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9094 - f1_macro: 0.9052 - loss: 0.2363 - val_accuracy: 0.9088 - val_f1_macro: 0.9067 - val_loss: 0.2280
# Epoch 16/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9112 - f1_macro: 0.9063 - loss: 0.2292 - val_accuracy: 0.9127 - val_f1_macro: 0.9087 - val_loss: 0.2296
# Epoch 17/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9078 - f1_macro: 0.9039 - loss: 0.2346 - val_accuracy: 0.9097 - val_f1_macro: 0.9057 - val_loss: 0.2300
# Epoch 18/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9120 - f1_macro: 0.9100 - loss: 0.2300 - val_accuracy: 0.9079 - val_f1_macro: 0.9043 - val_loss: 0.2207
# Epoch 19/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9216 - f1_macro: 0.9180 - loss: 0.2129 - val_accuracy: 0.9158 - val_f1_macro: 0.9144 - val_loss: 0.2130
# Epoch 20/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9193 - f1_macro: 0.9150 - loss: 0.2159 - val_accuracy: 0.9210 - val_f1_macro: 0.9185 - val_loss: 0.2045
# Epoch 21/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9222 - f1_macro: 0.9171 - loss: 0.2033 - val_accuracy: 0.9197 - val_f1_macro: 0.9158 - val_loss: 0.2028
# Epoch 22/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9234 - f1_macro: 0.9207 - loss: 0.2049 - val_accuracy: 0.9119 - val_f1_macro: 0.9045 - val_loss: 0.2367
# Epoch 23/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9226 - f1_macro: 0.9180 - loss: 0.2000 - val_accuracy: 0.9257 - val_f1_macro: 0.9230 - val_loss: 0.2042
# Epoch 24/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9274 - f1_macro: 0.9243 - loss: 0.1897 - val_accuracy: 0.9192 - val_f1_macro: 0.9148 - val_loss: 0.2046
# Epoch 25/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9270 - f1_macro: 0.9228 - loss: 0.1958 - val_accuracy: 0.9201 - val_f1_macro: 0.9179 - val_loss: 0.1955
# Epoch 26/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9292 - f1_macro: 0.9258 - loss: 0.1845 - val_accuracy: 0.9197 - val_f1_macro: 0.9156 - val_loss: 0.2038
# Epoch 27/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9249 - f1_macro: 0.9219 - loss: 0.1913 - val_accuracy: 0.9223 - val_f1_macro: 0.9177 - val_loss: 0.1942
# Epoch 28/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9338 - f1_macro: 0.9309 - loss: 0.1789 - val_accuracy: 0.9218 - val_f1_macro: 0.9176 - val_loss: 0.2046
# Epoch 29/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9316 - f1_macro: 0.9290 - loss: 0.1752 - val_accuracy: 0.9279 - val_f1_macro: 0.9245 - val_loss: 0.1888
# Epoch 30/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9352 - f1_macro: 0.9316 - loss: 0.1770 - val_accuracy: 0.9249 - val_f1_macro: 0.9236 - val_loss: 0.1984
# Epoch 31/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9423 - f1_macro: 0.9401 - loss: 0.1570 - val_accuracy: 0.9353 - val_f1_macro: 0.9330 - val_loss: 0.1809
# Epoch 32/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9370 - f1_macro: 0.9337 - loss: 0.1714 - val_accuracy: 0.9305 - val_f1_macro: 0.9290 - val_loss: 0.1863
# Epoch 33/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9442 - f1_macro: 0.9417 - loss: 0.1600 - val_accuracy: 0.9314 - val_f1_macro: 0.9283 - val_loss: 0.1842
# Epoch 34/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9430 - f1_macro: 0.9415 - loss: 0.1632 - val_accuracy: 0.9357 - val_f1_macro: 0.9327 - val_loss: 0.1888
# Epoch 35/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9473 - f1_macro: 0.9448 - loss: 0.1486 - val_accuracy: 0.9262 - val_f1_macro: 0.9223 - val_loss: 0.1894
# Epoch 36/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9465 - f1_macro: 0.9437 - loss: 0.1497 - val_accuracy: 0.9310 - val_f1_macro: 0.9299 - val_loss: 0.1918
# Epoch 37/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9470 - f1_macro: 0.9457 - loss: 0.1462 - val_accuracy: 0.9314 - val_f1_macro: 0.9287 - val_loss: 0.1806
# Epoch 38/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9443 - f1_macro: 0.9409 - loss: 0.1451 - val_accuracy: 0.9340 - val_f1_macro: 0.9310 - val_loss: 0.1777
# Epoch 39/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9436 - f1_macro: 0.9417 - loss: 0.1488 - val_accuracy: 0.9292 - val_f1_macro: 0.9248 - val_loss: 0.1976
# Epoch 40/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9497 - f1_macro: 0.9477 - loss: 0.1406 - val_accuracy: 0.9305 - val_f1_macro: 0.9263 - val_loss: 0.1911
# Epoch 41/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9473 - f1_macro: 0.9453 - loss: 0.1390 - val_accuracy: 0.9336 - val_f1_macro: 0.9314 - val_loss: 0.1831
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Fold 4 - CV Val Loss: 0.1809, CV Val Acc: 0.9353, CV Val F1-Macro: 0.9330
# --- Fold 5/5 ---
# Epoch 1/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 43s 59ms/step - accuracy: 0.7179 - f1_macro: 0.6974 - loss: 0.5557 - val_accuracy: 0.8059 - val_f1_macro: 0.7904 - val_loss: 0.4280
# Epoch 2/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8119 - f1_macro: 0.7942 - loss: 0.4281 - val_accuracy: 0.8354 - val_f1_macro: 0.8193 - val_loss: 0.3750
# Epoch 3/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8445 - f1_macro: 0.8345 - loss: 0.3733 - val_accuracy: 0.8515 - val_f1_macro: 0.8337 - val_loss: 0.3427
# Epoch 4/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8513 - f1_macro: 0.8433 - loss: 0.3562 - val_accuracy: 0.8645 - val_f1_macro: 0.8528 - val_loss: 0.3195
# Epoch 5/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8685 - f1_macro: 0.8594 - loss: 0.3290 - val_accuracy: 0.8732 - val_f1_macro: 0.8646 - val_loss: 0.3051
# Epoch 6/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8776 - f1_macro: 0.8709 - loss: 0.3120 - val_accuracy: 0.8732 - val_f1_macro: 0.8623 - val_loss: 0.3029
# Epoch 7/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8878 - f1_macro: 0.8807 - loss: 0.2852 - val_accuracy: 0.8819 - val_f1_macro: 0.8715 - val_loss: 0.3060
# Epoch 8/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8821 - f1_macro: 0.8756 - loss: 0.3053 - val_accuracy: 0.8897 - val_f1_macro: 0.8827 - val_loss: 0.2754
# Epoch 9/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8884 - f1_macro: 0.8805 - loss: 0.2904 - val_accuracy: 0.8910 - val_f1_macro: 0.8871 - val_loss: 0.2750
# Epoch 10/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8929 - f1_macro: 0.8866 - loss: 0.2765 - val_accuracy: 0.8936 - val_f1_macro: 0.8873 - val_loss: 0.2766
# Epoch 11/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8891 - f1_macro: 0.8836 - loss: 0.2783 - val_accuracy: 0.8927 - val_f1_macro: 0.8850 - val_loss: 0.2707
# Epoch 12/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8994 - f1_macro: 0.8927 - loss: 0.2620 - val_accuracy: 0.8954 - val_f1_macro: 0.8862 - val_loss: 0.2587
# Epoch 13/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9032 - f1_macro: 0.8974 - loss: 0.2526 - val_accuracy: 0.8893 - val_f1_macro: 0.8824 - val_loss: 0.2774
# Epoch 14/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9041 - f1_macro: 0.9006 - loss: 0.2491 - val_accuracy: 0.9006 - val_f1_macro: 0.8974 - val_loss: 0.2611
# Epoch 15/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9134 - f1_macro: 0.9093 - loss: 0.2411 - val_accuracy: 0.8988 - val_f1_macro: 0.8934 - val_loss: 0.2425
# Epoch 16/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9094 - f1_macro: 0.9042 - loss: 0.2424 - val_accuracy: 0.8993 - val_f1_macro: 0.8933 - val_loss: 0.2492
# Epoch 17/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9101 - f1_macro: 0.9061 - loss: 0.2375 - val_accuracy: 0.9058 - val_f1_macro: 0.8995 - val_loss: 0.2379
# Epoch 18/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9152 - f1_macro: 0.9095 - loss: 0.2224 - val_accuracy: 0.9036 - val_f1_macro: 0.9005 - val_loss: 0.2498
# Epoch 19/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9132 - f1_macro: 0.9072 - loss: 0.2216 - val_accuracy: 0.9166 - val_f1_macro: 0.9126 - val_loss: 0.2225
# Epoch 20/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9190 - f1_macro: 0.9154 - loss: 0.2153 - val_accuracy: 0.9092 - val_f1_macro: 0.9037 - val_loss: 0.2257
# Epoch 21/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9226 - f1_macro: 0.9190 - loss: 0.2045 - val_accuracy: 0.9106 - val_f1_macro: 0.9035 - val_loss: 0.2387
# Epoch 22/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9222 - f1_macro: 0.9175 - loss: 0.2020 - val_accuracy: 0.9136 - val_f1_macro: 0.9084 - val_loss: 0.2234
# Epoch 23/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9225 - f1_macro: 0.9196 - loss: 0.2100 - val_accuracy: 0.9140 - val_f1_macro: 0.9089 - val_loss: 0.2315
# Epoch 24/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9174 - f1_macro: 0.9125 - loss: 0.2108 - val_accuracy: 0.9092 - val_f1_macro: 0.9043 - val_loss: 0.2467
# Epoch 25/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9258 - f1_macro: 0.9215 - loss: 0.1877 - val_accuracy: 0.9145 - val_f1_macro: 0.9112 - val_loss: 0.2243
# Epoch 26/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9301 - f1_macro: 0.9273 - loss: 0.1791 - val_accuracy: 0.9171 - val_f1_macro: 0.9123 - val_loss: 0.2179
# Epoch 27/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9352 - f1_macro: 0.9332 - loss: 0.1783 - val_accuracy: 0.9231 - val_f1_macro: 0.9204 - val_loss: 0.2140
# Epoch 28/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9284 - f1_macro: 0.9246 - loss: 0.1785 - val_accuracy: 0.9197 - val_f1_macro: 0.9158 - val_loss: 0.2164
# Epoch 29/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9300 - f1_macro: 0.9261 - loss: 0.1804 - val_accuracy: 0.9227 - val_f1_macro: 0.9203 - val_loss: 0.2039
# Epoch 30/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9399 - f1_macro: 0.9379 - loss: 0.1667 - val_accuracy: 0.9188 - val_f1_macro: 0.9141 - val_loss: 0.2189
# Epoch 31/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9402 - f1_macro: 0.9368 - loss: 0.1663 - val_accuracy: 0.9223 - val_f1_macro: 0.9201 - val_loss: 0.2160
# Epoch 32/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9378 - f1_macro: 0.9360 - loss: 0.1687 - val_accuracy: 0.9236 - val_f1_macro: 0.9204 - val_loss: 0.2154
# Epoch 33/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9413 - f1_macro: 0.9388 - loss: 0.1536 - val_accuracy: 0.9223 - val_f1_macro: 0.9185 - val_loss: 0.2140
# Epoch 34/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9372 - f1_macro: 0.9341 - loss: 0.1573 - val_accuracy: 0.9236 - val_f1_macro: 0.9214 - val_loss: 0.2199
# Epoch 35/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9436 - f1_macro: 0.9406 - loss: 0.1533 - val_accuracy: 0.9253 - val_f1_macro: 0.9221 - val_loss: 0.2123
# Epoch 36/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9426 - f1_macro: 0.9404 - loss: 0.1532 - val_accuracy: 0.9305 - val_f1_macro: 0.9282 - val_loss: 0.2022
# Epoch 37/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9506 - f1_macro: 0.9499 - loss: 0.1429 - val_accuracy: 0.9197 - val_f1_macro: 0.9153 - val_loss: 0.2199
# Epoch 38/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9449 - f1_macro: 0.9429 - loss: 0.1425 - val_accuracy: 0.9218 - val_f1_macro: 0.9176 - val_loss: 0.2114
# Epoch 39/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9420 - f1_macro: 0.9395 - loss: 0.1500 - val_accuracy: 0.9249 - val_f1_macro: 0.9220 - val_loss: 0.2243
# Epoch 40/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9464 - f1_macro: 0.9438 - loss: 0.1401 - val_accuracy: 0.9288 - val_f1_macro: 0.9264 - val_loss: 0.1976
# Epoch 41/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9484 - f1_macro: 0.9459 - loss: 0.1376 - val_accuracy: 0.9188 - val_f1_macro: 0.9147 - val_loss: 0.2266
# Epoch 42/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9511 - f1_macro: 0.9485 - loss: 0.1358 - val_accuracy: 0.9284 - val_f1_macro: 0.9248 - val_loss: 0.2039
# Epoch 43/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9515 - f1_macro: 0.9498 - loss: 0.1321 - val_accuracy: 0.9314 - val_f1_macro: 0.9286 - val_loss: 0.2049
# Epoch 44/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9525 - f1_macro: 0.9499 - loss: 0.1268 - val_accuracy: 0.9292 - val_f1_macro: 0.9258 - val_loss: 0.2185
# Epoch 45/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9524 - f1_macro: 0.9503 - loss: 0.1212 - val_accuracy: 0.9201 - val_f1_macro: 0.9165 - val_loss: 0.2300
# Epoch 46/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9577 - f1_macro: 0.9559 - loss: 0.1120 - val_accuracy: 0.9262 - val_f1_macro: 0.9224 - val_loss: 0.2247
# Epoch 47/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9578 - f1_macro: 0.9562 - loss: 0.1172 - val_accuracy: 0.9314 - val_f1_macro: 0.9289 - val_loss: 0.2030
# Epoch 48/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9508 - f1_macro: 0.9482 - loss: 0.1294 - val_accuracy: 0.9340 - val_f1_macro: 0.9312 - val_loss: 0.2074
# Epoch 49/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9620 - f1_macro: 0.9604 - loss: 0.1065 - val_accuracy: 0.9271 - val_f1_macro: 0.9243 - val_loss: 0.2232
# Epoch 50/50
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9547 - f1_macro: 0.9529 - loss: 0.1190 - val_accuracy: 0.9310 - val_f1_macro: 0.9276 - val_loss: 0.2176
# Restoring model weights from the end of the best epoch: 48.
# Fold 5 - CV Val Loss: 0.2074, CV Val Acc: 0.9340, CV Val F1-Macro: 0.9312
#
# --- Cross-Validation Summary ---
# Average CV Loss: 0.2234 (+/- 0.0271)
# Average CV Accuracy: 0.9291 (+/- 0.0057)
# Average CV F1-Macro: 0.9266 (+/- 0.0056)

# %%
# ----- Train Final Model -----

BATCH_SIZE_FINAL = 32
EPOCHS_FINAL_NEW = 80  # เพิ่มจำนวน Epochs สำหรับการฝึกที่นานขึ้น
PATIENCE_FINAL_NEW = 10 # เพิ่ม Patience สำหรับ EarlyStopping
history_final = None 

# --- LEARNING RATE PARAMETERS FOR FINAL MODEL SCHEDULER ---
INITIAL_LR_FINAL = 0.0001  # <<<<----- ปรับค่าเริ่มต้นที่นี่ (เช่น 0.0005 หรือ 0.00025)
END_LR_FINAL = 0.00005     # <<<<----- ปรับค่าสุดท้ายที่นี่ (เช่น 0.00001 หรือ 0.000005)

if X_train_orig.shape[0] > 0:
    y_train_orig_2d = y_train_orig.reshape(-1, 1)
    y_val_orig_2d = None
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        y_val_orig_2d = y_val_orig.reshape(-1, 1)

    print("\n--- Training Final Model with Transformer Classifier ---")
    
    # สร้าง final_model ด้วย create_transformer_classifier
    # learning_rate ที่ส่งเข้าไปใน create_transformer_classifier จะไม่ถูกใช้
    # ถ้าเรา recompile ด้วย optimizer ใหม่ด้านล่าง
    final_model = create_transformer_classifier(
        input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
        d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
        projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
        dropout_rate=DROPOUT_RATE, # ใช้ DROPOUT_RATE ที่ตั้งไว้
        learning_rate=0.0005 # ค่า dummy หรือ initial LR เดิม, เพราะจะ recompile อยู่ดี
    )

    # --- DEFINE LEARNING RATE SCHEDULE FOR FINAL MODEL ---
    num_train_samples_final = X_train_orig.shape[0]
    total_decay_steps_final = (num_train_samples_final // BATCH_SIZE_FINAL) * EPOCHS_FINAL_NEW 
    
    final_lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        initial_learning_rate=INITIAL_LR_FINAL, 
        decay_steps=total_decay_steps_final,
        end_learning_rate=END_LR_FINAL,         
        power=0.5 # Linear decay (หรือลองค่าอื่น เช่น 0.5)
    )
    
    # สร้าง Optimizer ใหม่ด้วย Learning Rate Schedule
    optimizer_with_schedule_final = Adam(learning_rate=final_lr_schedule)

    # Recompile final_model ด้วย Optimizer ใหม่ที่มี Schedule
    f1_metric_for_recompile = tf.keras.metrics.F1Score(average='macro', threshold=0.5, name='f1_macro')
    final_model.compile(optimizer=optimizer_with_schedule_final,
                        loss='binary_crossentropy',
                        metrics=['accuracy', f1_metric_for_recompile])
    print(f"Recompiled final_model with PolynomialDecay LR schedule (Initial: {INITIAL_LR_FINAL}, End: {END_LR_FINAL}).")

    callbacks_final = []
    validation_data_for_fit = None
    if y_val_orig_2d is not None:
        validation_data_for_fit = (X_val_orig, y_val_orig_2d)
        early_stopping_final = EarlyStopping(
            monitor='val_f1_macro', 
            patience=PATIENCE_FINAL_NEW, # ใช้ PATIENCE_FINAL_NEW ที่ตั้งไว้
            verbose=1, 
            mode='max', 
            restore_best_weights=True
        )
        callbacks_final.append(early_stopping_final)
        
        class PrintLR(tf.keras.callbacks.Callback): # Optional: Callback to print LR
            def on_epoch_end(self, epoch, logs=None):
                current_lr_value = self.model.optimizer.learning_rate
                if isinstance(current_lr_value, tf.keras.optimizers.schedules.LearningRateSchedule):
                    current_lr_value = current_lr_value(self.model.optimizer.iterations)
                try:
                    current_lr_value = tf.keras.backend.get_value(current_lr_value)
                except: pass
                print(f" - LR: {current_lr_value:.7f}", end="")
        callbacks_final.append(PrintLR())

        print(f"Training final model with validation data, LR schedule, and EarlyStopping (patience={PATIENCE_FINAL_NEW}).")
    else:
        print("Training final model without validation data. EarlyStopping on val_f1_macro disabled.")
    
    history_final = final_model.fit(X_train_orig, y_train_orig_2d, 
                                    epochs=EPOCHS_FINAL_NEW, # ใช้ EPOCHS_FINAL_NEW
                                    batch_size=BATCH_SIZE_FINAL, 
                                    validation_data=validation_data_for_fit, 
                                    callbacks=callbacks_final if callbacks_final else None, 
                                    verbose=1)
    
    if final_model:
        if X_test_orig.shape[0] > 0 and y_test_orig.shape[0] > 0:
            y_test_orig_2d = y_test_orig.reshape(-1, 1)
            print("\n--- Evaluating on Test Set (after final training) ---")
            eval_results_final = final_model.evaluate(X_test_orig, y_test_orig_2d, verbose=0)
            test_loss, test_accuracy, test_f1_macro = eval_results_final[0], eval_results_final[1], eval_results_final[2]
            print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Test F1-Macro: {test_f1_macro:.4f}")
        else:
            print("Skipping evaluation on Test Set: Test data is empty or not provided.")
else:
    print("Final model was not trained (likely due to empty training data).")


# ----- Export Model and Convert to TFLite -----
if 'final_model' in locals() and isinstance(final_model, tf.keras.Model):
    print("\n--- Evaluating on Test Set (Before Export) ---")
    if 'X_test_orig' in locals() and 'y_test_orig' in locals() and X_test_orig.size > 0:
        # --- RESHAPE y_test_orig for Keras F1Score metric during evaluation ---
        y_test_orig_2d_export = y_test_orig.reshape(-1, 1) # Use a different variable name or ensure it's reshaped if not already
        eval_results_export = final_model.evaluate(X_test_orig, y_test_orig_2d_export, verbose=0) # Use 2D y_true
        test_loss_exp, test_acc_exp, test_f1_exp = eval_results_export[0], eval_results_export[1], eval_results_export[2]
        print(f"Test Loss: {test_loss_exp:.4f}, Test Acc: {test_acc_exp:.4f}, Test F1-Macro: {test_f1_exp:.4f}")
    else:
        print("Test data not found or empty for pre-export evaluation.")

    export_directory = 'fall_model_exported_sm'
    try:
        final_model.export(export_directory)
        print(f"Model exported successfully in SavedModel format at: ./{export_directory}")

        print("\nConverting exported SavedModel to TensorFlow Lite...")
        try:
            converter = tf.lite.TFLiteConverter.from_saved_model(export_directory)
            tflite_model_content = converter.convert()
            tflite_model_path = 'fall_detection_transformer.tflite'
            with open(tflite_model_path, 'wb') as f: f.write(tflite_model_content)
            print(f"Model converted to TFLite and saved as {tflite_model_path} ({len(tflite_model_content)/1024:.2f} KB)")
        except Exception as tflite_e:
            print(f"Error during TFLite conversion: {tflite_e}")
    except Exception as e:
        print(f"Error during model export: {e}")
else:
    print("ERROR: 'final_model' not defined or not a Keras Model. Skipping export and TFLite conversion.")
# Out:
# --- Training Final Model with Transformer Classifier ---
# Recompiled final_model with PolynomialDecay LR schedule (Initial: 0.0001, End: 5e-05).
# Training final model with validation data, LR schedule, and EarlyStopping (patience=10).
# Epoch 1/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 48s 57ms/step - accuracy: 0.6919 - f1_macro: 0.6739 - loss: 0.5847 - val_accuracy: 0.8156 - val_f1_macro: 0.7904 - val_loss: 0.4147
# Epoch 2/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8176 - f1_macro: 0.8041 - loss: 0.4149 - val_accuracy: 0.8383 - val_f1_macro: 0.8334 - val_loss: 0.3658
# Epoch 3/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8568 - f1_macro: 0.8513 - loss: 0.3511 - val_accuracy: 0.8545 - val_f1_macro: 0.8385 - val_loss: 0.3496
# Epoch 4/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8666 - f1_macro: 0.8579 - loss: 0.3293 - val_accuracy: 0.8610 - val_f1_macro: 0.8450 - val_loss: 0.3484
# Epoch 5/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8811 - f1_macro: 0.8729 - loss: 0.3026 - val_accuracy: 0.8712 - val_f1_macro: 0.8614 - val_loss: 0.3274
# Epoch 6/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8785 - f1_macro: 0.8727 - loss: 0.2999 - val_accuracy: 0.8549 - val_f1_macro: 0.8538 - val_loss: 0.3333
# Epoch 7/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8873 - f1_macro: 0.8812 - loss: 0.2819 - val_accuracy: 0.8894 - val_f1_macro: 0.8828 - val_loss: 0.2753
# Epoch 8/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8945 - f1_macro: 0.8877 - loss: 0.2706 - val_accuracy: 0.8845 - val_f1_macro: 0.8775 - val_loss: 0.2833
# Epoch 9/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8981 - f1_macro: 0.8938 - loss: 0.2573 - val_accuracy: 0.8870 - val_f1_macro: 0.8824 - val_loss: 0.2863
# Epoch 10/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8974 - f1_macro: 0.8936 - loss: 0.2621 - val_accuracy: 0.8870 - val_f1_macro: 0.8746 - val_loss: 0.2921
# Epoch 11/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9025 - f1_macro: 0.8979 - loss: 0.2500 - val_accuracy: 0.8902 - val_f1_macro: 0.8866 - val_loss: 0.2760
# Epoch 12/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9062 - f1_macro: 0.9011 - loss: 0.2425 - val_accuracy: 0.8910 - val_f1_macro: 0.8822 - val_loss: 0.2671
# Epoch 13/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9096 - f1_macro: 0.9057 - loss: 0.2355 - val_accuracy: 0.9056 - val_f1_macro: 0.8993 - val_loss: 0.2350
# Epoch 14/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9137 - f1_macro: 0.9081 - loss: 0.2252 - val_accuracy: 0.9060 - val_f1_macro: 0.9012 - val_loss: 0.2379
# Epoch 15/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9146 - f1_macro: 0.9093 - loss: 0.2203 - val_accuracy: 0.9096 - val_f1_macro: 0.9062 - val_loss: 0.2406
# Epoch 16/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9182 - f1_macro: 0.9145 - loss: 0.2164 - val_accuracy: 0.9149 - val_f1_macro: 0.9115 - val_loss: 0.2231
# Epoch 17/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9221 - f1_macro: 0.9178 - loss: 0.2114 - val_accuracy: 0.9019 - val_f1_macro: 0.8939 - val_loss: 0.2512
# Epoch 18/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9258 - f1_macro: 0.9223 - loss: 0.1994 - val_accuracy: 0.9157 - val_f1_macro: 0.9117 - val_loss: 0.2251
# Epoch 19/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9220 - f1_macro: 0.9180 - loss: 0.2090 - val_accuracy: 0.9198 - val_f1_macro: 0.9165 - val_loss: 0.2166
# Epoch 20/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9285 - f1_macro: 0.9245 - loss: 0.1907 - val_accuracy: 0.9157 - val_f1_macro: 0.9109 - val_loss: 0.2179
# Epoch 21/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9285 - f1_macro: 0.9244 - loss: 0.1937 - val_accuracy: 0.9137 - val_f1_macro: 0.9121 - val_loss: 0.2224
# Epoch 22/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9312 - f1_macro: 0.9280 - loss: 0.1863 - val_accuracy: 0.9218 - val_f1_macro: 0.9171 - val_loss: 0.2188
# Epoch 23/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9387 - f1_macro: 0.9357 - loss: 0.1699 - val_accuracy: 0.9165 - val_f1_macro: 0.9120 - val_loss: 0.2152
# Epoch 24/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9358 - f1_macro: 0.9322 - loss: 0.1731 - val_accuracy: 0.9226 - val_f1_macro: 0.9193 - val_loss: 0.1992
# Epoch 25/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9377 - f1_macro: 0.9357 - loss: 0.1670 - val_accuracy: 0.9149 - val_f1_macro: 0.9085 - val_loss: 0.2153
# Epoch 26/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9320 - f1_macro: 0.9296 - loss: 0.1711 - val_accuracy: 0.9194 - val_f1_macro: 0.9149 - val_loss: 0.2033
# Epoch 27/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9366 - f1_macro: 0.9338 - loss: 0.1681 - val_accuracy: 0.9246 - val_f1_macro: 0.9228 - val_loss: 0.2037
# Epoch 28/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9369 - f1_macro: 0.9340 - loss: 0.1596 - val_accuracy: 0.9275 - val_f1_macro: 0.9247 - val_loss: 0.2097
# Epoch 29/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9366 - f1_macro: 0.9347 - loss: 0.1633 - val_accuracy: 0.9267 - val_f1_macro: 0.9241 - val_loss: 0.2071
# Epoch 30/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9465 - f1_macro: 0.9439 - loss: 0.1522 - val_accuracy: 0.9319 - val_f1_macro: 0.9290 - val_loss: 0.1919
# Epoch 31/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9408 - f1_macro: 0.9369 - loss: 0.1598 - val_accuracy: 0.9259 - val_f1_macro: 0.9224 - val_loss: 0.2016
# Epoch 32/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9445 - f1_macro: 0.9427 - loss: 0.1540 - val_accuracy: 0.9283 - val_f1_macro: 0.9253 - val_loss: 0.2056
# Epoch 33/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9479 - f1_macro: 0.9457 - loss: 0.1464 - val_accuracy: 0.9218 - val_f1_macro: 0.9167 - val_loss: 0.2033
# Epoch 34/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9452 - f1_macro: 0.9426 - loss: 0.1410 - val_accuracy: 0.9287 - val_f1_macro: 0.9268 - val_loss: 0.2135
# Epoch 35/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9489 - f1_macro: 0.9455 - loss: 0.1363 - val_accuracy: 0.9315 - val_f1_macro: 0.9280 - val_loss: 0.2057
# Epoch 36/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9481 - f1_macro: 0.9469 - loss: 0.1406 - val_accuracy: 0.9267 - val_f1_macro: 0.9237 - val_loss: 0.2109
# Epoch 37/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9466 - f1_macro: 0.9438 - loss: 0.1452 - val_accuracy: 0.9340 - val_f1_macro: 0.9310 - val_loss: 0.1882
# Epoch 38/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9455 - f1_macro: 0.9432 - loss: 0.1364 - val_accuracy: 0.9404 - val_f1_macro: 0.9385 - val_loss: 0.1930
# Epoch 39/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9601 - f1_macro: 0.9587 - loss: 0.1184 - val_accuracy: 0.9234 - val_f1_macro: 0.9208 - val_loss: 0.2146
# Epoch 40/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9521 - f1_macro: 0.9502 - loss: 0.1239 - val_accuracy: 0.9295 - val_f1_macro: 0.9266 - val_loss: 0.2020
# Epoch 41/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9585 - f1_macro: 0.9568 - loss: 0.1163 - val_accuracy: 0.9275 - val_f1_macro: 0.9234 - val_loss: 0.1999
# Epoch 42/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9519 - f1_macro: 0.9494 - loss: 0.1225 - val_accuracy: 0.9356 - val_f1_macro: 0.9326 - val_loss: 0.1879
# Epoch 43/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9608 - f1_macro: 0.9595 - loss: 0.1079 - val_accuracy: 0.9299 - val_f1_macro: 0.9267 - val_loss: 0.2040
# Epoch 44/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9596 - f1_macro: 0.9575 - loss: 0.1145 - val_accuracy: 0.9380 - val_f1_macro: 0.9351 - val_loss: 0.1969
# Epoch 45/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9627 - f1_macro: 0.9614 - loss: 0.1063 - val_accuracy: 0.9303 - val_f1_macro: 0.9271 - val_loss: 0.2027
# Epoch 46/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9606 - f1_macro: 0.9592 - loss: 0.1113 - val_accuracy: 0.9307 - val_f1_macro: 0.9282 - val_loss: 0.2046
# Epoch 47/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9618 - f1_macro: 0.9601 - loss: 0.1048 - val_accuracy: 0.9364 - val_f1_macro: 0.9336 - val_loss: 0.1891
# Epoch 48/80
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9643 - f1_macro: 0.9630 - loss: 0.0971 - val_accuracy: 0.9323 - val_f1_macro: 0.9304 - val_loss: 0.1922
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.
#
# --- Evaluating on Test Set (after final training) ---
# Test Loss: 0.2017, Test Accuracy: 0.9287, Test F1-Macro: 0.9264
#
# --- Evaluating on Test Set (Before Export) ---
# Test Loss: 0.2017, Test Acc: 0.9287, Test F1-Macro: 0.9264
# Saved artifact at 'fall_model_exported_sm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 51), dtype=tf.float32, name='input_features')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139216766933456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216766931728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216761444048: TensorSpec(shape=(1, 60, 64), dtype=tf.float32, name=None)
#   139216766928848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216766931152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216766939984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216761448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730626128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730633808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730632656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730630352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730620368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730635344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730619984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730629968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730629584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730626512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730621904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730633424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730623440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216730627280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735877648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735875920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735878800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735871504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735869200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735866896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216735875728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008392208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008389712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008393360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008388560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008388176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008390672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008393936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008395472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008398544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008395856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008396432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008398736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008400080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008403536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008397392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139213008399696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216719149968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216719141136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216719137296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139216719145744: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model exported successfully in SavedModel format at: ./fall_model_exported_sm
#
# Converting exported SavedModel to TensorFlow Lite...
# Model converted to TFLite and saved as fall_detection_transformer.tflite (461.57 KB)
# W0000 00:00:1749115723.984618      35 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749115723.984661      35 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1749115724.021483      35 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
# ----- Plot Training History of Final Model -----
if history_final and hasattr(history_final, 'history') and history_final.history:
    plt.figure(figsize=(18, 5)) # Adjusted for 3 subplots
    
    plt.subplot(1, 3, 1)
    if 'accuracy' in history_final.history: plt.plot(history_final.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history_final.history: plt.plot(history_final.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    
    plt.subplot(1, 3, 2)
    if 'loss' in history_final.history: plt.plot(history_final.history['loss'], label='Train Loss')
    if 'val_loss' in history_final.history: plt.plot(history_final.history['val_loss'], label='Val Loss')
    plt.title('Model Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)

    plt.subplot(1, 3, 3) # New subplot for F1-Macro
    if 'f1_macro' in history_final.history: plt.plot(history_final.history['f1_macro'], label='Train F1-Macro')
    if 'val_f1_macro' in history_final.history: plt.plot(history_final.history['val_f1_macro'], label='Val F1-Macro')
    plt.title('Model F1-Macro Score'); plt.xlabel('Epoch'); plt.ylabel('F1-Macro'); plt.legend(); plt.grid(True)
    
    plt.tight_layout(); plt.show()
else:
    print("Skipping plotting: final model training history unavailable.")

# %%
# ----- FUNCTION TO PLOT CONFUSION MATRIX -----
def plot_confusion_matrix_custom(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title); plt.ylabel('True label'); plt.xlabel('Predicted label'); plt.show()

# ----- FUNCTION TO PLOT METRICS BARCHART  -----
def plot_metrics_barchart(metrics_data, class_names, title='Metrics per Class'):
    df_metrics = pd.DataFrame(metrics_data, index=class_names)
    ax = df_metrics.plot(kind='bar', figsize=(10, 7), width=0.8, colormap='viridis')
    plt.title(title, fontsize=15); plt.ylabel('Score (%)', fontsize=12); plt.xlabel('Class', fontsize=12)
    plt.xticks(rotation=0); plt.ylim(0, 1)
    for p in ax.patches:
        ax.annotate(f"{p.get_height()*100:.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 9), textcoords='offset points', fontsize=10)
    plt.legend(title='Metrics'); plt.tight_layout(); plt.show()

# ----- DETAILED EVALUATION AND REPORTING -----
target_names = ['no_fall', 'fall']
class_labels = [0, 1] # Corresponding numerical labels

# Initialize prediction variables to None
y_pred_val_probs = None
y_pred_val_classes = None
y_pred_test_probs = None
y_pred_test_classes = None

# --- กำหนด Optimized Threshold ที่คุณได้มา ---
OPTIMIZED_THRESHOLD = 0.50 # หรือค่าที่คุณได้จากการทดลองล่าสุด

if final_model is not None:
    # --- Evaluation on Validation Set ---
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        print(f"\n\n--- Custom Validation Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_val_probs = final_model.predict(X_val_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_val_classes = (y_pred_val_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_val, recall_val, f1_val, support_val = precision_recall_fscore_support(
            y_val_orig, y_pred_val_classes, labels=class_labels, zero_division=0
        )
        f2_val_per_class = fbeta_score(y_val_orig, y_pred_val_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ validation) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_val[i]:>10.4f} {recall_val[i]:>10.4f} {f1_val[i]:>10.4f} {f2_val_per_class[i]:>10.4f} {support_val[i]:>10}")
        val_metrics_for_plot = {'Precision': precision_val, 'Recall': recall_val, 'F1-score': f1_val, 'F2-score': f2_val_per_class}
        plot_metrics_barchart(val_metrics_for_plot, target_names, title=f'Validation Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_val = confusion_matrix(y_val_orig, y_pred_val_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_val, classes=target_names, title=f'Validation Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')

    else: print("\nValidation data empty. Skipping detailed validation metrics report.")

    # --- Evaluation on Test Set ---
    if X_test_orig.size > 0 and y_test_orig.size > 0:
        print(f"\n\n--- Custom Test Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_test_probs = final_model.predict(X_test_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_test_classes = (y_pred_test_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_test, recall_test, f1_test, support_test = precision_recall_fscore_support(
            y_test_orig, y_pred_test_classes, labels=class_labels, zero_division=0
        )
        f2_test_per_class = fbeta_score(y_test_orig, y_pred_test_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ test) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_test[i]:>10.4f} {recall_test[i]:>10.4f} {f1_test[i]:>10.4f} {f2_test_per_class[i]:>10.4f} {support_test[i]:>10}")
        test_metrics_for_plot = {'Precision': precision_test, 'Recall': recall_test, 'F1-score': f1_test, 'F2-score': f2_test_per_class}
        plot_metrics_barchart(test_metrics_for_plot, target_names, title=f'Test Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_test = confusion_matrix(y_test_orig, y_pred_test_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_test, classes=target_names, title=f'Test Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')
    else: print("\nTest data empty. Skipping detailed test metrics.")
else:
    print("Final model not trained. Skipping detailed evaluation.")
# Out:
# --- Custom Validation Metrics Report (Threshold: 0.5) ---
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9441     0.9404     0.9423     0.9412       1276
# fall          0.9365     0.9404     0.9385     0.9396       1192
# --- Custom Test Metrics Report (Threshold: 0.5) ---
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9331     0.9287     0.9309     0.9296       1276
# fall          0.9241     0.9288     0.9264     0.9278       1193

# %%
from sklearn.metrics import f1_score

# y_pred_val_probs ได้จากการ predict บน X_val_orig
best_threshold = 0.5
best_f1 = 0.0
thresholds = np.arange(0.1, 0.9, 0.01)
for thresh in thresholds:
    current_preds = (y_pred_val_probs > thresh).astype(int)
    current_f1 = f1_score(y_val_orig, current_preds, average='macro') # หรือ average='binary' ถ้าสนใจ F1 ของคลาส fall
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_threshold = thresh
print(f"Best threshold on validation set: {best_threshold:.2f} with F1-Macro: {best_f1:.4f}")
# Out:
# Best threshold on validation set: 0.50 with F1-Macro: 0.9404

# %%
# ----- Error Analysis and Logging -----
print("\nStarting Error Analysis and Logging...")
error_log_filename = "error_analysis_report.txt"

# --- Validation Set Analysis ---
can_analyze_val = False
missing_val_vars_reason = ""

if 'target_names' not in locals():
    missing_val_vars_reason = "'target_names' is not defined."
elif 'y_val_orig' not in locals() or y_val_orig is None:
    missing_val_vars_reason = "'y_val_orig' is not defined or is None."
elif 'val_npy_filepaths' not in locals() or val_npy_filepaths is None:
    missing_val_vars_reason = "'val_npy_filepaths' is not defined or is None."
elif 'y_pred_val_classes' not in locals() or y_pred_val_classes is None:
    missing_val_vars_reason = "'y_pred_val_classes' (predictions for validation) is not defined or is None. This might happen if validation data was empty or model was not trained."
elif 'y_pred_val_probs' not in locals() or y_pred_val_probs is None:
    missing_val_vars_reason = "'y_pred_val_probs' (prediction probabilities for validation) is not defined or is None."
elif not (y_val_orig.size > 0 and len(val_npy_filepaths) > 0 and \
          y_pred_val_classes.size > 0 and y_pred_val_probs.size > 0 and \
          len(y_val_orig) == len(val_npy_filepaths) == len(y_pred_val_classes) == y_pred_val_probs.shape[0]): # Check shape[0] for probs
    missing_val_vars_reason = "Data for validation error analysis is empty, or array lengths are mismatched."
else:
    can_analyze_val = True

if not can_analyze_val:
    print(f"ERROR: Validation Error Analysis cannot proceed. Reason: {missing_val_vars_reason}")
    # Optionally, write this skip reason to the log file if it's created unconditionally
    with open(error_log_filename, "w", encoding="utf-8") as log_f_skip: # Open in write mode to create/overwrite
        log_f_skip.write("--- Error Analysis Report ---\n")
        log_f_skip.write(f"Timestamp: {pd.Timestamp.now()}\n\n")
        log_f_skip.write("=== Validation Set Analysis ===\n")
        log_f_skip.write(f"Skipped. Reason: {missing_val_vars_reason}\n")
else:
    with open(error_log_filename, "w", encoding="utf-8") as log_f: # Open in write mode
        log_f.write("--- Error Analysis Report ---\n")
        log_f.write(f"Timestamp: {pd.Timestamp.now()}\n")

        log_f.write("\n\n=== Validation Set Analysis ===\n")
        fp_indices_val = np.where((y_pred_val_classes == 1) & (y_val_orig == 0))[0]
        fn_indices_val = np.where((y_pred_val_classes == 0) & (y_val_orig == 1))[0]

        log_f.write(f"Total Validation Samples: {len(y_val_orig)}\n")
        log_f.write(f"False Positives (No_Fall predicted as Fall): {len(fp_indices_val)}\n")
        log_f.write(f"False Negatives (Fall predicted as No_Fall): {len(fn_indices_val)}\n")

        log_f.write("\n--- Details of False Positives (Validation) ---\n")
        if len(fp_indices_val) > 0:
            for i, fp_idx in enumerate(fp_indices_val):
                true_label = y_val_orig[fp_idx]
                pred_label = y_pred_val_classes[fp_idx]
                pred_prob_fall = y_pred_val_probs[fp_idx]
                if isinstance(pred_prob_fall, (np.ndarray, list)): pred_prob_fall = pred_prob_fall[0]
                
                npy_full_path_str = val_npy_filepaths[fp_idx]
                npy_filename = Path(npy_full_path_str).name
                # ... (rest of FP logging logic from your original code) ...
                log_f.write(f"\nFP Sample #{i+1} (Original Index: {fp_idx})\n")
                log_f.write(f"  NPY File: {npy_filename}, True: {target_names[true_label]}, Pred: {target_names[pred_label]}, Prob(Fall): {pred_prob_fall:.4f}\n")
                log_f.write(f"  NPY Full Path: {npy_full_path_str}\n")
        else:
            log_f.write("No False Positives found in Validation Set.\n")

        log_f.write("\n--- Details of False Negatives (Validation) ---\n")
        if len(fn_indices_val) > 0:
            for i, fn_idx in enumerate(fn_indices_val):
                true_label = y_val_orig[fn_idx]
                pred_label = y_pred_val_classes[fn_idx]
                pred_prob_fall = y_pred_val_probs[fn_idx]
                if isinstance(pred_prob_fall, (np.ndarray, list)): pred_prob_fall = pred_prob_fall[0]

                npy_full_path_str = val_npy_filepaths[fn_idx]
                npy_filename = Path(npy_full_path_str).name
                # ... (rest of FN logging logic from your original code) ...
                log_f.write(f"\nFN Sample #{i+1} (Original Index: {fn_idx})\n")
                log_f.write(f"  NPY File: {npy_filename}, True: {target_names[true_label]}, Pred: {target_names[pred_label]}, Prob(Fall): {pred_prob_fall:.4f}\n")
                log_f.write(f"  NPY Full Path: {npy_full_path_str}\n")
        else:
            log_f.write("No False Negatives found in Validation Set.\n")

        # --- (Optional) Test Set Analysis (within the same log file if validation analysis was done) ---
        can_analyze_test = False
        missing_test_vars_reason = ""
        if 'y_test_orig' not in locals() or y_test_orig is None:
            missing_test_vars_reason = "'y_test_orig' is not defined or is None."
        elif 'test_npy_filepaths' not in locals() or test_npy_filepaths is None:
            missing_test_vars_reason = "'test_npy_filepaths' is not defined or is None."
        elif 'y_pred_test_classes' not in locals() or y_pred_test_classes is None:
            missing_test_vars_reason = "'y_pred_test_classes' (predictions for test) is not defined or is None."
        elif 'y_pred_test_probs' not in locals() or y_pred_test_probs is None:
            missing_test_vars_reason = "'y_pred_test_probs' (prediction probabilities for test) is not defined or is None."
        elif not (y_test_orig.size > 0 and len(test_npy_filepaths) > 0 and \
                  y_pred_test_classes.size > 0 and y_pred_test_probs.size > 0 and \
                  len(y_test_orig) == len(test_npy_filepaths) == len(y_pred_test_classes) == y_pred_test_probs.shape[0]):
             missing_test_vars_reason = "Data for test error analysis is empty, or array lengths are mismatched."
        else:
            can_analyze_test = True

        if not can_analyze_test:
            log_f.write("\n\n=== Test Set Analysis ===\n")
            log_f.write(f"Skipped. Reason: {missing_test_vars_reason}\n")
            print(f"Skipping Test Error Analysis in log. Reason: {missing_test_vars_reason}")
        else:
            log_f.write("\n\n=== Test Set Analysis ===\n")
            fp_indices_test = np.where((y_pred_test_classes == 1) & (y_test_orig == 0))[0]
            fn_indices_test = np.where((y_pred_test_classes == 0) & (y_test_orig == 1))[0]

            log_f.write(f"Total Test Samples: {len(y_test_orig)}\n")
            log_f.write(f"False Positives: {len(fp_indices_test)}\n")
            log_f.write(f"False Negatives: {len(fn_indices_test)}\n")
            
            log_f.write("\n--- Details of False Positives (Test) ---\n")
            # ... (Similar logging logic as validation FP) ...
            if len(fp_indices_test) > 0:
                 for i, fp_idx_t in enumerate(fp_indices_test):
                    true_label_t, pred_label_t = y_test_orig[fp_idx_t], y_pred_test_classes[fp_idx_t]
                    pred_prob_t = y_pred_test_probs[fp_idx_t][0] if isinstance(y_pred_test_probs[fp_idx_t], (np.ndarray, list)) else y_pred_test_probs[fp_idx_t]
                    npy_path_t = test_npy_filepaths[fp_idx_t]
                    npy_fn_t = Path(npy_path_t).name
                    log_f.write(f"\nFP_Test Sample #{i+1} (Idx: {fp_idx_t}) NPY: {npy_fn_t}\n  True: {target_names[true_label_t]}, Pred: {target_names[pred_label_t]}, Prob(Fall): {pred_prob_t:.4f}\n  Path: {npy_path_t}\n")
            else: log_f.write("No False Positives found in Test Set.\n")

            log_f.write("\n--- Details of False Negatives (Test) ---\n")
            # ... (Similar logging logic as validation FN) ...
            if len(fn_indices_test) > 0:
                for i, fn_idx_t in enumerate(fn_indices_test):
                    true_label_t, pred_label_t = y_test_orig[fn_idx_t], y_pred_test_classes[fn_idx_t]
                    pred_prob_t = y_pred_test_probs[fn_idx_t][0] if isinstance(y_pred_test_probs[fn_idx_t], (np.ndarray, list)) else y_pred_test_probs[fn_idx_t]
                    npy_path_t = test_npy_filepaths[fn_idx_t]
                    npy_fn_t = Path(npy_path_t).name
                    log_f.write(f"\nFN_Test Sample #{i+1} (Idx: {fn_idx_t}) NPY: {npy_fn_t}\n  True: {target_names[true_label_t]}, Pred: {target_names[pred_label_t]}, Prob(Fall): {pred_prob_t:.4f}\n  Path: {npy_path_t}\n")
            else: log_f.write("No False Negatives found in Test Set.\n")

    if can_analyze_val or (not can_analyze_val and 'log_f_skip' in locals()): # Check if log file was opened
        print(f"\nError Analysis Report status logged to: {error_log_filename}")
# Out:
# Starting Error Analysis and Logging...
#
# Error Analysis Report status logged to: error_analysis_report.txt
