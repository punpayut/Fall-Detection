# %%
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, fbeta_score, precision_recall_fscore_support

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense, Dropout, LayerNormalization, MultiHeadAttention,
    GlobalAveragePooling1D, Embedding, Add, Input
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-06-03 05:10:56.968123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748927457.203239      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748927457.271304      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----- 0. GLOBAL CONSTANTS AND KEYPOINT DEFINITIONS -----
KEYPOINT_NAMES = [
    'Nose', 'Left Eye', 'Right Eye', 'Left Ear', 'Right Ear',
    'Left Shoulder', 'Right Shoulder', 'Left Elbow', 'Right Elbow',
    'Left Wrist', 'Right Wrist', 'Left Hip', 'Right Hip',
    'Left Knee', 'Right Knee', 'Left Ankle', 'Right Ankle'
]
SORTED_KEYPOINT_NAMES = sorted(KEYPOINT_NAMES)
KEYPOINT_DICT = {name: i for i, name in enumerate(SORTED_KEYPOINT_NAMES)}
NUM_KEYPOINTS = len(KEYPOINT_DICT)

print("--- Initializing Keypoint Definitions ---")
print(f"SORTED_KEYPOINT_NAMES (used for ordering): {SORTED_KEYPOINT_NAMES}")
print(f"Generated KEYPOINT_DICT: {KEYPOINT_DICT}")
print(f"NUM_KEYPOINTS: {NUM_KEYPOINTS}")
if NUM_KEYPOINTS != 17:
    print(f"WARNING: NUM_KEYPOINTS is {NUM_KEYPOINTS}, expected 17.")
print("----------------------------------------")
# Out:
# --- Initializing Keypoint Definitions ---
# SORTED_KEYPOINT_NAMES (used for ordering): ['Left Ankle', 'Left Ear', 'Left Elbow', 'Left Eye', 'Left Hip', 'Left Knee', 'Left Shoulder', 'Left Wrist', 'Nose', 'Right Ankle', 'Right Ear', 'Right Elbow', 'Right Eye', 'Right Hip', 'Right Knee', 'Right Shoulder', 'Right Wrist']
# Generated KEYPOINT_DICT: {'Left Ankle': 0, 'Left Ear': 1, 'Left Elbow': 2, 'Left Eye': 3, 'Left Hip': 4, 'Left Knee': 5, 'Left Shoulder': 6, 'Left Wrist': 7, 'Nose': 8, 'Right Ankle': 9, 'Right Ear': 10, 'Right Elbow': 11, 'Right Eye': 12, 'Right Hip': 13, 'Right Knee': 14, 'Right Shoulder': 15, 'Right Wrist': 16}
# NUM_KEYPOINTS: 17
# ----------------------------------------

# %%
# ----- 1. HELPER FUNCTION FOR KEYPOINT INDICES -----
def get_kpt_indices(keypoint_name):
    if keypoint_name not in KEYPOINT_DICT:
        available_keys = list(KEYPOINT_DICT.keys())
        similar_keys = [k for k in available_keys if keypoint_name.lower() in k.lower() or k.lower() in keypoint_name.lower()]
        error_msg = f"Keypoint name '{keypoint_name}' not found in KEYPOINT_DICT. "
        error_msg += f"Available keys: {available_keys}. "
        if similar_keys: error_msg += f"Did you mean: {similar_keys}? "
        raise ValueError(error_msg)
    kp_idx = KEYPOINT_DICT[keypoint_name]
    return kp_idx * 3, kp_idx * 3 + 1, kp_idx * 3 + 2

# %%
# ----- 2. SKELETON NORMALIZATION FUNCTION -----
def normalize_skeleton(sequence_data, min_confidence=0.3):
    normalized_sequence = np.copy(sequence_data)
    ref_kp_names = {
        'ls': 'Left Shoulder', 'rs': 'Right Shoulder',
        'lh': 'Left Hip', 'rh': 'Right Hip'
    }
    for ref_kp_key, ref_kp_name_val in ref_kp_names.items():
        if ref_kp_name_val not in KEYPOINT_DICT:
            print(f"WARNING in normalize_skeleton: Ref keypoint '{ref_kp_name_val}' not in KEYPOINT_DICT.")

    for t in range(sequence_data.shape[0]):
        frame_data = sequence_data[t, :]
        current_frame_normalized = np.copy(frame_data)
        try:
            ls_x_idx, ls_y_idx, ls_c_idx = get_kpt_indices(ref_kp_names['ls'])
            rs_x_idx, rs_y_idx, rs_c_idx = get_kpt_indices(ref_kp_names['rs'])
            lh_x_idx, lh_y_idx, lh_c_idx = get_kpt_indices(ref_kp_names['lh'])
            rh_x_idx, rh_y_idx, rh_c_idx = get_kpt_indices(ref_kp_names['rh'])
        except ValueError:
            normalized_sequence[t, :] = frame_data; continue

        ls_x, ls_y, ls_c = frame_data[ls_x_idx], frame_data[ls_y_idx], frame_data[ls_c_idx]
        rs_x, rs_y, rs_c = frame_data[rs_x_idx], frame_data[rs_y_idx], frame_data[rs_c_idx]
        lh_x, lh_y, lh_c = frame_data[lh_x_idx], frame_data[lh_y_idx], frame_data[lh_c_idx]
        rh_x, rh_y, rh_c = frame_data[rh_x_idx], frame_data[rh_y_idx], frame_data[rh_c_idx]

        mid_shoulder_x, mid_shoulder_y = np.nan, np.nan
        valid_ls, valid_rs = ls_c > min_confidence, rs_c > min_confidence
        if valid_ls and valid_rs: mid_shoulder_x, mid_shoulder_y = (ls_x + rs_x) / 2, (ls_y + rs_y) / 2
        elif valid_ls: mid_shoulder_x, mid_shoulder_y = ls_x, ls_y
        elif valid_rs: mid_shoulder_x, mid_shoulder_y = rs_x, rs_y

        mid_hip_x, mid_hip_y = np.nan, np.nan
        valid_lh, valid_rh = lh_c > min_confidence, rh_c > min_confidence
        if valid_lh and valid_rh: mid_hip_x, mid_hip_y = (lh_x + rh_x) / 2, (lh_y + rh_y) / 2
        elif valid_lh: mid_hip_x, mid_hip_y = lh_x, lh_y
        elif valid_rh: mid_hip_x, mid_hip_y = rh_x, rh_y

        if np.isnan(mid_hip_x) or np.isnan(mid_hip_y):
            normalized_sequence[t, :] = frame_data; continue

        reference_height = np.nan
        if not np.isnan(mid_shoulder_y) and not np.isnan(mid_hip_y):
            reference_height = np.abs(mid_shoulder_y - mid_hip_y)

        perform_scaling = not (np.isnan(reference_height) or reference_height < 1e-5)

        for kp_i in range(NUM_KEYPOINTS):
            x_i_col, y_i_col = kp_i * 3, kp_i * 3 + 1
            current_frame_normalized[x_i_col] -= mid_hip_x
            current_frame_normalized[y_i_col] -= mid_hip_y
            if perform_scaling:
                current_frame_normalized[x_i_col] /= reference_height
                current_frame_normalized[y_i_col] /= reference_height
        normalized_sequence[t, :] = current_frame_normalized
    return normalized_sequence

# %%
# ----- 3. DATA LOADING FUNCTION  -----
def load_dataset(data_path, expected_shape_template=(30, None), normalize=True, min_confidence_norm=0.3):
    if NUM_KEYPOINTS is None or NUM_KEYPOINTS == 0:
        raise ValueError("NUM_KEYPOINTS is not set or is zero.")
    expected_shape = (expected_shape_template[0], NUM_KEYPOINTS * 3)
    
    X, y = [], []
    npy_filepaths = []

    print(f"Loading data from: {data_path}, expecting shape {expected_shape} for .npy files.")
    for label_name, label_val in [('no_fall', 0), ('fall', 1)]:
        folder = os.path.join(data_path, label_name)
        if not os.path.isdir(folder):
            print(f"Warning: Subfolder not found for label '{label_name}': {folder}")
            continue
        
        files_in_folder = glob(os.path.join(folder, "*.npy"))
        print(f"Found {len(files_in_folder)} .npy files in {folder}")
        
        loaded_count_for_label = 0
        for file_path_str in files_in_folder:
            try:
                arr = np.load(file_path_str)
            except Exception as e:
                print(f"Warning: Could not load file {file_path_str}: {e}")
                continue

            if arr.shape == expected_shape:
                if normalize:
                    arr_normalized = normalize_skeleton(arr, min_confidence=min_confidence_norm)
                    if np.isnan(arr_normalized).any():
                        arr_normalized = np.nan_to_num(arr_normalized, nan=0.0, posinf=0.0, neginf=0.0)
                    X.append(arr_normalized)
                else:
                    X.append(arr)
                y.append(label_val)
                npy_filepaths.append(file_path_str)
                loaded_count_for_label += 1
            else:
                print(f"Warning: Skipping file {file_path_str} due to incorrect shape: {arr.shape}. Expected: {expected_shape}")
        print(f"Successfully loaded {loaded_count_for_label} samples for label '{label_name}'.")

    if not X:
        print(f"Critical Warning: No data was loaded from {data_path}.")
        return np.array([]), np.array([]), []
        
    return np.array(X), np.array(y), npy_filepaths

# %%
# --- Transformer Encoder Block ---
def transformer_encoder_block(inputs, d_model, num_heads, ff_dim, dropout_rate=0.1, name_prefix=""):
    attention_output = MultiHeadAttention(
        num_heads=num_heads, key_dim=d_model // num_heads, dropout=dropout_rate,
        name=f"{name_prefix}_mha"
    )(inputs, inputs, inputs)
    attention_output = Dropout(dropout_rate, name=f"{name_prefix}_mha_dropout")(attention_output)
    out1 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm1")(inputs + attention_output)

    ffn_output = Dense(ff_dim, activation="relu", name=f"{name_prefix}_ffn_dense1")(out1)
    ffn_output = Dense(d_model, name=f"{name_prefix}_ffn_dense2")(ffn_output)
    ffn_output = Dropout(dropout_rate, name=f"{name_prefix}_ffn_dropout")(ffn_output)
    out2 = LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_layernorm2")(out1 + ffn_output)
    return out2

# --- Positional Embedding Layer (Learned) ---
def get_positional_embedding(seq_len, d_model, name_prefix=""):
    positions = tf.range(start=0, limit=seq_len, delta=1)
    position_embeddings_2d = Embedding(input_dim=seq_len, output_dim=d_model, name=f"{name_prefix}_pos_embed")(positions)
    position_embeddings_3d = tf.expand_dims(position_embeddings_2d, axis=0)
    return position_embeddings_3d

# %%
# --- Model Creation Function ---
def create_transformer_classifier(
    input_shape,
    num_encoder_blocks=2,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    projection_dim=None,
    final_dense_units=32,
    dropout_rate=0.1,
    learning_rate=0.0005
):
    timesteps, num_features = input_shape
    if projection_dim is None: projection_dim = d_model

    inputs = Input(shape=input_shape, name="input_features")
    projected_x = Dense(projection_dim, name="feature_projection")(inputs)
    positional_embeddings = get_positional_embedding(timesteps, projection_dim, name_prefix="pos_enc")
    x = Add(name="add_positional_encoding")([projected_x, positional_embeddings])
    x = Dropout(dropout_rate, name="input_dropout_after_pos_enc")(x)

    for i in range(num_encoder_blocks):
        x = transformer_encoder_block(x, projection_dim, num_heads, ff_dim, dropout_rate, name_prefix=f"encoder_block_{i+1}")

    x = GlobalAveragePooling1D(name="global_avg_pooling")(x)
    x = Dropout(dropout_rate, name="dropout_after_pooling")(x)
    x = Dense(final_dense_units, activation="relu", name="final_dense_1")(x)
    x = Dropout(dropout_rate / 2, name="dropout_final_dense")(x)
    outputs = Dense(1, activation="sigmoid", name="output_sigmoid")(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    # ใช้ tf.keras.metrics.F1Score
    # สำหรับ binary classification ที่มี output เป็น sigmoid และ target เป็น 0 หรือ 1,
    # Keras F1Score จะคำนวณ F1 ของ positive class (1) โดย default
    # ถ้าต้องการ Macro F1 (เฉลี่ย F1 ของ class 0 และ class 1)
    f1_macro_metric = tf.keras.metrics.F1Score(
        average='macro', # คำนวณ F1 สำหรับแต่ละคลาสแล้วเฉลี่ย
        threshold=0.5,   # Threshold สำหรับการแปลง probability เป็น class label
        name='f1_macro'  # ชื่อนี้จะปรากฏใน history.history
    )
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), 
                  loss='binary_crossentropy',
                  metrics=['accuracy', f1_macro_metric]) # เพิ่ม f1_macro_metric
    return model

# %%
#--- Load Dataset ---

# Paths 
base_train = '/kaggle/input/fall-dataset6/train'
base_val   = '/kaggle/input/fall-dataset6/val'
base_test  = '/kaggle/input/fall-dataset6/test'

# ----- Parameters -----
TIMESTEPS = 30
EXPECTED_SHAPE_TEMPLATE = (TIMESTEPS, None)
MIN_CONF_NORM = 0.2

print("\n--- Loading Training Data ---")
X_train_orig, y_train_orig, train_npy_filepaths = load_dataset(
    base_train, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Validation Data ---")
X_val_orig, y_val_orig, val_npy_filepaths = load_dataset(
    base_val, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)
print("\n--- Loading Test Data ---")
X_test_orig, y_test_orig, test_npy_filepaths = load_dataset(
    base_test, expected_shape_template=EXPECTED_SHAPE_TEMPLATE, normalize=True, min_confidence_norm=MIN_CONF_NORM
)

if X_train_orig.size == 0:
    print("FATAL ERROR: Training data is empty.")
else:
    if len(X_train_orig) == len(train_npy_filepaths): print(f"Training set: Loaded {len(X_train_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Training set! Samples: {len(X_train_orig)}, Filepaths: {len(train_npy_filepaths)}.")

if X_val_orig.size > 0:
    if len(X_val_orig) == len(val_npy_filepaths): print(f"Validation set: Loaded {len(X_val_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Validation set! Samples: {len(X_val_orig)}, Filepaths: {len(val_npy_filepaths)}.")
else: print("Validation data is empty or was not loaded.")

if X_test_orig.size > 0:
    if len(X_test_orig) == len(test_npy_filepaths): print(f"Test set: Loaded {len(X_test_orig)} samples and filepaths.")
    else: print(f"WARNING: Mismatch in Test set! Samples: {len(X_test_orig)}, Filepaths: {len(test_npy_filepaths)}.")
else: print("Test data is empty or was not loaded.")
    
print(f"\nShapes after loading:")
print(f"Train: X={X_train_orig.shape if X_train_orig.size > 0 else 'Empty'}, y={y_train_orig.shape if y_train_orig.size > 0 else 'Empty'}")
print(f"Val:   X={X_val_orig.shape if X_val_orig.size > 0 else 'Empty'}, y={y_val_orig.shape if y_val_orig.size > 0 else 'Empty'}")
print(f"Test:  X={X_test_orig.shape if X_test_orig.size > 0 else 'Empty'}, y={y_test_orig.shape if y_test_orig.size > 0 else 'Empty'}")

if 'NUM_KEYPOINTS' in locals() and isinstance(NUM_KEYPOINTS, int) and NUM_KEYPOINTS > 0:
    transformer_input_shape = (TIMESTEPS, NUM_KEYPOINTS * 3)
    print(f"\nTransformer Input Shape: {transformer_input_shape}")
else:
    print("\nERROR: NUM_KEYPOINTS not defined correctly. Cannot determine Transformer Input Shape.")
    transformer_input_shape = (TIMESTEPS, -1)
# Out:
# --- Loading Training Data ---
# Loading data from: /kaggle/input/fall-dataset6/train, expecting shape (30, 51) for .npy files.
# Found 6279 .npy files in /kaggle/input/fall-dataset6/train/no_fall
# Successfully loaded 6279 samples for label 'no_fall'.
# Found 5722 .npy files in /kaggle/input/fall-dataset6/train/fall
# Successfully loaded 5722 samples for label 'fall'.
#
# --- Loading Validation Data ---
# Loading data from: /kaggle/input/fall-dataset6/val, expecting shape (30, 51) for .npy files.
# Found 1346 .npy files in /kaggle/input/fall-dataset6/val/no_fall
# Successfully loaded 1346 samples for label 'no_fall'.
# Found 1226 .npy files in /kaggle/input/fall-dataset6/val/fall
# Successfully loaded 1226 samples for label 'fall'.
#
# --- Loading Test Data ---
# Loading data from: /kaggle/input/fall-dataset6/test, expecting shape (30, 51) for .npy files.
# Found 1346 .npy files in /kaggle/input/fall-dataset6/test/no_fall
# Successfully loaded 1346 samples for label 'no_fall'.
# Found 1226 .npy files in /kaggle/input/fall-dataset6/test/fall
# Successfully loaded 1226 samples for label 'fall'.
# Training set: Loaded 12001 samples and filepaths.
# Validation set: Loaded 2572 samples and filepaths.
# Test set: Loaded 2572 samples and filepaths.
#
# Shapes after loading:
# Train: X=(12001, 30, 51), y=(12001,)
# Val:   X=(2572, 30, 51), y=(2572,)
# Test:  X=(2572, 30, 51), y=(2572,)
#
# Transformer Input Shape: (30, 51)

# %%
# ----- Model Parameters -----
NUM_ENCODER_BLOCKS = 3
D_MODEL = 64
NUM_HEADS = 4
FF_DIM = D_MODEL * 2
PROJECTION_DIM = D_MODEL
FINAL_DENSE_UNITS = 32
DROPOUT_RATE = 0.06
LEARNING_RATE = 0.0001

# ----- Cross-Validation -----
N_SPLITS_CV = 5
EPOCHS_CV = 50
BATCH_SIZE_CV = 32
cv_accuracies, cv_losses, cv_f1_macros = [], [], []
fold_no = 1

print(f"\n--- Starting {N_SPLITS_CV}-Fold Cross-Validation with Transformer Classifier ---")
if X_train_orig.shape[0] > 0 and y_train_orig.shape[0] >= N_SPLITS_CV:
    skf = StratifiedKFold(n_splits=N_SPLITS_CV, shuffle=True, random_state=42)
    for train_idx, val_idx in skf.split(X_train_orig, y_train_orig):
        print(f"--- Fold {fold_no}/{N_SPLITS_CV} ---")
        X_cv_train, X_cv_val = X_train_orig[train_idx], X_train_orig[val_idx]
        y_cv_train_1d, y_cv_val_1d = y_train_orig[train_idx], y_train_orig[val_idx] # Keep 1D versions if needed elsewhere

        # --- RESHAPE y_true for Keras F1Score metric ---
        y_cv_train_2d = y_cv_train_1d.reshape(-1, 1)
        y_cv_val_2d = y_cv_val_1d.reshape(-1, 1)
        
        cv_model = create_transformer_classifier(
            input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
            d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
            projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
            dropout_rate=DROPOUT_RATE, learning_rate=LEARNING_RATE
        )
        
        early_stopping_cv = EarlyStopping(monitor='val_f1_macro', patience=15, verbose=1, mode='max', restore_best_weights=True)
        
        history_cv = cv_model.fit(X_cv_train, y_cv_train_2d, # Use 2D y_true for training
                                  epochs=EPOCHS_CV, batch_size=BATCH_SIZE_CV, 
                                  validation_data=(X_cv_val, y_cv_val_2d), # Use 2D y_true for validation
                                  callbacks=[early_stopping_cv],
                                  verbose=1) 
        
        # Evaluate with 2D y_true
        eval_results_cv = cv_model.evaluate(X_cv_val, y_cv_val_2d, verbose=0)
        loss, accuracy, f1_macro = eval_results_cv[0], eval_results_cv[1], eval_results_cv[2]

        print(f"Fold {fold_no} - CV Val Loss: {loss:.4f}, CV Val Acc: {accuracy:.4f}, CV Val F1-Macro: {f1_macro:.4f}")
        cv_losses.append(loss); cv_accuracies.append(accuracy); cv_f1_macros.append(f1_macro)
        fold_no += 1

    if cv_accuracies:
        print("\n--- Cross-Validation Summary ---")
        print(f"Average CV Loss: {np.mean(cv_losses):.4f} (+/- {np.std(cv_losses):.4f})")
        print(f"Average CV Accuracy: {np.mean(cv_accuracies):.4f} (+/- {np.std(cv_accuracies):.4f})")
        if cv_f1_macros:
             print(f"Average CV F1-Macro: {np.mean(cv_f1_macros):.4f} (+/- {np.std(cv_f1_macros):.4f})")
    else: 
        print("Cross-validation did not produce results (or was skipped).")
else:
    print(f"Skipping CV: Training data empty or too few samples for {N_SPLITS_CV} splits.")
# Out:
# --- Starting 5-Fold Cross-Validation with Transformer Classifier ---
# --- Fold 1/5 ---
# Epoch 1/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.6781 - f1_macro: 0.6547 - loss: 0.5967 - val_accuracy: 0.8034 - val_f1_macro: 0.7897 - val_loss: 0.4334
# Epoch 2/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8014 - f1_macro: 0.7850 - loss: 0.4442 - val_accuracy: 0.8238 - val_f1_macro: 0.8107 - val_loss: 0.4034
# Epoch 3/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8275 - f1_macro: 0.8187 - loss: 0.4062 - val_accuracy: 0.8492 - val_f1_macro: 0.8421 - val_loss: 0.3585
# Epoch 4/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8429 - f1_macro: 0.8376 - loss: 0.3737 - val_accuracy: 0.8463 - val_f1_macro: 0.8325 - val_loss: 0.3745
# Epoch 5/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8523 - f1_macro: 0.8462 - loss: 0.3554 - val_accuracy: 0.8546 - val_f1_macro: 0.8436 - val_loss: 0.3594
# Epoch 6/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8611 - f1_macro: 0.8592 - loss: 0.3403 - val_accuracy: 0.8546 - val_f1_macro: 0.8426 - val_loss: 0.3521
# Epoch 7/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8678 - f1_macro: 0.8629 - loss: 0.3305 - val_accuracy: 0.8584 - val_f1_macro: 0.8494 - val_loss: 0.3475
# Epoch 8/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8730 - f1_macro: 0.8681 - loss: 0.3158 - val_accuracy: 0.8676 - val_f1_macro: 0.8640 - val_loss: 0.3270
# Epoch 9/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8658 - f1_macro: 0.8626 - loss: 0.3262 - val_accuracy: 0.8684 - val_f1_macro: 0.8609 - val_loss: 0.3367
# Epoch 10/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8689 - f1_macro: 0.8652 - loss: 0.3129 - val_accuracy: 0.8742 - val_f1_macro: 0.8704 - val_loss: 0.3295
# Epoch 11/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8750 - f1_macro: 0.8703 - loss: 0.3038 - val_accuracy: 0.8738 - val_f1_macro: 0.8674 - val_loss: 0.3196
# Epoch 12/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8801 - f1_macro: 0.8783 - loss: 0.2967 - val_accuracy: 0.8730 - val_f1_macro: 0.8676 - val_loss: 0.3292
# Epoch 13/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8799 - f1_macro: 0.8773 - loss: 0.2921 - val_accuracy: 0.8726 - val_f1_macro: 0.8651 - val_loss: 0.3286
# Epoch 14/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8839 - f1_macro: 0.8820 - loss: 0.2823 - val_accuracy: 0.8742 - val_f1_macro: 0.8696 - val_loss: 0.3192
# Epoch 15/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8753 - f1_macro: 0.8748 - loss: 0.2919 - val_accuracy: 0.8709 - val_f1_macro: 0.8647 - val_loss: 0.3191
# Epoch 16/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8817 - f1_macro: 0.8802 - loss: 0.2826 - val_accuracy: 0.8801 - val_f1_macro: 0.8718 - val_loss: 0.3144
# Epoch 17/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8834 - f1_macro: 0.8773 - loss: 0.2800 - val_accuracy: 0.8784 - val_f1_macro: 0.8735 - val_loss: 0.3086
# Epoch 18/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8903 - f1_macro: 0.8877 - loss: 0.2679 - val_accuracy: 0.8709 - val_f1_macro: 0.8597 - val_loss: 0.3332
# Epoch 19/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8902 - f1_macro: 0.8863 - loss: 0.2629 - val_accuracy: 0.8796 - val_f1_macro: 0.8718 - val_loss: 0.3129
# Epoch 20/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8913 - f1_macro: 0.8872 - loss: 0.2668 - val_accuracy: 0.8796 - val_f1_macro: 0.8724 - val_loss: 0.3138
# Epoch 21/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8986 - f1_macro: 0.8935 - loss: 0.2486 - val_accuracy: 0.8801 - val_f1_macro: 0.8727 - val_loss: 0.3186
# Epoch 22/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8985 - f1_macro: 0.8955 - loss: 0.2508 - val_accuracy: 0.8809 - val_f1_macro: 0.8778 - val_loss: 0.3011
# Epoch 23/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9002 - f1_macro: 0.8970 - loss: 0.2470 - val_accuracy: 0.8759 - val_f1_macro: 0.8687 - val_loss: 0.3139
# Epoch 24/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8977 - f1_macro: 0.8935 - loss: 0.2525 - val_accuracy: 0.8817 - val_f1_macro: 0.8762 - val_loss: 0.2986
# Epoch 25/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9024 - f1_macro: 0.8995 - loss: 0.2417 - val_accuracy: 0.8842 - val_f1_macro: 0.8786 - val_loss: 0.3140
# Epoch 26/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9081 - f1_macro: 0.9058 - loss: 0.2316 - val_accuracy: 0.8825 - val_f1_macro: 0.8746 - val_loss: 0.3147
# Epoch 27/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9075 - f1_macro: 0.9032 - loss: 0.2279 - val_accuracy: 0.8805 - val_f1_macro: 0.8714 - val_loss: 0.3284
# Epoch 28/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9063 - f1_macro: 0.9049 - loss: 0.2245 - val_accuracy: 0.8817 - val_f1_macro: 0.8729 - val_loss: 0.3251
# Epoch 29/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9106 - f1_macro: 0.9062 - loss: 0.2202 - val_accuracy: 0.8817 - val_f1_macro: 0.8753 - val_loss: 0.3161
# Epoch 30/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9055 - f1_macro: 0.9042 - loss: 0.2268 - val_accuracy: 0.8771 - val_f1_macro: 0.8702 - val_loss: 0.3260
# Epoch 31/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9114 - f1_macro: 0.9089 - loss: 0.2279 - val_accuracy: 0.8821 - val_f1_macro: 0.8743 - val_loss: 0.3081
# Epoch 32/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9188 - f1_macro: 0.9146 - loss: 0.2054 - val_accuracy: 0.8805 - val_f1_macro: 0.8734 - val_loss: 0.3212
# Epoch 33/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9206 - f1_macro: 0.9169 - loss: 0.2007 - val_accuracy: 0.8846 - val_f1_macro: 0.8807 - val_loss: 0.3083
# Epoch 34/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9143 - f1_macro: 0.9097 - loss: 0.2153 - val_accuracy: 0.8850 - val_f1_macro: 0.8788 - val_loss: 0.3255
# Epoch 35/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9164 - f1_macro: 0.9135 - loss: 0.1991 - val_accuracy: 0.8850 - val_f1_macro: 0.8802 - val_loss: 0.3261
# Epoch 36/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9195 - f1_macro: 0.9179 - loss: 0.2032 - val_accuracy: 0.8875 - val_f1_macro: 0.8817 - val_loss: 0.3173
# Epoch 37/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9239 - f1_macro: 0.9209 - loss: 0.1915 - val_accuracy: 0.8855 - val_f1_macro: 0.8800 - val_loss: 0.3175
# Epoch 38/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9219 - f1_macro: 0.9193 - loss: 0.1992 - val_accuracy: 0.8863 - val_f1_macro: 0.8797 - val_loss: 0.3358
# Epoch 39/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9202 - f1_macro: 0.9169 - loss: 0.1974 - val_accuracy: 0.8834 - val_f1_macro: 0.8788 - val_loss: 0.3274
# Epoch 40/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9249 - f1_macro: 0.9222 - loss: 0.1912 - val_accuracy: 0.8855 - val_f1_macro: 0.8778 - val_loss: 0.3290
# Epoch 41/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9241 - f1_macro: 0.9214 - loss: 0.1867 - val_accuracy: 0.8871 - val_f1_macro: 0.8832 - val_loss: 0.3301
# Epoch 42/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9260 - f1_macro: 0.9218 - loss: 0.1802 - val_accuracy: 0.8830 - val_f1_macro: 0.8753 - val_loss: 0.3567
# Epoch 43/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9234 - f1_macro: 0.9206 - loss: 0.1849 - val_accuracy: 0.8880 - val_f1_macro: 0.8838 - val_loss: 0.3207
# Epoch 44/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9305 - f1_macro: 0.9277 - loss: 0.1808 - val_accuracy: 0.8855 - val_f1_macro: 0.8782 - val_loss: 0.3500
# Epoch 45/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9279 - f1_macro: 0.9253 - loss: 0.1803 - val_accuracy: 0.8801 - val_f1_macro: 0.8698 - val_loss: 0.3509
# Epoch 46/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9274 - f1_macro: 0.9239 - loss: 0.1731 - val_accuracy: 0.8776 - val_f1_macro: 0.8690 - val_loss: 0.3519
# Epoch 47/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9247 - f1_macro: 0.9222 - loss: 0.1863 - val_accuracy: 0.8817 - val_f1_macro: 0.8738 - val_loss: 0.3451
# Epoch 48/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9285 - f1_macro: 0.9240 - loss: 0.1771 - val_accuracy: 0.8871 - val_f1_macro: 0.8807 - val_loss: 0.3583
# Epoch 49/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9297 - f1_macro: 0.9266 - loss: 0.1660 - val_accuracy: 0.8730 - val_f1_macro: 0.8598 - val_loss: 0.3627
# Epoch 50/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9360 - f1_macro: 0.9327 - loss: 0.1550 - val_accuracy: 0.8751 - val_f1_macro: 0.8615 - val_loss: 0.3922
# Restoring model weights from the end of the best epoch: 43.
# Fold 1 - CV Val Loss: 0.3207, CV Val Acc: 0.8880, CV Val F1-Macro: 0.8838
# --- Fold 2/5 ---
# Epoch 1/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.7041 - f1_macro: 0.6668 - loss: 0.5603 - val_accuracy: 0.8033 - val_f1_macro: 0.7937 - val_loss: 0.4451
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8090 - f1_macro: 0.7973 - loss: 0.4294 - val_accuracy: 0.8242 - val_f1_macro: 0.8192 - val_loss: 0.4227
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8417 - f1_macro: 0.8362 - loss: 0.3777 - val_accuracy: 0.8383 - val_f1_macro: 0.8340 - val_loss: 0.3876
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8501 - f1_macro: 0.8438 - loss: 0.3636 - val_accuracy: 0.8354 - val_f1_macro: 0.8372 - val_loss: 0.3782
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8693 - f1_macro: 0.8634 - loss: 0.3395 - val_accuracy: 0.8417 - val_f1_macro: 0.8422 - val_loss: 0.3722
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8723 - f1_macro: 0.8689 - loss: 0.3248 - val_accuracy: 0.8425 - val_f1_macro: 0.8409 - val_loss: 0.3715
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8764 - f1_macro: 0.8756 - loss: 0.3176 - val_accuracy: 0.8483 - val_f1_macro: 0.8447 - val_loss: 0.3769
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8791 - f1_macro: 0.8749 - loss: 0.3055 - val_accuracy: 0.8504 - val_f1_macro: 0.8473 - val_loss: 0.3657
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8697 - f1_macro: 0.8683 - loss: 0.3128 - val_accuracy: 0.8504 - val_f1_macro: 0.8463 - val_loss: 0.3711
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8865 - f1_macro: 0.8857 - loss: 0.2964 - val_accuracy: 0.8554 - val_f1_macro: 0.8501 - val_loss: 0.3525
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8833 - f1_macro: 0.8806 - loss: 0.3011 - val_accuracy: 0.8554 - val_f1_macro: 0.8524 - val_loss: 0.3463
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8847 - f1_macro: 0.8799 - loss: 0.2958 - val_accuracy: 0.8475 - val_f1_macro: 0.8495 - val_loss: 0.3566
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8698 - f1_macro: 0.8688 - loss: 0.3151 - val_accuracy: 0.8592 - val_f1_macro: 0.8598 - val_loss: 0.3523
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8829 - f1_macro: 0.8795 - loss: 0.2939 - val_accuracy: 0.8637 - val_f1_macro: 0.8616 - val_loss: 0.3409
# Epoch 15/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8899 - f1_macro: 0.8854 - loss: 0.2720 - val_accuracy: 0.8625 - val_f1_macro: 0.8602 - val_loss: 0.3568
# Epoch 16/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8890 - f1_macro: 0.8816 - loss: 0.2827 - val_accuracy: 0.8600 - val_f1_macro: 0.8585 - val_loss: 0.3474
# Epoch 17/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8925 - f1_macro: 0.8903 - loss: 0.2683 - val_accuracy: 0.8662 - val_f1_macro: 0.8625 - val_loss: 0.3352
# Epoch 18/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8935 - f1_macro: 0.8903 - loss: 0.2649 - val_accuracy: 0.8579 - val_f1_macro: 0.8521 - val_loss: 0.3555
# Epoch 19/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8989 - f1_macro: 0.8962 - loss: 0.2683 - val_accuracy: 0.8671 - val_f1_macro: 0.8620 - val_loss: 0.3428
# Epoch 20/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8974 - f1_macro: 0.8938 - loss: 0.2605 - val_accuracy: 0.8654 - val_f1_macro: 0.8648 - val_loss: 0.3434
# Epoch 21/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8949 - f1_macro: 0.8914 - loss: 0.2584 - val_accuracy: 0.8671 - val_f1_macro: 0.8643 - val_loss: 0.3414
# Epoch 22/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9112 - f1_macro: 0.9070 - loss: 0.2344 - val_accuracy: 0.8671 - val_f1_macro: 0.8645 - val_loss: 0.3284
# Epoch 23/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8927 - f1_macro: 0.8869 - loss: 0.2603 - val_accuracy: 0.8667 - val_f1_macro: 0.8628 - val_loss: 0.3369
# Epoch 24/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8960 - f1_macro: 0.8900 - loss: 0.2551 - val_accuracy: 0.8692 - val_f1_macro: 0.8669 - val_loss: 0.3278
# Epoch 25/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9125 - f1_macro: 0.9091 - loss: 0.2302 - val_accuracy: 0.8675 - val_f1_macro: 0.8623 - val_loss: 0.3393
# Epoch 26/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9049 - f1_macro: 0.9014 - loss: 0.2398 - val_accuracy: 0.8754 - val_f1_macro: 0.8736 - val_loss: 0.3374
# Epoch 27/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9083 - f1_macro: 0.9033 - loss: 0.2379 - val_accuracy: 0.8721 - val_f1_macro: 0.8669 - val_loss: 0.3362
# Epoch 28/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9057 - f1_macro: 0.9033 - loss: 0.2365 - val_accuracy: 0.8721 - val_f1_macro: 0.8689 - val_loss: 0.3291
# Epoch 29/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9104 - f1_macro: 0.9080 - loss: 0.2341 - val_accuracy: 0.8754 - val_f1_macro: 0.8717 - val_loss: 0.3266
# Epoch 30/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9180 - f1_macro: 0.9152 - loss: 0.2092 - val_accuracy: 0.8587 - val_f1_macro: 0.8514 - val_loss: 0.3491
# Epoch 31/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9126 - f1_macro: 0.9095 - loss: 0.2304 - val_accuracy: 0.8721 - val_f1_macro: 0.8696 - val_loss: 0.3259
# Epoch 32/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9099 - f1_macro: 0.9070 - loss: 0.2242 - val_accuracy: 0.8737 - val_f1_macro: 0.8706 - val_loss: 0.3321
# Epoch 33/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9077 - f1_macro: 0.9037 - loss: 0.2314 - val_accuracy: 0.8721 - val_f1_macro: 0.8696 - val_loss: 0.3460
# Epoch 34/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9190 - f1_macro: 0.9145 - loss: 0.2117 - val_accuracy: 0.8750 - val_f1_macro: 0.8745 - val_loss: 0.3403
# Epoch 35/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9204 - f1_macro: 0.9175 - loss: 0.2048 - val_accuracy: 0.8737 - val_f1_macro: 0.8673 - val_loss: 0.3376
# Epoch 36/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9209 - f1_macro: 0.9189 - loss: 0.2030 - val_accuracy: 0.8662 - val_f1_macro: 0.8588 - val_loss: 0.3631
# Epoch 37/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9189 - f1_macro: 0.9149 - loss: 0.2091 - val_accuracy: 0.8729 - val_f1_macro: 0.8688 - val_loss: 0.3332
# Epoch 38/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9160 - f1_macro: 0.9139 - loss: 0.2057 - val_accuracy: 0.8750 - val_f1_macro: 0.8733 - val_loss: 0.3339
# Epoch 39/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9263 - f1_macro: 0.9227 - loss: 0.1918 - val_accuracy: 0.8788 - val_f1_macro: 0.8759 - val_loss: 0.3248
# Epoch 40/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9268 - f1_macro: 0.9244 - loss: 0.1920 - val_accuracy: 0.8733 - val_f1_macro: 0.8689 - val_loss: 0.3531
# Epoch 41/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9274 - f1_macro: 0.9251 - loss: 0.1833 - val_accuracy: 0.8717 - val_f1_macro: 0.8638 - val_loss: 0.3323
# Epoch 42/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9267 - f1_macro: 0.9234 - loss: 0.1885 - val_accuracy: 0.8700 - val_f1_macro: 0.8685 - val_loss: 0.3444
# Epoch 43/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9240 - f1_macro: 0.9213 - loss: 0.1944 - val_accuracy: 0.8729 - val_f1_macro: 0.8710 - val_loss: 0.3515
# Epoch 44/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9266 - f1_macro: 0.9250 - loss: 0.1840 - val_accuracy: 0.8742 - val_f1_macro: 0.8675 - val_loss: 0.3500
# Epoch 45/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9388 - f1_macro: 0.9370 - loss: 0.1662 - val_accuracy: 0.8763 - val_f1_macro: 0.8716 - val_loss: 0.3357
# Epoch 46/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9293 - f1_macro: 0.9260 - loss: 0.1817 - val_accuracy: 0.8742 - val_f1_macro: 0.8686 - val_loss: 0.3441
# Epoch 47/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9275 - f1_macro: 0.9255 - loss: 0.1840 - val_accuracy: 0.8800 - val_f1_macro: 0.8780 - val_loss: 0.3474
# Epoch 48/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9404 - f1_macro: 0.9387 - loss: 0.1681 - val_accuracy: 0.8746 - val_f1_macro: 0.8696 - val_loss: 0.3484
# Epoch 49/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9297 - f1_macro: 0.9277 - loss: 0.1764 - val_accuracy: 0.8729 - val_f1_macro: 0.8672 - val_loss: 0.3350
# Epoch 50/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9392 - f1_macro: 0.9373 - loss: 0.1604 - val_accuracy: 0.8767 - val_f1_macro: 0.8760 - val_loss: 0.3551
# Restoring model weights from the end of the best epoch: 47.
# Fold 2 - CV Val Loss: 0.3474, CV Val Acc: 0.8800, CV Val F1-Macro: 0.8780
# --- Fold 3/5 ---
# Epoch 1/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.7132 - f1_macro: 0.6599 - loss: 0.5526 - val_accuracy: 0.8296 - val_f1_macro: 0.8216 - val_loss: 0.4131
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8196 - f1_macro: 0.8140 - loss: 0.4216 - val_accuracy: 0.8358 - val_f1_macro: 0.8211 - val_loss: 0.3969
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8355 - f1_macro: 0.8276 - loss: 0.3899 - val_accuracy: 0.8487 - val_f1_macro: 0.8358 - val_loss: 0.3562
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8538 - f1_macro: 0.8490 - loss: 0.3640 - val_accuracy: 0.8571 - val_f1_macro: 0.8458 - val_loss: 0.3486
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8561 - f1_macro: 0.8517 - loss: 0.3471 - val_accuracy: 0.8742 - val_f1_macro: 0.8706 - val_loss: 0.3223
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8629 - f1_macro: 0.8599 - loss: 0.3353 - val_accuracy: 0.8654 - val_f1_macro: 0.8574 - val_loss: 0.3456
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8643 - f1_macro: 0.8590 - loss: 0.3330 - val_accuracy: 0.8683 - val_f1_macro: 0.8620 - val_loss: 0.3208
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8640 - f1_macro: 0.8588 - loss: 0.3210 - val_accuracy: 0.8629 - val_f1_macro: 0.8525 - val_loss: 0.3244
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8737 - f1_macro: 0.8706 - loss: 0.3101 - val_accuracy: 0.8700 - val_f1_macro: 0.8610 - val_loss: 0.3278
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8719 - f1_macro: 0.8677 - loss: 0.3127 - val_accuracy: 0.8671 - val_f1_macro: 0.8585 - val_loss: 0.3227
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8702 - f1_macro: 0.8697 - loss: 0.3234 - val_accuracy: 0.8729 - val_f1_macro: 0.8679 - val_loss: 0.3054
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8798 - f1_macro: 0.8757 - loss: 0.2987 - val_accuracy: 0.8729 - val_f1_macro: 0.8643 - val_loss: 0.3193
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8838 - f1_macro: 0.8811 - loss: 0.2993 - val_accuracy: 0.8746 - val_f1_macro: 0.8690 - val_loss: 0.3099
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8810 - f1_macro: 0.8777 - loss: 0.2922 - val_accuracy: 0.8783 - val_f1_macro: 0.8733 - val_loss: 0.3066
# Epoch 15/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8659 - f1_macro: 0.8668 - loss: 0.3197 - val_accuracy: 0.8687 - val_f1_macro: 0.8586 - val_loss: 0.3198
# Epoch 16/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8879 - f1_macro: 0.8831 - loss: 0.2843 - val_accuracy: 0.8721 - val_f1_macro: 0.8631 - val_loss: 0.3226
# Epoch 17/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8827 - f1_macro: 0.8802 - loss: 0.2849 - val_accuracy: 0.8746 - val_f1_macro: 0.8671 - val_loss: 0.3230
# Epoch 18/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8881 - f1_macro: 0.8855 - loss: 0.2864 - val_accuracy: 0.8796 - val_f1_macro: 0.8730 - val_loss: 0.3133
# Epoch 19/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8869 - f1_macro: 0.8828 - loss: 0.2808 - val_accuracy: 0.8754 - val_f1_macro: 0.8704 - val_loss: 0.3052
# Epoch 20/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8877 - f1_macro: 0.8858 - loss: 0.2747 - val_accuracy: 0.8775 - val_f1_macro: 0.8703 - val_loss: 0.3059
# Epoch 21/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8966 - f1_macro: 0.8940 - loss: 0.2645 - val_accuracy: 0.8758 - val_f1_macro: 0.8674 - val_loss: 0.3121
# Epoch 22/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8950 - f1_macro: 0.8912 - loss: 0.2684 - val_accuracy: 0.8737 - val_f1_macro: 0.8655 - val_loss: 0.3146
# Epoch 23/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8910 - f1_macro: 0.8880 - loss: 0.2570 - val_accuracy: 0.8750 - val_f1_macro: 0.8651 - val_loss: 0.3126
# Epoch 24/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9040 - f1_macro: 0.9019 - loss: 0.2505 - val_accuracy: 0.8733 - val_f1_macro: 0.8631 - val_loss: 0.3200
# Epoch 25/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8948 - f1_macro: 0.8906 - loss: 0.2587 - val_accuracy: 0.8758 - val_f1_macro: 0.8690 - val_loss: 0.3109
# Epoch 26/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9013 - f1_macro: 0.8987 - loss: 0.2502 - val_accuracy: 0.8742 - val_f1_macro: 0.8655 - val_loss: 0.3064
# Epoch 27/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9027 - f1_macro: 0.8996 - loss: 0.2418 - val_accuracy: 0.8704 - val_f1_macro: 0.8604 - val_loss: 0.3172
# Epoch 28/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8981 - f1_macro: 0.8920 - loss: 0.2545 - val_accuracy: 0.8763 - val_f1_macro: 0.8696 - val_loss: 0.3073
# Epoch 29/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9042 - f1_macro: 0.9007 - loss: 0.2365 - val_accuracy: 0.8750 - val_f1_macro: 0.8650 - val_loss: 0.3124
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Fold 3 - CV Val Loss: 0.3066, CV Val Acc: 0.8783, CV Val F1-Macro: 0.8733
# --- Fold 4/5 ---
# Epoch 1/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 31s 35ms/step - accuracy: 0.6890 - f1_macro: 0.6828 - loss: 0.6144 - val_accuracy: 0.7967 - val_f1_macro: 0.7732 - val_loss: 0.4405
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8085 - f1_macro: 0.8027 - loss: 0.4302 - val_accuracy: 0.8246 - val_f1_macro: 0.8070 - val_loss: 0.3994
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8355 - f1_macro: 0.8285 - loss: 0.3846 - val_accuracy: 0.8504 - val_f1_macro: 0.8441 - val_loss: 0.3631
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8463 - f1_macro: 0.8444 - loss: 0.3695 - val_accuracy: 0.8617 - val_f1_macro: 0.8545 - val_loss: 0.3430
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8606 - f1_macro: 0.8557 - loss: 0.3469 - val_accuracy: 0.8683 - val_f1_macro: 0.8636 - val_loss: 0.3360
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8600 - f1_macro: 0.8566 - loss: 0.3363 - val_accuracy: 0.8675 - val_f1_macro: 0.8599 - val_loss: 0.3367
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8690 - f1_macro: 0.8647 - loss: 0.3232 - val_accuracy: 0.8583 - val_f1_macro: 0.8443 - val_loss: 0.3434
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8633 - f1_macro: 0.8580 - loss: 0.3205 - val_accuracy: 0.8704 - val_f1_macro: 0.8664 - val_loss: 0.3153
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8786 - f1_macro: 0.8764 - loss: 0.3066 - val_accuracy: 0.8700 - val_f1_macro: 0.8656 - val_loss: 0.3225
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8738 - f1_macro: 0.8697 - loss: 0.3038 - val_accuracy: 0.8704 - val_f1_macro: 0.8629 - val_loss: 0.3096
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8762 - f1_macro: 0.8721 - loss: 0.3000 - val_accuracy: 0.8683 - val_f1_macro: 0.8605 - val_loss: 0.3283
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8814 - f1_macro: 0.8750 - loss: 0.2862 - val_accuracy: 0.8708 - val_f1_macro: 0.8632 - val_loss: 0.3114
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8861 - f1_macro: 0.8825 - loss: 0.2831 - val_accuracy: 0.8617 - val_f1_macro: 0.8487 - val_loss: 0.3265
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8878 - f1_macro: 0.8859 - loss: 0.2806 - val_accuracy: 0.8692 - val_f1_macro: 0.8592 - val_loss: 0.3150
# Epoch 15/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8887 - f1_macro: 0.8832 - loss: 0.2783 - val_accuracy: 0.8717 - val_f1_macro: 0.8641 - val_loss: 0.3115
# Epoch 16/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8926 - f1_macro: 0.8887 - loss: 0.2664 - val_accuracy: 0.8763 - val_f1_macro: 0.8723 - val_loss: 0.2943
# Epoch 17/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8916 - f1_macro: 0.8898 - loss: 0.2705 - val_accuracy: 0.8733 - val_f1_macro: 0.8652 - val_loss: 0.3014
# Epoch 18/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8899 - f1_macro: 0.8856 - loss: 0.2674 - val_accuracy: 0.8737 - val_f1_macro: 0.8644 - val_loss: 0.3235
# Epoch 19/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8962 - f1_macro: 0.8926 - loss: 0.2584 - val_accuracy: 0.8754 - val_f1_macro: 0.8680 - val_loss: 0.3130
# Epoch 20/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8977 - f1_macro: 0.8934 - loss: 0.2500 - val_accuracy: 0.8717 - val_f1_macro: 0.8642 - val_loss: 0.3066
# Epoch 21/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8979 - f1_macro: 0.8937 - loss: 0.2501 - val_accuracy: 0.8725 - val_f1_macro: 0.8627 - val_loss: 0.3047
# Epoch 22/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9002 - f1_macro: 0.8960 - loss: 0.2498 - val_accuracy: 0.8604 - val_f1_macro: 0.8461 - val_loss: 0.3242
# Epoch 23/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9015 - f1_macro: 0.8970 - loss: 0.2427 - val_accuracy: 0.8729 - val_f1_macro: 0.8627 - val_loss: 0.3049
# Epoch 24/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9091 - f1_macro: 0.9085 - loss: 0.2310 - val_accuracy: 0.8742 - val_f1_macro: 0.8643 - val_loss: 0.3050
# Epoch 25/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9091 - f1_macro: 0.9065 - loss: 0.2346 - val_accuracy: 0.8617 - val_f1_macro: 0.8457 - val_loss: 0.3461
# Epoch 26/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9025 - f1_macro: 0.8975 - loss: 0.2398 - val_accuracy: 0.8612 - val_f1_macro: 0.8437 - val_loss: 0.3374
# Epoch 27/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8931 - f1_macro: 0.8856 - loss: 0.2630 - val_accuracy: 0.8725 - val_f1_macro: 0.8615 - val_loss: 0.3167
# Epoch 28/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9017 - f1_macro: 0.8975 - loss: 0.2435 - val_accuracy: 0.8808 - val_f1_macro: 0.8733 - val_loss: 0.2967
# Epoch 29/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9110 - f1_macro: 0.9101 - loss: 0.2214 - val_accuracy: 0.8687 - val_f1_macro: 0.8553 - val_loss: 0.3279
# Epoch 30/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9163 - f1_macro: 0.9119 - loss: 0.2115 - val_accuracy: 0.8788 - val_f1_macro: 0.8693 - val_loss: 0.2990
# Epoch 31/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9147 - f1_macro: 0.9118 - loss: 0.2212 - val_accuracy: 0.8788 - val_f1_macro: 0.8707 - val_loss: 0.3066
# Epoch 32/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9142 - f1_macro: 0.9112 - loss: 0.2126 - val_accuracy: 0.8763 - val_f1_macro: 0.8665 - val_loss: 0.3077
# Epoch 33/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9129 - f1_macro: 0.9108 - loss: 0.2103 - val_accuracy: 0.8833 - val_f1_macro: 0.8767 - val_loss: 0.3057
# Epoch 34/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9157 - f1_macro: 0.9117 - loss: 0.2126 - val_accuracy: 0.8804 - val_f1_macro: 0.8714 - val_loss: 0.3196
# Epoch 35/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9193 - f1_macro: 0.9146 - loss: 0.2052 - val_accuracy: 0.8771 - val_f1_macro: 0.8677 - val_loss: 0.3240
# Epoch 36/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9179 - f1_macro: 0.9142 - loss: 0.1992 - val_accuracy: 0.8750 - val_f1_macro: 0.8650 - val_loss: 0.3167
# Epoch 37/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9218 - f1_macro: 0.9187 - loss: 0.1989 - val_accuracy: 0.8796 - val_f1_macro: 0.8701 - val_loss: 0.3203
# Epoch 38/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9170 - f1_macro: 0.9137 - loss: 0.2045 - val_accuracy: 0.8700 - val_f1_macro: 0.8591 - val_loss: 0.3308
# Epoch 39/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9223 - f1_macro: 0.9194 - loss: 0.2017 - val_accuracy: 0.8825 - val_f1_macro: 0.8753 - val_loss: 0.3307
# Epoch 40/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9208 - f1_macro: 0.9185 - loss: 0.1961 - val_accuracy: 0.8742 - val_f1_macro: 0.8636 - val_loss: 0.3511
# Epoch 41/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9250 - f1_macro: 0.9208 - loss: 0.1928 - val_accuracy: 0.8775 - val_f1_macro: 0.8679 - val_loss: 0.3510
# Epoch 42/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9291 - f1_macro: 0.9257 - loss: 0.1796 - val_accuracy: 0.8796 - val_f1_macro: 0.8708 - val_loss: 0.3304
# Epoch 43/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9308 - f1_macro: 0.9292 - loss: 0.1817 - val_accuracy: 0.8729 - val_f1_macro: 0.8613 - val_loss: 0.3443
# Epoch 44/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9316 - f1_macro: 0.9302 - loss: 0.1817 - val_accuracy: 0.8758 - val_f1_macro: 0.8656 - val_loss: 0.3490
# Epoch 45/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9215 - f1_macro: 0.9168 - loss: 0.1896 - val_accuracy: 0.8696 - val_f1_macro: 0.8565 - val_loss: 0.3776
# Epoch 46/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9327 - f1_macro: 0.9304 - loss: 0.1686 - val_accuracy: 0.8625 - val_f1_macro: 0.8482 - val_loss: 0.3768
# Epoch 47/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9339 - f1_macro: 0.9298 - loss: 0.1691 - val_accuracy: 0.8867 - val_f1_macro: 0.8826 - val_loss: 0.3298
# Epoch 48/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9339 - f1_macro: 0.9299 - loss: 0.1670 - val_accuracy: 0.8692 - val_f1_macro: 0.8552 - val_loss: 0.3842
# Epoch 49/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9331 - f1_macro: 0.9300 - loss: 0.1681 - val_accuracy: 0.8771 - val_f1_macro: 0.8678 - val_loss: 0.3605
# Epoch 50/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9359 - f1_macro: 0.9326 - loss: 0.1660 - val_accuracy: 0.8675 - val_f1_macro: 0.8549 - val_loss: 0.3761
# Restoring model weights from the end of the best epoch: 47.
# Fold 4 - CV Val Loss: 0.3298, CV Val Acc: 0.8867, CV Val F1-Macro: 0.8826
# --- Fold 5/5 ---
# Epoch 1/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.7153 - f1_macro: 0.6868 - loss: 0.5596 - val_accuracy: 0.8150 - val_f1_macro: 0.7944 - val_loss: 0.4389
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8052 - f1_macro: 0.7900 - loss: 0.4451 - val_accuracy: 0.8267 - val_f1_macro: 0.8109 - val_loss: 0.4105
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8274 - f1_macro: 0.8166 - loss: 0.4048 - val_accuracy: 0.8450 - val_f1_macro: 0.8361 - val_loss: 0.3727
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8377 - f1_macro: 0.8330 - loss: 0.3827 - val_accuracy: 0.8512 - val_f1_macro: 0.8451 - val_loss: 0.3577
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8509 - f1_macro: 0.8449 - loss: 0.3516 - val_accuracy: 0.8521 - val_f1_macro: 0.8410 - val_loss: 0.3667
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8560 - f1_macro: 0.8466 - loss: 0.3420 - val_accuracy: 0.8558 - val_f1_macro: 0.8493 - val_loss: 0.3542
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8627 - f1_macro: 0.8588 - loss: 0.3359 - val_accuracy: 0.8696 - val_f1_macro: 0.8653 - val_loss: 0.3364
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8622 - f1_macro: 0.8603 - loss: 0.3336 - val_accuracy: 0.8479 - val_f1_macro: 0.8320 - val_loss: 0.3718
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8661 - f1_macro: 0.8617 - loss: 0.3275 - val_accuracy: 0.8658 - val_f1_macro: 0.8586 - val_loss: 0.3445
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8724 - f1_macro: 0.8680 - loss: 0.3131 - val_accuracy: 0.8692 - val_f1_macro: 0.8641 - val_loss: 0.3252
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8694 - f1_macro: 0.8652 - loss: 0.3101 - val_accuracy: 0.8621 - val_f1_macro: 0.8516 - val_loss: 0.3426
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8803 - f1_macro: 0.8766 - loss: 0.3027 - val_accuracy: 0.8725 - val_f1_macro: 0.8657 - val_loss: 0.3255
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8819 - f1_macro: 0.8768 - loss: 0.2979 - val_accuracy: 0.8712 - val_f1_macro: 0.8638 - val_loss: 0.3208
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8788 - f1_macro: 0.8737 - loss: 0.2967 - val_accuracy: 0.8725 - val_f1_macro: 0.8665 - val_loss: 0.3223
# Epoch 15/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8828 - f1_macro: 0.8799 - loss: 0.2912 - val_accuracy: 0.8696 - val_f1_macro: 0.8613 - val_loss: 0.3239
# Epoch 16/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8878 - f1_macro: 0.8847 - loss: 0.2868 - val_accuracy: 0.8750 - val_f1_macro: 0.8675 - val_loss: 0.3133
# Epoch 17/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8914 - f1_macro: 0.8873 - loss: 0.2734 - val_accuracy: 0.8583 - val_f1_macro: 0.8427 - val_loss: 0.3437
# Epoch 18/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8921 - f1_macro: 0.8893 - loss: 0.2705 - val_accuracy: 0.8746 - val_f1_macro: 0.8679 - val_loss: 0.3140
# Epoch 19/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8898 - f1_macro: 0.8862 - loss: 0.2756 - val_accuracy: 0.8763 - val_f1_macro: 0.8708 - val_loss: 0.3080
# Epoch 20/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8893 - f1_macro: 0.8852 - loss: 0.2692 - val_accuracy: 0.8675 - val_f1_macro: 0.8583 - val_loss: 0.3232
# Epoch 21/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8929 - f1_macro: 0.8892 - loss: 0.2684 - val_accuracy: 0.8763 - val_f1_macro: 0.8674 - val_loss: 0.3141
# Epoch 22/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8860 - f1_macro: 0.8824 - loss: 0.2783 - val_accuracy: 0.8621 - val_f1_macro: 0.8477 - val_loss: 0.3466
# Epoch 23/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9019 - f1_macro: 0.8989 - loss: 0.2500 - val_accuracy: 0.8754 - val_f1_macro: 0.8671 - val_loss: 0.3148
# Epoch 24/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9018 - f1_macro: 0.8972 - loss: 0.2480 - val_accuracy: 0.8675 - val_f1_macro: 0.8552 - val_loss: 0.3230
# Epoch 25/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8978 - f1_macro: 0.8940 - loss: 0.2516 - val_accuracy: 0.8779 - val_f1_macro: 0.8704 - val_loss: 0.3154
# Epoch 26/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8909 - f1_macro: 0.8890 - loss: 0.2584 - val_accuracy: 0.8729 - val_f1_macro: 0.8640 - val_loss: 0.3187
# Epoch 27/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9030 - f1_macro: 0.8995 - loss: 0.2410 - val_accuracy: 0.8704 - val_f1_macro: 0.8588 - val_loss: 0.3291
# Epoch 28/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9003 - f1_macro: 0.8974 - loss: 0.2459 - val_accuracy: 0.8646 - val_f1_macro: 0.8499 - val_loss: 0.3411
# Epoch 29/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9024 - f1_macro: 0.8977 - loss: 0.2410 - val_accuracy: 0.8804 - val_f1_macro: 0.8727 - val_loss: 0.3158
# Epoch 30/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9145 - f1_macro: 0.9093 - loss: 0.2209 - val_accuracy: 0.8821 - val_f1_macro: 0.8738 - val_loss: 0.3167
# Epoch 31/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9103 - f1_macro: 0.9071 - loss: 0.2265 - val_accuracy: 0.8863 - val_f1_macro: 0.8796 - val_loss: 0.3018
# Epoch 32/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9076 - f1_macro: 0.9047 - loss: 0.2266 - val_accuracy: 0.8783 - val_f1_macro: 0.8672 - val_loss: 0.3235
# Epoch 33/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9155 - f1_macro: 0.9130 - loss: 0.2207 - val_accuracy: 0.8779 - val_f1_macro: 0.8690 - val_loss: 0.3152
# Epoch 34/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9141 - f1_macro: 0.9106 - loss: 0.2209 - val_accuracy: 0.8800 - val_f1_macro: 0.8707 - val_loss: 0.3170
# Epoch 35/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9155 - f1_macro: 0.9126 - loss: 0.2100 - val_accuracy: 0.8833 - val_f1_macro: 0.8760 - val_loss: 0.3057
# Epoch 36/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9208 - f1_macro: 0.9180 - loss: 0.2001 - val_accuracy: 0.8696 - val_f1_macro: 0.8550 - val_loss: 0.3393
# Epoch 37/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9200 - f1_macro: 0.9153 - loss: 0.2025 - val_accuracy: 0.8792 - val_f1_macro: 0.8691 - val_loss: 0.3261
# Epoch 38/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9123 - f1_macro: 0.9086 - loss: 0.2102 - val_accuracy: 0.8892 - val_f1_macro: 0.8822 - val_loss: 0.3099
# Epoch 39/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9226 - f1_macro: 0.9206 - loss: 0.2001 - val_accuracy: 0.8813 - val_f1_macro: 0.8716 - val_loss: 0.3165
# Epoch 40/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9158 - f1_macro: 0.9131 - loss: 0.2021 - val_accuracy: 0.8800 - val_f1_macro: 0.8721 - val_loss: 0.3176
# Epoch 41/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9185 - f1_macro: 0.9143 - loss: 0.1984 - val_accuracy: 0.8804 - val_f1_macro: 0.8692 - val_loss: 0.3186
# Epoch 42/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9226 - f1_macro: 0.9197 - loss: 0.1965 - val_accuracy: 0.8821 - val_f1_macro: 0.8727 - val_loss: 0.3168
# Epoch 43/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9198 - f1_macro: 0.9178 - loss: 0.1946 - val_accuracy: 0.8825 - val_f1_macro: 0.8756 - val_loss: 0.3186
# Epoch 44/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9132 - f1_macro: 0.9077 - loss: 0.2132 - val_accuracy: 0.8821 - val_f1_macro: 0.8734 - val_loss: 0.3358
# Epoch 45/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9223 - f1_macro: 0.9182 - loss: 0.1854 - val_accuracy: 0.8800 - val_f1_macro: 0.8702 - val_loss: 0.3298
# Epoch 46/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9249 - f1_macro: 0.9217 - loss: 0.1830 - val_accuracy: 0.8725 - val_f1_macro: 0.8577 - val_loss: 0.3536
# Epoch 47/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9100 - f1_macro: 0.9039 - loss: 0.2167 - val_accuracy: 0.8808 - val_f1_macro: 0.8722 - val_loss: 0.3130
# Epoch 48/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9274 - f1_macro: 0.9240 - loss: 0.1809 - val_accuracy: 0.8671 - val_f1_macro: 0.8492 - val_loss: 0.3767
# Epoch 49/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9270 - f1_macro: 0.9234 - loss: 0.1784 - val_accuracy: 0.8825 - val_f1_macro: 0.8730 - val_loss: 0.3383
# Epoch 50/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9267 - f1_macro: 0.9243 - loss: 0.1722 - val_accuracy: 0.8775 - val_f1_macro: 0.8664 - val_loss: 0.3337
# Restoring model weights from the end of the best epoch: 38.
# Fold 5 - CV Val Loss: 0.3099, CV Val Acc: 0.8892, CV Val F1-Macro: 0.8822
#
# --- Cross-Validation Summary ---
# Average CV Loss: 0.3229 (+/- 0.0148)
# Average CV Accuracy: 0.8844 (+/- 0.0044)
# Average CV F1-Macro: 0.8800 (+/- 0.0039)

# %%
# ----- Train Final Model -----
#EPOCHS_FINAL = 40 
BATCH_SIZE_FINAL = 32
EPOCHS_FINAL_NEW = 60  # เพิ่มจำนวน Epochs สำหรับการฝึกที่นานขึ้น
PATIENCE_FINAL_NEW = 15 # เพิ่ม Patience สำหรับ EarlyStopping
history_final = None 

# --- LEARNING RATE PARAMETERS FOR FINAL MODEL SCHEDULER ---
INITIAL_LR_FINAL = 0.0001  # <<<<----- ปรับค่าเริ่มต้นที่นี่ (เช่น 0.0005 หรือ 0.00025)
END_LR_FINAL = 0.00005     # <<<<----- ปรับค่าสุดท้ายที่นี่ (เช่น 0.00001 หรือ 0.000005)

if X_train_orig.shape[0] > 0:
    y_train_orig_2d = y_train_orig.reshape(-1, 1)
    y_val_orig_2d = None
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        y_val_orig_2d = y_val_orig.reshape(-1, 1)

    print("\n--- Training Final Model with Transformer Classifier ---")
    
    # สร้าง final_model ด้วย create_transformer_classifier
    # learning_rate ที่ส่งเข้าไปใน create_transformer_classifier จะไม่ถูกใช้
    # ถ้าเรา recompile ด้วย optimizer ใหม่ด้านล่าง
    final_model = create_transformer_classifier(
        input_shape=transformer_input_shape, num_encoder_blocks=NUM_ENCODER_BLOCKS,
        d_model=D_MODEL, num_heads=NUM_HEADS, ff_dim=FF_DIM,
        projection_dim=PROJECTION_DIM, final_dense_units=FINAL_DENSE_UNITS,
        dropout_rate=DROPOUT_RATE, # ใช้ DROPOUT_RATE ที่ตั้งไว้
        learning_rate=0.0005 # ค่า dummy หรือ initial LR เดิม, เพราะจะ recompile อยู่ดี
    )

    # --- DEFINE LEARNING RATE SCHEDULE FOR FINAL MODEL ---
    num_train_samples_final = X_train_orig.shape[0]
    total_decay_steps_final = (num_train_samples_final // BATCH_SIZE_FINAL) * EPOCHS_FINAL_NEW 
    
    final_lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        initial_learning_rate=INITIAL_LR_FINAL, # <<<<----- ใช้ค่าใหม่ที่ตั้งไว้
        decay_steps=total_decay_steps_final,
        end_learning_rate=END_LR_FINAL,         # <<<<----- ใช้ค่าใหม่ที่ตั้งไว้
        power=1.0 # Linear decay (หรือลองค่าอื่น เช่น 0.5)
    )
    
    # สร้าง Optimizer ใหม่ด้วย Learning Rate Schedule
    optimizer_with_schedule_final = Adam(learning_rate=final_lr_schedule)

    # Recompile final_model ด้วย Optimizer ใหม่ที่มี Schedule
    f1_metric_for_recompile = tf.keras.metrics.F1Score(average='macro', threshold=0.5, name='f1_macro')
    final_model.compile(optimizer=optimizer_with_schedule_final,
                        loss='binary_crossentropy',
                        metrics=['accuracy', f1_metric_for_recompile])
    print(f"Recompiled final_model with PolynomialDecay LR schedule (Initial: {INITIAL_LR_FINAL}, End: {END_LR_FINAL}).")

    callbacks_final = []
    validation_data_for_fit = None
    if y_val_orig_2d is not None:
        validation_data_for_fit = (X_val_orig, y_val_orig_2d)
        early_stopping_final = EarlyStopping(
            monitor='val_f1_macro', 
            patience=PATIENCE_FINAL_NEW, # ใช้ PATIENCE_FINAL_NEW ที่ตั้งไว้
            verbose=1, 
            mode='max', 
            restore_best_weights=True
        )
        callbacks_final.append(early_stopping_final)
        
        class PrintLR(tf.keras.callbacks.Callback): # Optional: Callback to print LR
            def on_epoch_end(self, epoch, logs=None):
                current_lr_value = self.model.optimizer.learning_rate
                if isinstance(current_lr_value, tf.keras.optimizers.schedules.LearningRateSchedule):
                    current_lr_value = current_lr_value(self.model.optimizer.iterations)
                try:
                    current_lr_value = tf.keras.backend.get_value(current_lr_value)
                except: pass
                print(f" - LR: {current_lr_value:.7f}", end="")
        callbacks_final.append(PrintLR())

        print(f"Training final model with validation data, LR schedule, and EarlyStopping (patience={PATIENCE_FINAL_NEW}).")
    else:
        print("Training final model without validation data. EarlyStopping on val_f1_macro disabled.")
    
    history_final = final_model.fit(X_train_orig, y_train_orig_2d, 
                                    epochs=EPOCHS_FINAL_NEW, # ใช้ EPOCHS_FINAL_NEW
                                    batch_size=BATCH_SIZE_FINAL, 
                                    validation_data=validation_data_for_fit, 
                                    callbacks=callbacks_final if callbacks_final else None, 
                                    verbose=1)
    
    if final_model:
        if X_test_orig.shape[0] > 0 and y_test_orig.shape[0] > 0:
            y_test_orig_2d = y_test_orig.reshape(-1, 1)
            print("\n--- Evaluating on Test Set (after final training) ---")
            eval_results_final = final_model.evaluate(X_test_orig, y_test_orig_2d, verbose=0)
            test_loss, test_accuracy, test_f1_macro = eval_results_final[0], eval_results_final[1], eval_results_final[2]
            print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Test F1-Macro: {test_f1_macro:.4f}")
        else:
            print("Skipping evaluation on Test Set: Test data is empty or not provided.")
else:
    print("Final model was not trained (likely due to empty training data).")


# ----- Export Model and Convert to TFLite -----
if 'final_model' in locals() and isinstance(final_model, tf.keras.Model):
    print("\n--- Evaluating on Test Set (Before Export) ---")
    if 'X_test_orig' in locals() and 'y_test_orig' in locals() and X_test_orig.size > 0:
        # --- RESHAPE y_test_orig for Keras F1Score metric during evaluation ---
        y_test_orig_2d_export = y_test_orig.reshape(-1, 1) # Use a different variable name or ensure it's reshaped if not already
        eval_results_export = final_model.evaluate(X_test_orig, y_test_orig_2d_export, verbose=0) # Use 2D y_true
        test_loss_exp, test_acc_exp, test_f1_exp = eval_results_export[0], eval_results_export[1], eval_results_export[2]
        print(f"Test Loss: {test_loss_exp:.4f}, Test Acc: {test_acc_exp:.4f}, Test F1-Macro: {test_f1_exp:.4f}")
    else:
        print("Test data not found or empty for pre-export evaluation.")

    export_directory = 'fall_model_exported_sm'
    try:
        final_model.export(export_directory)
        print(f"Model exported successfully in SavedModel format at: ./{export_directory}")

        print("\nConverting exported SavedModel to TensorFlow Lite...")
        try:
            converter = tf.lite.TFLiteConverter.from_saved_model(export_directory)
            tflite_model_content = converter.convert()
            tflite_model_path = 'fall_detection_transformer.tflite'
            with open(tflite_model_path, 'wb') as f: f.write(tflite_model_content)
            print(f"Model converted to TFLite and saved as {tflite_model_path} ({len(tflite_model_content)/1024:.2f} KB)")
        except Exception as tflite_e:
            print(f"Error during TFLite conversion: {tflite_e}")
    except Exception as e:
        print(f"Error during model export: {e}")
else:
    print("ERROR: 'final_model' not defined or not a Keras Model. Skipping export and TFLite conversion.")
# Out:
# --- Training Final Model with Transformer Classifier ---
# Recompiled final_model with PolynomialDecay LR schedule (Initial: 0.0001, End: 5e-05).
# Training final model with validation data, LR schedule, and EarlyStopping (patience=15).
# Epoch 1/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 34s 31ms/step - accuracy: 0.7131 - f1_macro: 0.6962 - loss: 0.5544 - val_accuracy: 0.8243 - val_f1_macro: 0.8072 - val_loss: 0.4119
# Epoch 2/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8181 - f1_macro: 0.8089 - loss: 0.4204 - val_accuracy: 0.8359 - val_f1_macro: 0.8222 - val_loss: 0.3665
# Epoch 3/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8403 - f1_macro: 0.8326 - loss: 0.3818 - val_accuracy: 0.8546 - val_f1_macro: 0.8494 - val_loss: 0.3429
# Epoch 4/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8456 - f1_macro: 0.8412 - loss: 0.3683 - val_accuracy: 0.8526 - val_f1_macro: 0.8374 - val_loss: 0.3538
# Epoch 5/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8625 - f1_macro: 0.8560 - loss: 0.3450 - val_accuracy: 0.8721 - val_f1_macro: 0.8646 - val_loss: 0.3150
# Epoch 6/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8571 - f1_macro: 0.8529 - loss: 0.3374 - val_accuracy: 0.8736 - val_f1_macro: 0.8670 - val_loss: 0.3116
# Epoch 7/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8667 - f1_macro: 0.8633 - loss: 0.3278 - val_accuracy: 0.8764 - val_f1_macro: 0.8721 - val_loss: 0.3016
# Epoch 8/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8728 - f1_macro: 0.8681 - loss: 0.3103 - val_accuracy: 0.8733 - val_f1_macro: 0.8648 - val_loss: 0.3080
# Epoch 9/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8757 - f1_macro: 0.8728 - loss: 0.3056 - val_accuracy: 0.8787 - val_f1_macro: 0.8710 - val_loss: 0.3027
# Epoch 10/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8778 - f1_macro: 0.8763 - loss: 0.2942 - val_accuracy: 0.8830 - val_f1_macro: 0.8789 - val_loss: 0.2906
# Epoch 11/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8782 - f1_macro: 0.8760 - loss: 0.3008 - val_accuracy: 0.8810 - val_f1_macro: 0.8733 - val_loss: 0.3076
# Epoch 12/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8851 - f1_macro: 0.8811 - loss: 0.2925 - val_accuracy: 0.8837 - val_f1_macro: 0.8804 - val_loss: 0.2904
# Epoch 13/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8818 - f1_macro: 0.8797 - loss: 0.2935 - val_accuracy: 0.8802 - val_f1_macro: 0.8736 - val_loss: 0.2919
# Epoch 14/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8869 - f1_macro: 0.8825 - loss: 0.2834 - val_accuracy: 0.8771 - val_f1_macro: 0.8696 - val_loss: 0.2938
# Epoch 15/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8868 - f1_macro: 0.8843 - loss: 0.2820 - val_accuracy: 0.8834 - val_f1_macro: 0.8779 - val_loss: 0.2910
# Epoch 16/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8888 - f1_macro: 0.8855 - loss: 0.2801 - val_accuracy: 0.8826 - val_f1_macro: 0.8786 - val_loss: 0.2853
# Epoch 17/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8865 - f1_macro: 0.8820 - loss: 0.2749 - val_accuracy: 0.8818 - val_f1_macro: 0.8776 - val_loss: 0.2878
# Epoch 18/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8934 - f1_macro: 0.8904 - loss: 0.2697 - val_accuracy: 0.8787 - val_f1_macro: 0.8696 - val_loss: 0.3014
# Epoch 19/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8946 - f1_macro: 0.8901 - loss: 0.2664 - val_accuracy: 0.8760 - val_f1_macro: 0.8662 - val_loss: 0.2981
# Epoch 20/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8874 - f1_macro: 0.8823 - loss: 0.2751 - val_accuracy: 0.8760 - val_f1_macro: 0.8701 - val_loss: 0.2937
# Epoch 21/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8954 - f1_macro: 0.8916 - loss: 0.2620 - val_accuracy: 0.8740 - val_f1_macro: 0.8641 - val_loss: 0.2984
# Epoch 22/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8973 - f1_macro: 0.8941 - loss: 0.2571 - val_accuracy: 0.8841 - val_f1_macro: 0.8751 - val_loss: 0.3006
# Epoch 23/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8996 - f1_macro: 0.8964 - loss: 0.2544 - val_accuracy: 0.8791 - val_f1_macro: 0.8719 - val_loss: 0.2901
# Epoch 24/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9046 - f1_macro: 0.9006 - loss: 0.2437 - val_accuracy: 0.8837 - val_f1_macro: 0.8769 - val_loss: 0.2881
# Epoch 25/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9028 - f1_macro: 0.8988 - loss: 0.2415 - val_accuracy: 0.8818 - val_f1_macro: 0.8755 - val_loss: 0.2896
# Epoch 26/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9013 - f1_macro: 0.8985 - loss: 0.2369 - val_accuracy: 0.8876 - val_f1_macro: 0.8824 - val_loss: 0.2771
# Epoch 27/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9042 - f1_macro: 0.8995 - loss: 0.2410 - val_accuracy: 0.8861 - val_f1_macro: 0.8813 - val_loss: 0.2849
# Epoch 28/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9052 - f1_macro: 0.9027 - loss: 0.2355 - val_accuracy: 0.8841 - val_f1_macro: 0.8779 - val_loss: 0.2933
# Epoch 29/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9066 - f1_macro: 0.9019 - loss: 0.2310 - val_accuracy: 0.8869 - val_f1_macro: 0.8816 - val_loss: 0.2951
# Epoch 30/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9116 - f1_macro: 0.9089 - loss: 0.2278 - val_accuracy: 0.8791 - val_f1_macro: 0.8709 - val_loss: 0.2930
# Epoch 31/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9119 - f1_macro: 0.9080 - loss: 0.2329 - val_accuracy: 0.8884 - val_f1_macro: 0.8831 - val_loss: 0.2798
# Epoch 32/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9054 - f1_macro: 0.9033 - loss: 0.2374 - val_accuracy: 0.8802 - val_f1_macro: 0.8750 - val_loss: 0.2946
# Epoch 33/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9131 - f1_macro: 0.9097 - loss: 0.2175 - val_accuracy: 0.8830 - val_f1_macro: 0.8763 - val_loss: 0.2832
# Epoch 34/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9157 - f1_macro: 0.9128 - loss: 0.2161 - val_accuracy: 0.8865 - val_f1_macro: 0.8804 - val_loss: 0.2880
# Epoch 35/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9195 - f1_macro: 0.9150 - loss: 0.2067 - val_accuracy: 0.8849 - val_f1_macro: 0.8793 - val_loss: 0.2895
# Epoch 36/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9124 - f1_macro: 0.9081 - loss: 0.2213 - val_accuracy: 0.8853 - val_f1_macro: 0.8827 - val_loss: 0.2893
# Epoch 37/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9151 - f1_macro: 0.9124 - loss: 0.2159 - val_accuracy: 0.8861 - val_f1_macro: 0.8811 - val_loss: 0.2877
# Epoch 38/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9131 - f1_macro: 0.9117 - loss: 0.2098 - val_accuracy: 0.8853 - val_f1_macro: 0.8791 - val_loss: 0.2875
# Epoch 39/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9213 - f1_macro: 0.9180 - loss: 0.2069 - val_accuracy: 0.8896 - val_f1_macro: 0.8841 - val_loss: 0.2947
# Epoch 40/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9189 - f1_macro: 0.9145 - loss: 0.2124 - val_accuracy: 0.8876 - val_f1_macro: 0.8809 - val_loss: 0.3008
# Epoch 41/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9218 - f1_macro: 0.9181 - loss: 0.2050 - val_accuracy: 0.8876 - val_f1_macro: 0.8840 - val_loss: 0.2888
# Epoch 42/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9190 - f1_macro: 0.9143 - loss: 0.2067 - val_accuracy: 0.8802 - val_f1_macro: 0.8731 - val_loss: 0.3012
# Epoch 43/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9255 - f1_macro: 0.9219 - loss: 0.1936 - val_accuracy: 0.8818 - val_f1_macro: 0.8749 - val_loss: 0.2996
# Epoch 44/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9235 - f1_macro: 0.9214 - loss: 0.1963 - val_accuracy: 0.8802 - val_f1_macro: 0.8718 - val_loss: 0.3064
# Epoch 45/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9246 - f1_macro: 0.9218 - loss: 0.1911 - val_accuracy: 0.8853 - val_f1_macro: 0.8791 - val_loss: 0.2987
# Epoch 46/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9262 - f1_macro: 0.9237 - loss: 0.1843 - val_accuracy: 0.8822 - val_f1_macro: 0.8720 - val_loss: 0.3165
# Epoch 47/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9247 - f1_macro: 0.9211 - loss: 0.1858 - val_accuracy: 0.8849 - val_f1_macro: 0.8765 - val_loss: 0.3138
# Epoch 48/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9276 - f1_macro: 0.9245 - loss: 0.1857 - val_accuracy: 0.8884 - val_f1_macro: 0.8842 - val_loss: 0.2970
# Epoch 49/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9278 - f1_macro: 0.9244 - loss: 0.1753 - val_accuracy: 0.8872 - val_f1_macro: 0.8821 - val_loss: 0.3092
# Epoch 50/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9289 - f1_macro: 0.9262 - loss: 0.1750 - val_accuracy: 0.8876 - val_f1_macro: 0.8807 - val_loss: 0.3174
# Epoch 51/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9301 - f1_macro: 0.9274 - loss: 0.1792 - val_accuracy: 0.8806 - val_f1_macro: 0.8723 - val_loss: 0.3190
# Epoch 52/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9287 - f1_macro: 0.9272 - loss: 0.1794 - val_accuracy: 0.8767 - val_f1_macro: 0.8662 - val_loss: 0.3166
# Epoch 53/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9354 - f1_macro: 0.9307 - loss: 0.1711 - val_accuracy: 0.8853 - val_f1_macro: 0.8783 - val_loss: 0.3069
# Epoch 54/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9292 - f1_macro: 0.9264 - loss: 0.1793 - val_accuracy: 0.8841 - val_f1_macro: 0.8759 - val_loss: 0.3163
# Epoch 55/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9316 - f1_macro: 0.9298 - loss: 0.1744 - val_accuracy: 0.8853 - val_f1_macro: 0.8780 - val_loss: 0.2993
# Epoch 56/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9355 - f1_macro: 0.9321 - loss: 0.1643 - val_accuracy: 0.8771 - val_f1_macro: 0.8674 - val_loss: 0.3052
# Epoch 57/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9354 - f1_macro: 0.9320 - loss: 0.1723 - val_accuracy: 0.8837 - val_f1_macro: 0.8764 - val_loss: 0.3075
# Epoch 58/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9294 - f1_macro: 0.9259 - loss: 0.1754 - val_accuracy: 0.8880 - val_f1_macro: 0.8824 - val_loss: 0.3087
# Epoch 59/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9350 - f1_macro: 0.9327 - loss: 0.1619 - val_accuracy: 0.8826 - val_f1_macro: 0.8745 - val_loss: 0.3252
# Epoch 60/60
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9382 - f1_macro: 0.9345 - loss: 0.1525 - val_accuracy: 0.8892 - val_f1_macro: 0.8837 - val_loss: 0.3081
# Restoring model weights from the end of the best epoch: 48.
#
# --- Evaluating on Test Set (after final training) ---
# Test Loss: 0.2817, Test Accuracy: 0.8985, Test F1-Macro: 0.8936
#
# --- Evaluating on Test Set (Before Export) ---
# Test Loss: 0.2817, Test Acc: 0.8985, Test F1-Macro: 0.8936
# Saved artifact at 'fall_model_exported_sm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 30, 51), dtype=tf.float32, name='input_features')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   134994057356176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994057349072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994057357712: TensorSpec(shape=(1, 30, 64), dtype=tf.float32, name=None)
#   134994057362320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134995245154576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994057347344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994057348112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994057363088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134995236712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134995236700624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134995236712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994088385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994088383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994088382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994737375632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994737373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994740481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994088381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588559760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588565136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588562448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588550544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588551312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588555536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994588556688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743733968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743733200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743727248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743734352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743737424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994743735504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063156688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063158992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063159760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063151312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063157072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063162448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063150160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063148624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063147856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994063159376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994066003472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994066008464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994066005776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994066013840: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model exported successfully in SavedModel format at: ./fall_model_exported_sm
#
# Converting exported SavedModel to TensorFlow Lite...
# Model converted to TFLite and saved as fall_detection_transformer.tflite (454.25 KB)
# W0000 00:00:1748933106.359967      35 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1748933106.360001      35 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.

# %%
# ----- Plot Training History of Final Model -----
if history_final and hasattr(history_final, 'history') and history_final.history:
    plt.figure(figsize=(18, 5)) # Adjusted for 3 subplots
    
    plt.subplot(1, 3, 1)
    if 'accuracy' in history_final.history: plt.plot(history_final.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history_final.history: plt.plot(history_final.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    
    plt.subplot(1, 3, 2)
    if 'loss' in history_final.history: plt.plot(history_final.history['loss'], label='Train Loss')
    if 'val_loss' in history_final.history: plt.plot(history_final.history['val_loss'], label='Val Loss')
    plt.title('Model Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)

    plt.subplot(1, 3, 3) # New subplot for F1-Macro
    if 'f1_macro' in history_final.history: plt.plot(history_final.history['f1_macro'], label='Train F1-Macro')
    if 'val_f1_macro' in history_final.history: plt.plot(history_final.history['val_f1_macro'], label='Val F1-Macro')
    plt.title('Model F1-Macro Score'); plt.xlabel('Epoch'); plt.ylabel('F1-Macro'); plt.legend(); plt.grid(True)
    
    plt.tight_layout(); plt.show()
else:
    print("Skipping plotting: final model training history unavailable.")

# %%
from sklearn.metrics import f1_score

# y_pred_val_probs ได้จากการ predict บน X_val_orig
best_threshold = 0.5
best_f1 = 0.0
thresholds = np.arange(0.1, 0.9, 0.01)
for thresh in thresholds:
    current_preds = (y_pred_val_probs > thresh).astype(int)
    current_f1 = f1_score(y_val_orig, current_preds, average='macro') # หรือ average='binary' ถ้าสนใจ F1 ของคลาส fall
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_threshold = thresh
print(f"Best threshold on validation set: {best_threshold:.2f} with F1-Macro: {best_f1:.4f}")
# Out:
# Best threshold on validation set: 0.53 with F1-Macro: 0.8926

# %%
# ----- FUNCTION TO PLOT CONFUSION MATRIX -----
def plot_confusion_matrix_custom(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title); plt.ylabel('True label'); plt.xlabel('Predicted label'); plt.show()

# ----- FUNCTION TO PLOT METRICS BARCHART  -----
def plot_metrics_barchart(metrics_data, class_names, title='Metrics per Class'):
    df_metrics = pd.DataFrame(metrics_data, index=class_names)
    ax = df_metrics.plot(kind='bar', figsize=(10, 7), width=0.8, colormap='viridis')
    plt.title(title, fontsize=15); plt.ylabel('Score (%)', fontsize=12); plt.xlabel('Class', fontsize=12)
    plt.xticks(rotation=0); plt.ylim(0, 1)
    for p in ax.patches:
        ax.annotate(f"{p.get_height()*100:.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 9), textcoords='offset points', fontsize=10)
    plt.legend(title='Metrics'); plt.tight_layout(); plt.show()

# ----- DETAILED EVALUATION AND REPORTING -----
target_names = ['no_fall', 'fall']
class_labels = [0, 1] # Corresponding numerical labels

# Initialize prediction variables to None
y_pred_val_probs = None
y_pred_val_classes = None
y_pred_test_probs = None
y_pred_test_classes = None

# --- กำหนด Optimized Threshold ที่คุณได้มา ---
OPTIMIZED_THRESHOLD = 0.5 # หรือค่าที่คุณได้จากการทดลองล่าสุด

if final_model is not None:
    # --- Evaluation on Validation Set ---
    if X_val_orig.size > 0 and y_val_orig.size > 0:
        print(f"\n\n--- Custom Validation Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_val_probs = final_model.predict(X_val_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_val_classes = (y_pred_val_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_val, recall_val, f1_val, support_val = precision_recall_fscore_support(
            y_val_orig, y_pred_val_classes, labels=class_labels, zero_division=0
        )
        f2_val_per_class = fbeta_score(y_val_orig, y_pred_val_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ validation) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_val[i]:>10.4f} {recall_val[i]:>10.4f} {f1_val[i]:>10.4f} {f2_val_per_class[i]:>10.4f} {support_val[i]:>10}")
        val_metrics_for_plot = {'Precision': precision_val, 'Recall': recall_val, 'F1-score': f1_val, 'F2-score': f2_val_per_class}
        plot_metrics_barchart(val_metrics_for_plot, target_names, title=f'Validation Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_val = confusion_matrix(y_val_orig, y_pred_val_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_val, classes=target_names, title=f'Validation Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')

    else: print("\nValidation data empty. Skipping detailed validation metrics report.")

    # --- Evaluation on Test Set ---
    if X_test_orig.size > 0 and y_test_orig.size > 0:
        print(f"\n\n--- Custom Test Metrics Report (Threshold: {OPTIMIZED_THRESHOLD}) ---")
        y_pred_test_probs = final_model.predict(X_test_orig)
        # --- ใช้ OPTIMIZED_THRESHOLD ที่นี่ ---
        y_pred_test_classes = (y_pred_test_probs > OPTIMIZED_THRESHOLD).astype(int).flatten()
        
        precision_test, recall_test, f1_test, support_test = precision_recall_fscore_support(
            y_test_orig, y_pred_test_classes, labels=class_labels, zero_division=0
        )
        f2_test_per_class = fbeta_score(y_test_orig, y_pred_test_classes, beta=2, labels=class_labels, average=None, zero_division=0)
        # ... (ส่วนที่เหลือของการ print report และ plot ของ test) ...
        print(f"{'':9} {'Precision':>10} {'Recall':>10} {'F1-score':>10} {'F2-score':>10} {'Support':>10}")
        for i, class_name in enumerate(target_names):
            print(f"{class_name:9} {precision_test[i]:>10.4f} {recall_test[i]:>10.4f} {f1_test[i]:>10.4f} {f2_test_per_class[i]:>10.4f} {support_test[i]:>10}")
        test_metrics_for_plot = {'Precision': precision_test, 'Recall': recall_test, 'F1-score': f1_test, 'F2-score': f2_test_per_class}
        plot_metrics_barchart(test_metrics_for_plot, target_names, title=f'Test Metrics (Threshold: {OPTIMIZED_THRESHOLD})')
        cm_test = confusion_matrix(y_test_orig, y_pred_test_classes, labels=class_labels)
        plot_confusion_matrix_custom(cm_test, classes=target_names, title=f'Test Confusion Matrix (Threshold: {OPTIMIZED_THRESHOLD})')
    else: print("\nTest data empty. Skipping detailed test metrics.")
else:
    print("Final model not trained. Skipping detailed evaluation.")
# Out:
# --- Custom Validation Metrics Report (Threshold: 0.5) ---
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9014     0.8834     0.8923     0.8869       1346
# fall          0.8747     0.8940     0.8842     0.8900       1226
# --- Custom Test Metrics Report (Threshold: 0.5) ---
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#            Precision     Recall   F1-score   F2-score    Support
# no_fall       0.9033     0.9027     0.9030     0.9028       1346
# fall          0.8932     0.8940     0.8936     0.8938       1226

# %%
# ----- Error Analysis and Logging -----
print("\nStarting Error Analysis and Logging...")
error_log_filename = "error_analysis_report.txt"

# --- Validation Set Analysis ---
can_analyze_val = False
missing_val_vars_reason = ""

if 'target_names' not in locals():
    missing_val_vars_reason = "'target_names' is not defined."
elif 'y_val_orig' not in locals() or y_val_orig is None:
    missing_val_vars_reason = "'y_val_orig' is not defined or is None."
elif 'val_npy_filepaths' not in locals() or val_npy_filepaths is None:
    missing_val_vars_reason = "'val_npy_filepaths' is not defined or is None."
elif 'y_pred_val_classes' not in locals() or y_pred_val_classes is None:
    missing_val_vars_reason = "'y_pred_val_classes' (predictions for validation) is not defined or is None. This might happen if validation data was empty or model was not trained."
elif 'y_pred_val_probs' not in locals() or y_pred_val_probs is None:
    missing_val_vars_reason = "'y_pred_val_probs' (prediction probabilities for validation) is not defined or is None."
elif not (y_val_orig.size > 0 and len(val_npy_filepaths) > 0 and \
          y_pred_val_classes.size > 0 and y_pred_val_probs.size > 0 and \
          len(y_val_orig) == len(val_npy_filepaths) == len(y_pred_val_classes) == y_pred_val_probs.shape[0]): # Check shape[0] for probs
    missing_val_vars_reason = "Data for validation error analysis is empty, or array lengths are mismatched."
else:
    can_analyze_val = True

if not can_analyze_val:
    print(f"ERROR: Validation Error Analysis cannot proceed. Reason: {missing_val_vars_reason}")
    # Optionally, write this skip reason to the log file if it's created unconditionally
    with open(error_log_filename, "w", encoding="utf-8") as log_f_skip: # Open in write mode to create/overwrite
        log_f_skip.write("--- Error Analysis Report ---\n")
        log_f_skip.write(f"Timestamp: {pd.Timestamp.now()}\n\n")
        log_f_skip.write("=== Validation Set Analysis ===\n")
        log_f_skip.write(f"Skipped. Reason: {missing_val_vars_reason}\n")
else:
    with open(error_log_filename, "w", encoding="utf-8") as log_f: # Open in write mode
        log_f.write("--- Error Analysis Report ---\n")
        log_f.write(f"Timestamp: {pd.Timestamp.now()}\n")

        log_f.write("\n\n=== Validation Set Analysis ===\n")
        fp_indices_val = np.where((y_pred_val_classes == 1) & (y_val_orig == 0))[0]
        fn_indices_val = np.where((y_pred_val_classes == 0) & (y_val_orig == 1))[0]

        log_f.write(f"Total Validation Samples: {len(y_val_orig)}\n")
        log_f.write(f"False Positives (No_Fall predicted as Fall): {len(fp_indices_val)}\n")
        log_f.write(f"False Negatives (Fall predicted as No_Fall): {len(fn_indices_val)}\n")

        log_f.write("\n--- Details of False Positives (Validation) ---\n")
        if len(fp_indices_val) > 0:
            for i, fp_idx in enumerate(fp_indices_val):
                true_label = y_val_orig[fp_idx]
                pred_label = y_pred_val_classes[fp_idx]
                pred_prob_fall = y_pred_val_probs[fp_idx]
                if isinstance(pred_prob_fall, (np.ndarray, list)): pred_prob_fall = pred_prob_fall[0]
                
                npy_full_path_str = val_npy_filepaths[fp_idx]
                npy_filename = Path(npy_full_path_str).name
                # ... (rest of FP logging logic from your original code) ...
                log_f.write(f"\nFP Sample #{i+1} (Original Index: {fp_idx})\n")
                log_f.write(f"  NPY File: {npy_filename}, True: {target_names[true_label]}, Pred: {target_names[pred_label]}, Prob(Fall): {pred_prob_fall:.4f}\n")
                log_f.write(f"  NPY Full Path: {npy_full_path_str}\n")
        else:
            log_f.write("No False Positives found in Validation Set.\n")

        log_f.write("\n--- Details of False Negatives (Validation) ---\n")
        if len(fn_indices_val) > 0:
            for i, fn_idx in enumerate(fn_indices_val):
                true_label = y_val_orig[fn_idx]
                pred_label = y_pred_val_classes[fn_idx]
                pred_prob_fall = y_pred_val_probs[fn_idx]
                if isinstance(pred_prob_fall, (np.ndarray, list)): pred_prob_fall = pred_prob_fall[0]

                npy_full_path_str = val_npy_filepaths[fn_idx]
                npy_filename = Path(npy_full_path_str).name
                # ... (rest of FN logging logic from your original code) ...
                log_f.write(f"\nFN Sample #{i+1} (Original Index: {fn_idx})\n")
                log_f.write(f"  NPY File: {npy_filename}, True: {target_names[true_label]}, Pred: {target_names[pred_label]}, Prob(Fall): {pred_prob_fall:.4f}\n")
                log_f.write(f"  NPY Full Path: {npy_full_path_str}\n")
        else:
            log_f.write("No False Negatives found in Validation Set.\n")

        # --- (Optional) Test Set Analysis (within the same log file if validation analysis was done) ---
        can_analyze_test = False
        missing_test_vars_reason = ""
        if 'y_test_orig' not in locals() or y_test_orig is None:
            missing_test_vars_reason = "'y_test_orig' is not defined or is None."
        elif 'test_npy_filepaths' not in locals() or test_npy_filepaths is None:
            missing_test_vars_reason = "'test_npy_filepaths' is not defined or is None."
        elif 'y_pred_test_classes' not in locals() or y_pred_test_classes is None:
            missing_test_vars_reason = "'y_pred_test_classes' (predictions for test) is not defined or is None."
        elif 'y_pred_test_probs' not in locals() or y_pred_test_probs is None:
            missing_test_vars_reason = "'y_pred_test_probs' (prediction probabilities for test) is not defined or is None."
        elif not (y_test_orig.size > 0 and len(test_npy_filepaths) > 0 and \
                  y_pred_test_classes.size > 0 and y_pred_test_probs.size > 0 and \
                  len(y_test_orig) == len(test_npy_filepaths) == len(y_pred_test_classes) == y_pred_test_probs.shape[0]):
             missing_test_vars_reason = "Data for test error analysis is empty, or array lengths are mismatched."
        else:
            can_analyze_test = True

        if not can_analyze_test:
            log_f.write("\n\n=== Test Set Analysis ===\n")
            log_f.write(f"Skipped. Reason: {missing_test_vars_reason}\n")
            print(f"Skipping Test Error Analysis in log. Reason: {missing_test_vars_reason}")
        else:
            log_f.write("\n\n=== Test Set Analysis ===\n")
            fp_indices_test = np.where((y_pred_test_classes == 1) & (y_test_orig == 0))[0]
            fn_indices_test = np.where((y_pred_test_classes == 0) & (y_test_orig == 1))[0]

            log_f.write(f"Total Test Samples: {len(y_test_orig)}\n")
            log_f.write(f"False Positives: {len(fp_indices_test)}\n")
            log_f.write(f"False Negatives: {len(fn_indices_test)}\n")
            
            log_f.write("\n--- Details of False Positives (Test) ---\n")
            # ... (Similar logging logic as validation FP) ...
            if len(fp_indices_test) > 0:
                 for i, fp_idx_t in enumerate(fp_indices_test):
                    true_label_t, pred_label_t = y_test_orig[fp_idx_t], y_pred_test_classes[fp_idx_t]
                    pred_prob_t = y_pred_test_probs[fp_idx_t][0] if isinstance(y_pred_test_probs[fp_idx_t], (np.ndarray, list)) else y_pred_test_probs[fp_idx_t]
                    npy_path_t = test_npy_filepaths[fp_idx_t]
                    npy_fn_t = Path(npy_path_t).name
                    log_f.write(f"\nFP_Test Sample #{i+1} (Idx: {fp_idx_t}) NPY: {npy_fn_t}\n  True: {target_names[true_label_t]}, Pred: {target_names[pred_label_t]}, Prob(Fall): {pred_prob_t:.4f}\n  Path: {npy_path_t}\n")
            else: log_f.write("No False Positives found in Test Set.\n")

            log_f.write("\n--- Details of False Negatives (Test) ---\n")
            # ... (Similar logging logic as validation FN) ...
            if len(fn_indices_test) > 0:
                for i, fn_idx_t in enumerate(fn_indices_test):
                    true_label_t, pred_label_t = y_test_orig[fn_idx_t], y_pred_test_classes[fn_idx_t]
                    pred_prob_t = y_pred_test_probs[fn_idx_t][0] if isinstance(y_pred_test_probs[fn_idx_t], (np.ndarray, list)) else y_pred_test_probs[fn_idx_t]
                    npy_path_t = test_npy_filepaths[fn_idx_t]
                    npy_fn_t = Path(npy_path_t).name
                    log_f.write(f"\nFN_Test Sample #{i+1} (Idx: {fn_idx_t}) NPY: {npy_fn_t}\n  True: {target_names[true_label_t]}, Pred: {target_names[pred_label_t]}, Prob(Fall): {pred_prob_t:.4f}\n  Path: {npy_path_t}\n")
            else: log_f.write("No False Negatives found in Test Set.\n")

    if can_analyze_val or (not can_analyze_val and 'log_f_skip' in locals()): # Check if log file was opened
        print(f"\nError Analysis Report status logged to: {error_log_filename}")
# Out:
# Starting Error Analysis and Logging...
#
# Error Analysis Report status logged to: error_analysis_report.txt
